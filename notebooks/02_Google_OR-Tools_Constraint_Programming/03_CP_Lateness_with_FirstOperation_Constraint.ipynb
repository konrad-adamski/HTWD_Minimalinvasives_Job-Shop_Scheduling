# %% [markdown]
# # Minimierung der Lateness jedes Produktionsauftrags

# %% [markdown]
# $$
# L_j = C_j - d_j
# $$
#
#
# - $L_j$: Lateness (Verspätung oder Frühfertigung) des Jobs $j$
# - $C_j$: tatsächliche Fertigstellungszeit (Completion Time) von Job $j$
# - $d_j$: Deadline bzw. geplanter Fertigstellungstermin von Job $j$
#
# **Interpretation:**
#
# - $L_j > 0$: Job ist **verspätet**
# - $L_j = 0$: Job ist **pünktlich**
# - $L_j < 0$: Job ist **zu früh** fertig

# %%
# Datenzugriff
from configs.path_manager import get_path

# Utils
from src.utils.new_filter import *
import src.utils.presenter as show
from src.utils.analize import check_constrains as check

# Solver Model
from src.models.cp import lateness_scheduling as cp_late_schedule
from src.models.cp import lateness_rescheduling as cp_late_reschedule

# Simulation
from src.simulation.ProductionRollingSimulation import ProductionSimulation

# Extern
import pandas as pd

pd.set_option('display.min_rows', 12)
pd.set_option('display.max_rows', 16)

# %%
# Harte Abbruchbedingung für die Scheduler
max_time = 60*30     # 30 min

# Simulation
simulation = ProductionSimulation(sigma = 0.15)

# %% [markdown]
# ## I. Laden des fertigen Job-Shop Scheduling Problems und der dazugehörigen Produktionsauftragsinformationen

# %%
basic_data_path = get_path("data", "basic")
df_jssp = pd.read_csv(basic_data_path / "jssp_final.csv")
df_jssp
# Out:
#             Job  Routing_ID  Operation Machine  Processing Time
# 0      J25-0000           8          0     M00               76
# 1      J25-0000           8          1     M01               69
# 2      J25-0000           8          2     M03               76
# 3      J25-0000           8          3     M05               51
# 4      J25-0000           8          4     M02               85
# 5      J25-0000           8          5     M09               11
# ...         ...         ...        ...     ...              ...
# 72494  J25-7249           4          4     M03               26
# 72495  J25-7249           4          5     M04               69
# 72496  J25-7249           4          6     M08               21
# 72497  J25-7249           4          7     M07               49
# 72498  J25-7249           4          8     M09               72
# 72499  J25-7249           4          9     M06               53
#
# [72500 rows x 5 columns]

# %%
df_jobs_times = pd.read_csv(basic_data_path / "jobs_times_final.csv")
df_jobs_times
# Out:
#            Job  Routing_ID  Arrival  Ready Time       End  Processing Time  \
# 0     J25-0000           8       79        1440    2704.0              597
# 1     J25-0001           6      129        1440    2336.0              416
# 2     J25-0002           0      198        1440    2925.0              395
# 3     J25-0003           2      243        1440    2801.0              568
# 4     J25-0004           3      287        1440    2697.0              655
# 5     J25-0005           1      498        1440    2630.0              510
# ...        ...         ...      ...         ...       ...              ...
# 7244  J25-7244           3   518085      518400  520251.0              655
# 7245  J25-7245           9   518089      518400  520296.0              540
# 7246  J25-7246           6   518116      518400  520027.0              416
# 7247  J25-7247           1   518184      518400  520040.0              510
# 7248  J25-7248           0   518188      518400  520417.0              395
# 7249  J25-7249           4   518302      518400  520333.0              393
#
#       Deadline
# 0         3660
# 1         2338
# 2         3744
# 3         3379
# 4         4856
# 5         3106
# ...        ...
# 7244    520389
# 7245    519640
# 7246    520157
# 7247    520172
# 7248    520490
# 7249    522163
#
# [7250 rows x 7 columns]

# %% [markdown]
# ## Tag 1
# - Am Tag 0 kommen die ersten Produktionsaufträge an, somit kann noch nichts geplant werden
# - Am Tag 1 findet die initiale Planung statt

# %%
day_length = 1440

day_numb = 1
day_start = day_length*day_numb
day_end = day_start + day_length
print(f"Tag {day_numb:02d}: [{day_start}, {day_end})")
# Out:
# Tag 01: [1440, 2880)

# %%
# "neue" und unerledigte Jobs
df_jobs_times_current = get_current_jobs(
    df_jobs_times, df_previous_not_started = None, ready_time=day_start
)
df_jobs_times_current
# Out:
#          Job  Routing_ID  Arrival  Ready Time     End  Processing Time  \
# 0   J25-0000           8       79        1440  2704.0              597
# 1   J25-0001           6      129        1440  2336.0              416
# 2   J25-0002           0      198        1440  2925.0              395
# 3   J25-0003           2      243        1440  2801.0              568
# 4   J25-0004           3      287        1440  2697.0              655
# 5   J25-0005           1      498        1440  2630.0              510
# 6   J25-0006           9      790        1440  2905.0              540
# 7   J25-0007           5      925        1440  2930.0              496
# 8   J25-0008           4      988        1440  2986.0              393
# 9   J25-0009           7     1004        1440  3045.0              539
# 10  J25-0010           0     1025        1440  3087.0              395
# 11  J25-0011           1     1030        1440  2773.0              510
# 12  J25-0012           2     1103        1440  3011.0              568
# 13  J25-0013           3     1192        1440  2834.0              655
# 14  J25-0014           4     1222        1440  3212.0              393
# 15  J25-0015           5     1436        1440  3096.0              496
#
#     Deadline
# 0       3660
# 1       2338
# 2       3744
# 3       3379
# 4       4856
# 5       3106
# 6       3539
# 7       2929
# 8       3541
# 9       3578
# 10      3345
# 11      3210
# 12      4385
# 13      2567
# 14      3315
# 15      2981

# %%
df_jssp_current = filter_current_jssp(df_jssp, df_jobs_times_current)
df_jssp_current
# Out:
#           Job  Routing_ID  Operation Machine  Processing Time
# 0    J25-0000           8          0     M00               76
# 1    J25-0000           8          1     M01               69
# 2    J25-0000           8          2     M03               76
# 3    J25-0000           8          3     M05               51
# 4    J25-0000           8          4     M02               85
# 5    J25-0000           8          5     M09               11
# ..        ...         ...        ...     ...              ...
# 154  J25-0015           5          4     M08               48
# 155  J25-0015           5          5     M09               72
# 156  J25-0015           5          6     M00               47
# 157  J25-0015           5          7     M06               65
# 158  J25-0015           5          8     M04                6
# 159  J25-0015           5          9     M07               25
#
# [160 rows x 5 columns]

# %% [markdown]
# ### Scheduling

# %% [markdown]
# #### Summe der Lateness (gewichtete Tardiness und Earliness) minimieren

# %% [markdown]
# ### Zielfunktion
#
# $$
# \min \sum_{j \in J} \left( w_t \cdot \max(C_j - d_j,\ 0) + w_e \cdot \max(d_j - C_j,\ 0) \right)
# $$
#
#
# - $J$: Menge aller Jobs
# - $C_j$: tatsächliche Endzeit (Completion Time) des letzten Arbeitsschritts von Job $j$
# - $d_j$: Deadline (Soll-Endzeitpunkt) von Job $j$
# - $w_t$: Gewichtung der **Tardiness** (Verspätung)
# - $w_e$: Gewichtung der **Earliness** (Frühfertigkeit)
# - $\max(C_j - d_j,\ 0)$: positive Verspätung
# - $\max(d_j - C_j,\ 0)$: positive Frühfertigkeit
#
# ### Erklärung
#
# Diese Zielfunktion minimiert die gewichtete Summe aus **Tardiness** (Verspätung) und **Earliness** (Frühfertigkeit) aller Jobs.
# Dabei wird jede Abweichung zur Deadline einzeln bewertet:
#
# - **Tardiness** wird mit $w_t$ gewichtet und tritt auf, wenn ein Job **nach** seiner Deadline fertig wird.
# - **Earliness** wird mit $w_e$ gewichtet und tritt auf, wenn ein Job **vor** seiner Deadline fertig wird.
#
# Durch die Wahl von $w_t \gg w_e$ kannst du **Verspätungen deutlich stärker bestrafen** als Frühfertigkeiten.

# %%
# Scheduling
df_schedule = cp_late_schedule.solve_jssp_sum_by_tardiness_and_earliness(
    df_jssp_current, df_jobs_times_current, earliest_start_column = "Ready Time", w_t= 5,
    msg=False, timeLimit=max_time, gapRel=0.01)
df_schedule
# Out:
# Solver-Status         : OPTIMAL
# Objective Value       : 0.00
# Best Objective Bound  : 0.00
# Laufzeit              : 0.03 Sekunden
#           Job  Routing_ID  Arrival  Ready Time  Deadline  Operation Machine  \
# 0    J25-0005           1      498        1440      3106          0     M00
# 1    J25-0007           5      925        1440      2929          0     M02
# 2    J25-0013           3     1192        1440      2567          0     M01
# 3    J25-0011           1     1030        1440      3210          0     M00
# 4    J25-0001           6      129        1440      2338          0     M01
# 5    J25-0013           3     1192        1440      2567          1     M02
# ..        ...         ...      ...         ...       ...        ...     ...
# 154  J25-0006           9      790        1440      3539          9     M07
# 155  J25-0009           7     1004        1440      3578          9     M03
# 156  J25-0000           8       79        1440      3660          9     M08
# 157  J25-0002           0      198        1440      3744          9     M09
# 158  J25-0012           2     1103        1440      4385          9     M04
# 159  J25-0004           3      287        1440      4856          9     M05
#
#      Start  Processing Time   End
# 0     1440               43  1483
# 1     1440               84  1524
# 2     1440               81  1521
# 3     1483               43  1526
# 4     1521               46  1567
# 5     1524               95  1619
# ..     ...              ...   ...
# 154   3494               45  3539
# 155   3499               79  3578
# 156   3586               74  3660
# 157   3723               21  3744
# 158   4352               33  4385
# 159   4813               43  4856
#
# [160 rows x 10 columns]

# %% [markdown]
# ### Simulation

# %%
simulation.run(dframe_schedule_plan = df_schedule, start_time = day_start, end_time=day_end)

# %%
df_execution = simulation.get_finished_operations_df()
show.plot_gantt(df_execution, perspective="Machine")

# %%
df_active = simulation.get_active_operations_df()
if df_active is not None:
    show.plot_gantt(df_active, perspective="Machine", duration_column="Planned Duration")

# %%
df_not_started = simulation.get_not_started_operations_df(df_schedule)
df_not_started

# %%
columns = ["Job", "Operation", "Machine", "Arrival", "Start", "Processing Time", "End"]
df_combined = pd.concat([df_execution, df_active[columns]], ignore_index=True)
show.plot_gantt_machines(df_combined)
check.is_machine_conflict_free(df_combined)
check.is_operation_sequence_correct(df_combined)
check.is_job_timing_correct(df_combined)
check.is_start_correct(df_combined)
# Out:
# + Keine Maschinenkonflikte gefunden
# + Alle Gruppen wurden in korrekter Operationsreihenfolge ausgeführt.
# + Alle technologischen Abhängigkeiten wurden eingehalten.
# + Alle Operation starten erst nach Arrival des Job
# True

# %% [markdown]
# ## Tag 2
# - hier findet die Neuplanung statt, also das Scheduling mit bestimmter Berücksichtigung der Simulation

# %%
day_numb = 2
day_start = day_length*day_numb
day_end = day_start + day_length
print(f"Tag {day_numb:02d}: [{day_start}, {day_end})")
# Out:
# Tag 02: [2880, 4320)

# %%
# "neue" und unerledigte Jobs
df_jobs_times_current = get_current_jobs(df_jobs_times, df_not_started, ready_time=day_start)
df_jobs_times_current
# Out:
#          Job  Routing_ID  Arrival  Ready Time     End  Processing Time  \
# 0   J25-0000           8       79        1440  2704.0              597
# 2   J25-0002           0      198        1440  2925.0              395
# 3   J25-0003           2      243        1440  2801.0              568
# 4   J25-0004           3      287        1440  2697.0              655
# 5   J25-0005           1      498        1440  2630.0              510
# 6   J25-0006           9      790        1440  2905.0              540
# ..       ...         ...      ...         ...     ...              ...
# 32  J25-0032           6     2654        2880  4856.0              416
# 33  J25-0033           2     2660        2880  5305.0              568
# 34  J25-0034           8     2715        2880  5271.0              597
# 35  J25-0035           5     2726        2880  4689.0              496
# 36  J25-0036           4     2734        2880  5135.0              393
# 37  J25-0037           7     2801        2880  5046.0              539
#
#     Deadline
# 0       3660
# 2       3744
# 3       3379
# 4       4856
# 5       3106
# 6       3539
# ..       ...
# 32      3881
# 33      6738
# 34      6387
# 35      4126
# 36      5231
# 37      5173
#
# [36 rows x 7 columns]

# %%
df_jssp_current = filter_current_jssp(
    df_jssp = df_jssp,
    df_jobs_times_current = df_jobs_times_current,
    exclusion_dataframes_list = [df_active, df_execution]
)
df_jssp_current
# Out:
#           Job  Routing_ID  Operation Machine  Processing Time
# 8    J25-0000           8          8     M04               26
# 9    J25-0000           8          9     M08               74
# 29   J25-0002           0          9     M09               21
# 39   J25-0003           2          9     M04               33
# 46   J25-0004           3          6     M07               85
# 47   J25-0004           3          7     M03               98
# ..        ...         ...        ...     ...              ...
# 374  J25-0037           7          4     M04               32
# 375  J25-0037           7          5     M06               88
# 376  J25-0037           7          6     M08               19
# 377  J25-0037           7          7     M09               48
# 378  J25-0037           7          8     M07               36
# 379  J25-0037           7          9     M03               79
#
# [238 rows x 5 columns]

# %% [markdown]
# ### A) Neuplanung mit zusätzlich Minimierung der Planabweichung für die zuvor geplante Arbeitsgänge

# %% [markdown]
# $$
# min
# Z = r \cdot \sum_
# {j \ in  \text
# {Jobs}} \left(w_t \cdot \text
# {Tardiness}
# _j + w_e \cdot \text
# {Earliness}
# _j \right) + (1 - r) \cdot \sum_
# {(j, o) \ in  \text
# {DevOps}} \left | \text
# {Start}
# _
# {j, o} - \text
# {Start}
# _
# {j, o} ^ {\text
# {original}} \right |
# $$

# %%
df_schedule_devpen = cp_late_reschedule.solve_jssp_by_tardiness_and_earliness_with_devpen(
    df_jssp_current, df_jobs_times_current, df_active,
    df_original_plan = df_schedule,                     # prev. Plan
    w_t = 5,
    r = 0.60,                                           # 60% Flowtime, 40% Abweichung
    reschedule_start = day_start,
    msg=False, timeLimit=max_time, gapRel= 0.02
)
df_schedule_devpen
# Out:
# Solver-Status         : OPTIMAL
# Objective Value       : 62800.00
# Best Objective Bound  : 62060.00
# Laufzeit              : 0.25 Sekunden
# Deviation terms       : 18
#           Job  Routing_ID  Arrival  Ready Time  Deadline  Operation Machine  \
# 0    J25-0019           9     1925        2880      4621          0     M01
# 1    J25-0031           1     2567        2880      4377          0     M00
# 2    J25-0035           5     2726        2880      4126          0     M02
# 3    J25-0023           8     2055        2880      4676          0     M00
# 4    J25-0031           1     2567        2880      4377          1     M02
# 5    J25-0035           5     2726        2880      4126          1     M01
# ..        ...         ...      ...         ...       ...        ...     ...
# 232  J25-0028           0     2282        2880      5291          9     M09
# 233  J25-0021           5     1952        2880      5368          9     M07
# 234  J25-0027           7     2277        2880      5711          9     M03
# 235  J25-0030           0     2313        2880      6015          9     M09
# 236  J25-0034           8     2715        2880      6387          9     M08
# 237  J25-0033           2     2660        2880      6738          9     M04
#
#      Start  Processing Time   End
# 0     2880               85  2965
# 1     2880               43  2923
# 2     2880               84  2964
# 3     2923               76  2999
# 4     2964               90  3054
# 5     2965                2  2967
# ..     ...              ...   ...
# 232   5270               21  5291
# 233   5343               25  5368
# 234   5632               79  5711
# 235   5994               21  6015
# 236   6313               74  6387
# 237   6705               33  6738
#
# [238 rows x 10 columns]

# %%
df_temp =  df_schedule_devpen

show.plot_gantt_machines(df_temp)
check.is_machine_conflict_free(df_temp)
check.is_operation_sequence_correct(df_temp)
check.is_job_timing_correct(df_temp)
check.is_start_correct(df_temp)
# Out:
# + Keine Maschinenkonflikte gefunden
# + Alle Gruppen wurden in korrekter Operationsreihenfolge ausgeführt.
# + Alle technologischen Abhängigkeiten wurden eingehalten.
# + Alle Operation starten erst nach Arrival des Job
# True

# %% [markdown]
# #### Check der Bedingungen des kombinierten Datensatzes aus den Simulationsdaten mit dem neuen Schedule

# %%
df_reschedule = df_schedule_devpen

columns = ["Job", "Operation", "Machine", "Arrival", "Start", "Processing Time", "End"]
df_combined = pd.concat([df_execution, df_active[columns], df_reschedule[columns]], ignore_index=True)
show.plot_gantt_machines(df_combined)
check.is_machine_conflict_free(df_combined)
check.is_operation_sequence_correct(df_combined)
check.is_job_timing_correct(df_combined)
check.is_start_correct(df_combined)
# Out:
# + Keine Maschinenkonflikte gefunden
# + Alle Gruppen wurden in korrekter Operationsreihenfolge ausgeführt.
# + Alle technologischen Abhängigkeiten wurden eingehalten.
# + Alle Operation starten erst nach Arrival des Job
# True

# %% [markdown]
# ### B) Neuplanung mit zusätzlich Minimierung der Planabweichung für die zuvor geplante Arbeitsgänge & Maximierung des ersten Arbeitsgangen

# %% [markdown]
# $$
# Z = \alpha \cdot \left[
# r \cdot \sum_{j \in \text{Jobs}} \left( w_t \cdot \max(0, C_j - D_j) + w_e \cdot \max(0, D_j - C_j) \right)
# + (1 - r) \cdot \sum_{(j,o) \in \text{DevOps}} \left| S_{j,o} - S_{j,o}^{\text{orig}} \right|
# \right]
# - (1 - \alpha) \cdot \sum_{j \in \text{Jobs}} S_j^{\text{first}}
# $$

# %%
df_schedule_advanced = cp_late_reschedule.solve_jssp_advanced(
    df_jssp_current, df_jobs_times_current, df_active,
    df_original_plan = df_schedule,                     # prev. Plan
    w_t = 5,
    r = 0.60,                                           # 60 % Flowtime, 40 % Abweichung
    alpha= 0.9,                                         # 90 % Haupt-Zielfunktion, 10 % Start des ersten Arbeitsganges
    reschedule_start = day_start,
    msg=False, timeLimit=max_time, gapRel= 0.02
)
df_schedule_advanced

# %%
df_temp =  df_schedule_advanced

show.plot_gantt_machines(df_temp)
check.is_machine_conflict_free(df_temp)
check.is_operation_sequence_correct(df_temp)
check.is_job_timing_correct(df_temp)
check.is_start_correct(df_temp)

# %%
df_reschedule = df_schedule_advanced

columns = ["Job", "Operation", "Machine", "Arrival", "Start", "Processing Time", "End"]
df_combined = pd.concat([df_execution, df_active[columns], df_reschedule[columns]], ignore_index=True)
show.plot_gantt_machines(df_combined)
check.is_machine_conflict_free(df_combined)
check.is_operation_sequence_correct(df_combined)
check.is_job_timing_correct(df_combined)
check.is_start_correct(df_combined)

# %% [markdown]
# ### Simulation

# %%
simulation.run(dframe_schedule_plan = df_schedule_advanced, start_time = day_start, end_time = day_end)
# Out:
# [Day 2 00:00:00] Job J25-0004, Operation 5 resumed with 36.00 min
# [Day 2 00:00:00] Job J25-0000, Operation 7 resumed with 106.00 min
# [Day 2 00:00:00] Job J25-0019 started on M01
# [Day 2 00:00:00] Job J25-0031 started on M00
# [Day 2 00:00:00] Job J25-0035 started on M02
# [Day 2 00:36:00] Job J25-0004 finished on M08 (after 36 minutes)
# [Day 2 00:51:00] Job J25-0031 finished on M00 (after 51 minutes)
# [Day 2 00:51:00] Job J25-0023 started on M00
# [Day 2 01:18:00] Job J25-0035 finished on M02 (after 78 minutes)
# [Day 2 01:23:00] Job J25-0019 finished on M01 (after 83 minutes)
# [Day 2 01:24:00] Job J25-0031 started on M02
# [Day 2 01:25:00] Job J25-0035 started on M01
# [Day 2 01:27:00] Job J25-0035 finished on M01 (after 02 minutes)
# [Day 2 01:27:00] Job J25-0032 started on M01
# [Day 2 01:34:00] Job J25-0035 started on M05
# [Day 2 01:46:00] Job J25-0000 finished on M07 (after 106 minutes)
# [Day 2 01:46:00] Job J25-0000 started on M04
# [Day 2 01:46:00] Job J25-0015 started on M07
# [Day 2 02:06:00] Job J25-0000 finished on M04 (after 20 minutes)
# [Day 2 02:16:00] Job J25-0015 finished on M07 (after 30 minutes)
# [Day 2 02:16:00] Job J25-0007 started on M07
# [Day 2 02:17:00] Job J25-0023 finished on M00 (after 86 minutes)
# [Day 2 02:17:00] Job J25-0019 started on M00
# [Day 2 02:20:00] Job J25-0032 finished on M01 (after 53 minutes)
# [Day 2 02:20:00] Job J25-0026 started on M01
# [Day 2 02:24:00] Job J25-0035 finished on M05 (after 50 minutes)
# [Day 2 02:26:00] Job J25-0035 started on M03
# [Day 2 02:34:00] Job J25-0019 finished on M00 (after 17 minutes)
# [Day 2 02:34:00] Job J25-0018 started on M00
# [Day 2 02:37:00] Job J25-0007 finished on M07 (after 21 minutes)
# [Day 2 02:37:00] Job J25-0004 started on M07
# [Day 2 02:55:00] Job J25-0031 finished on M02 (after 91 minutes)
# [Day 2 02:55:00] Job J25-0029 started on M02
# [Day 2 02:55:00] Job J25-0031 started on M04
# [Day 2 03:06:00] Job J25-0029 finished on M02 (after 11 minutes)
# [Day 2 03:08:00] Job J25-0019 started on M02
# [Day 2 03:14:00] Job J25-0026 finished on M01 (after 54 minutes)
# [Day 2 03:14:00] Job J25-0016 started on M01
# [Day 2 03:16:00] Job J25-0005 started on M08
# [Day 2 03:40:00] Job J25-0005 finished on M08 (after 24 minutes)
# [Day 2 03:43:00] Job J25-0035 finished on M03 (after 77 minutes)
# [Day 2 03:48:00] Job J25-0004 finished on M07 (after 71 minutes)
# [Day 2 03:59:00] Job J25-0018 finished on M00 (after 85 minutes)
# [Day 2 03:59:00] Job J25-0032 started on M00
# [Day 2 04:01:00] Job J25-0035 started on M08
# [Day 2 04:01:00] Job J25-0004 started on M03
# [Day 2 04:04:00] Job J25-0019 finished on M02 (after 56 minutes)
# [Day 2 04:09:00] Job J25-0017 started on M02
# [Day 2 04:09:00] Job J25-0019 started on M06
# [Day 2 04:11:00] Job J25-0031 finished on M04 (after 76 minutes)
# [Day 2 04:11:00] Job J25-0031 started on M09
# [Day 2 04:15:00] Job J25-0016 finished on M01 (after 61 minutes)
# [Day 2 04:15:00] Job J25-0019 finished on M06 (after 06 minutes)
# [Day 2 04:15:00] Job J25-0024 started on M01
# [Day 2 04:20:00] Job J25-0031 finished on M09 (after 09 minutes)
# [Day 2 04:38:00] Job J25-0032 finished on M00 (after 39 minutes)
# [Day 2 04:38:00] Job J25-0016 started on M00
# [Day 2 04:43:00] Job J25-0017 finished on M02 (after 34 minutes)
# [Day 2 04:43:00] Job J25-0037 started on M02
# [Day 2 04:47:00] Job J25-0035 finished on M08 (after 46 minutes)
# [Day 2 05:00:00] Job J25-0011 started on M08
# [Day 2 05:07:00] Job J25-0016 finished on M00 (after 29 minutes)
# [Day 2 05:07:00] Job J25-0026 started on M00
# [Day 2 05:14:00] Job J25-0037 finished on M02 (after 31 minutes)
# [Day 2 05:18:00] Job J25-0004 finished on M03 (after 77 minutes)
# [Day 2 05:31:00] Job J25-0024 finished on M01 (after 76 minutes)
# [Day 2 05:31:00] Job J25-0025 started on M01
# [Day 2 05:31:00] Job J25-0024 started on M02
# [Day 2 05:36:00] Job J25-0011 finished on M08 (after 36 minutes)
# [Day 2 05:36:00] Job J25-0019 started on M08
# [Day 2 05:39:00] Job J25-0032 started on M03
# [Day 2 05:39:00] Job J25-0004 started on M09
# [Day 2 05:44:00] Job J25-0026 finished on M00 (after 37 minutes)
# [Day 2 05:44:00] Job J25-0029 started on M00
# [Day 2 05:50:00] Job J25-0029 finished on M00 (after 06 minutes)
# [Day 2 05:50:00] Job J25-0030 started on M00
# [Day 2 05:58:00] Job J25-0004 finished on M09 (after 19 minutes)
# [Day 2 06:01:00] Job J25-0035 started on M09
# [Day 2 06:22:00] Job J25-0014 started on M06
# [Day 2 06:23:00] Job J25-0030 finished on M00 (after 33 minutes)
# [Day 2 06:23:00] Job J25-0020 started on M00
# [Day 2 06:32:00] Job J25-0025 finished on M01 (after 61 minutes)
# [Day 2 06:37:00] Job J25-0032 finished on M03 (after 58 minutes)
# [Day 2 06:37:00] Job J25-0022 started on M01
# [Day 2 06:40:00] Job J25-0026 started on M03
# [Day 2 06:49:00] Job J25-0019 finished on M08 (after 73 minutes)
# [Day 2 06:51:00] Job J25-0024 finished on M02 (after 80 minutes)
# [Day 2 06:51:00] Job J25-0032 started on M02
# [Day 2 06:59:00] Job J25-0014 finished on M06 (after 37 minutes)
# [Day 2 07:02:00] Job J25-0020 finished on M00 (after 39 minutes)
# [Day 2 07:02:00] Job J25-0024 started on M00
# [Day 2 07:05:00] Job J25-0032 finished on M02 (after 14 minutes)
# [Day 2 07:05:00] Job J25-0020 started on M02
# [Day 2 07:15:00] Job J25-0032 started on M06
# [Day 2 07:18:00] Job J25-0035 finished on M09 (after 77 minutes)
# [Day 2 07:24:00] Job J25-0010 started on M09
# [Day 2 07:46:00] Job J25-0003 started on M04
# [Day 2 07:49:00] Job J25-0032 finished on M06 (after 34 minutes)
# [Day 2 07:49:00] Job J25-0032 started on M05
# [Day 2 07:50:00] Job J25-0010 finished on M09 (after 26 minutes)
# [Day 2 07:50:00] Job J25-0019 started on M09
# [Day 2 07:59:00] Job J25-0026 finished on M03 (after 79 minutes)
# [Day 2 07:59:00] Job J25-0031 started on M03
# [Day 2 08:15:00] Job J25-0032 finished on M05 (after 26 minutes)
# [Day 2 08:18:00] Job J25-0003 finished on M04 (after 32 minutes)
# [Day 2 08:20:00] Job J25-0022 finished on M01 (after 103 minutes)
# [Day 2 08:20:00] Job J25-0023 started on M01
# [Day 2 08:21:00] Job J25-0024 finished on M00 (after 79 minutes)
# [Day 2 08:21:00] Job J25-0025 started on M00
# [Day 2 08:21:00] Job J25-0024 started on M04
# [Day 2 08:26:00] Job J25-0020 finished on M02 (after 81 minutes)
# [Day 2 08:29:00] Job J25-0026 started on M02
# [Day 2 08:48:00] Job J25-0026 finished on M02 (after 19 minutes)
# [Day 2 08:48:00] Job J25-0036 started on M02
# [Day 2 08:48:00] Job J25-0026 started on M06
# [Day 2 09:03:00] Job J25-0036 finished on M02 (after 15 minutes)
# [Day 2 09:03:00] Job J25-0027 started on M02
# [Day 2 09:13:00] Job J25-0026 finished on M06 (after 25 minutes)
# [Day 2 09:15:00] Job J25-0019 finished on M09 (after 85 minutes)
# [Day 2 09:15:00] Job J25-0032 started on M09
# [Day 2 09:15:00] Job J25-0019 started on M05
# [Day 2 09:16:00] Job J25-0031 finished on M03 (after 77 minutes)
# [Day 2 09:16:00] Job J25-0016 started on M03
# [Day 2 09:36:00] Job J25-0027 finished on M02 (after 33 minutes)
# [Day 2 09:39:00] Job J25-0023 finished on M01 (after 79 minutes)
# [Day 2 09:39:00] Job J25-0029 started on M01
# [Day 2 09:42:00] Job J25-0025 finished on M00 (after 81 minutes)
# [Day 2 09:42:00] Job J25-0022 started on M00
# [Day 2 09:50:00] Job J25-0032 finished on M09 (after 35 minutes)
# [Day 2 09:50:00] Job J25-0032 started on M08
# [Day 2 09:57:00] Job J25-0022 finished on M00 (after 15 minutes)
# [Day 2 09:57:00] Job J25-0017 started on M00
# [Day 2 09:57:00] Job J25-0022 started on M02
# [Day 2 09:58:00] Job J25-0024 finished on M04 (after 97 minutes)
# [Day 2 09:58:00] Job J25-0020 started on M04
# [Day 2 09:58:00] Job J25-0024 started on M06
# [Day 2 09:59:00] Job J25-0029 finished on M01 (after 20 minutes)
# [Day 2 09:59:00] Job J25-0018 started on M01
# [Day 2 10:08:00] Job J25-0019 finished on M05 (after 53 minutes)
# [Day 2 10:08:00] Job J25-0026 started on M05
# [Day 2 10:09:00] Job J25-0024 finished on M06 (after 11 minutes)
# [Day 2 10:09:00] Job J25-0008 started on M06
# [Day 2 10:14:00] Job J25-0006 started on M07
# [Day 2 10:17:00] Job J25-0016 finished on M03 (after 61 minutes)
# [Day 2 10:19:00] Job J25-0009 started on M03
# [Day 2 10:35:00] Job J25-0026 finished on M05 (after 27 minutes)
# [Day 2 10:35:00] Job J25-0029 started on M05
# [Day 2 10:35:00] Job J25-0026 started on M09
# [Day 2 10:56:00] Job J25-0006 finished on M07 (after 42 minutes)
# [Day 2 11:06:00] Job J25-0026 finished on M09 (after 31 minutes)
# [Day 2 11:07:00] Job J25-0032 finished on M08 (after 77 minutes)
# [Day 2 11:07:00] Job J25-0032 started on M07
# [Day 2 11:08:00] Job J25-0008 finished on M06 (after 59 minutes)
# [Day 2 11:15:00] Job J25-0022 finished on M02 (after 78 minutes)
# [Day 2 11:15:00] Job J25-0018 finished on M01 (after 76 minutes)
# [Day 2 11:15:00] Job J25-0021 started on M02
# [Day 2 11:15:00] Job J25-0022 started on M06
# [Day 2 11:15:00] Job J25-0031 started on M01
# [Day 2 11:22:00] Job J25-0020 finished on M04 (after 84 minutes)
# [Day 2 11:22:00] Job J25-0020 started on M09
# [Day 2 11:23:00] Job J25-0022 finished on M06 (after 08 minutes)
# [Day 2 11:32:00] Job J25-0020 finished on M09 (after 10 minutes)
# [Day 2 11:34:00] Job J25-0029 finished on M05 (after 59 minutes)
# [Day 2 11:35:00] Job J25-0017 finished on M00 (after 98 minutes)
# [Day 2 11:35:00] Job J25-0037 started on M00
# [Day 2 11:40:00] Job J25-0031 finished on M01 (after 25 minutes)
# [Day 2 11:40:00] Job J25-0031 started on M06
# [Day 2 11:46:00] Job J25-0000 started on M08
# [Day 2 11:47:00] Job J25-0032 finished on M07 (after 40 minutes)
# [Day 2 11:48:00] Job J25-0017 started on M01
# [Day 2 11:53:00] Job J25-0009 finished on M03 (after 94 minutes)
# [Day 2 11:53:00] Job J25-0018 started on M03
# [Day 2 12:24:00] Job J25-0031 finished on M06 (after 44 minutes)
# [Day 2 12:24:00] Job J25-0031 started on M05
# [Day 2 12:27:00] Job J25-0021 finished on M02 (after 72 minutes)
# [Day 2 12:27:00] Job J25-0016 started on M02
# [Day 2 12:28:00] Job J25-0017 finished on M01 (after 40 minutes)
# [Day 2 12:36:00] Job J25-0016 finished on M02 (after 09 minutes)
# [Day 2 12:36:00] Job J25-0016 started on M06
# [Day 2 13:02:00] Job J25-0000 finished on M08 (after 76 minutes)
# [Day 2 13:02:00] Job J25-0026 started on M08
# [Day 2 13:07:00] Job J25-0016 finished on M06 (after 31 minutes)
# [Day 2 13:12:00] Job J25-0031 finished on M05 (after 48 minutes)
# [Day 2 13:12:00] Job J25-0017 started on M05
# [Day 2 13:12:00] Job J25-0031 started on M07
# [Day 2 13:20:00] Job J25-0037 finished on M00 (after 105 minutes)
# [Day 2 13:20:00] Job J25-0021 started on M01
# [Day 2 13:20:00] Job J25-0035 started on M00
# [Day 2 13:22:00] Job J25-0018 finished on M03 (after 89 minutes)
# [Day 2 13:22:00] Job J25-0021 finished on M01 (after 02 minutes)
# [Day 2 13:22:00] Job J25-0025 started on M03
# [Day 2 13:22:00] Job J25-0037 started on M01
# [Day 2 13:56:00] Job J25-0035 finished on M00 (after 36 minutes)
# [Day 2 13:56:00] Job J25-0036 started on M00
# [Day 2 13:56:00] Job J25-0035 started on M06
# [Day 2 13:58:00] Job J25-0025 finished on M03 (after 36 minutes)
# [Day 2 13:58:00] Job J25-0023 started on M03
# [Day 2 13:58:00] Job J25-0025 started on M02
# [Day 2 14:03:00] Job J25-0002 started on M09
# [Day 2 14:04:00] Job J25-0036 finished on M00 (after 08 minutes)
# [Day 2 14:04:00] Job J25-0028 started on M00
# [Day 2 14:09:00] Job J25-0037 finished on M01 (after 47 minutes)
# [Day 2 14:09:00] Job J25-0030 started on M01
# [Day 2 14:12:00] Job J25-0017 finished on M05 (after 60 minutes)
# [Day 2 14:12:00] Job J25-0018 started on M05
# [Day 2 14:12:00] Job J25-0017 started on M04
# [Day 2 14:22:00] Job J25-0002 finished on M09 (after 19 minutes)
# [Day 2 14:29:00] Job J25-0028 finished on M00 (after 25 minutes)
# [Day 2 14:29:00] Job J25-0027 started on M00
# [Day 2 14:35:00] Job J25-0031 finished on M07 (after 83 minutes)
# [Day 2 14:38:00] Job J25-0026 finished on M08 (after 96 minutes)
# [Day 2 14:38:00] Job J25-0022 started on M08
# [Day 2 14:38:00] Job J25-0026 started on M07
# [Day 2 14:49:00] Job J25-0017 finished on M04 (after 37 minutes)
# [Day 2 15:06:00] Job J25-0018 finished on M05 (after 54 minutes)
# [Day 2 15:06:00] Job J25-0016 started on M05
# [Day 2 15:08:00] Job J25-0026 finished on M07 (after 30 minutes)
# [Day 2 15:11:00] Job J25-0035 finished on M06 (after 75 minutes)
# [Day 2 15:11:00] Job J25-0017 started on M06
# [Day 2 15:11:00] Job J25-0035 started on M04
# [Day 2 15:15:00] Job J25-0023 finished on M03 (after 77 minutes)
# [Day 2 15:15:00] Job J25-0019 started on M03
# [Day 2 15:16:00] Job J25-0025 finished on M02 (after 78 minutes)
# [Day 2 15:17:00] Job J25-0035 finished on M04 (after 06 minutes)
# [Day 2 15:31:00] Job J25-0016 finished on M05 (after 25 minutes)
# [Day 2 15:31:00] Job J25-0023 started on M05
# [Day 2 15:31:00] Job J25-0016 started on M09
# [Day 2 15:35:00] Job J25-0030 finished on M01 (after 86 minutes)
# [Day 2 15:35:00] Job J25-0036 started on M01
# [Day 2 15:35:00] Job J25-0030 started on M02
# [Day 2 15:41:00] Job J25-0030 finished on M02 (after 06 minutes)
# [Day 2 15:46:00] Job J25-0022 finished on M08 (after 68 minutes)
# [Day 2 15:46:00] Job J25-0032 started on M04
# [Day 2 15:46:00] Job J25-0025 started on M08
# [Day 2 15:57:00] Job J25-0027 finished on M00 (after 88 minutes)
# [Day 2 15:57:00] Job J25-0034 started on M00
# [Day 2 15:58:00] Job J25-0036 finished on M01 (after 23 minutes)
# [Day 2 15:58:00] Job J25-0028 started on M01
# [Day 2 16:03:00] Job J25-0016 finished on M09 (after 32 minutes)
# [Day 2 16:03:00] Job J25-0022 started on M09
# [Day 2 16:08:00] Job J25-0019 finished on M03 (after 53 minutes)
# [Day 2 16:08:00] Job J25-0029 started on M03
# [Day 2 16:21:00] Job J25-0023 finished on M05 (after 50 minutes)
# [Day 2 16:21:00] Job J25-0036 started on M05
# [Day 2 16:29:00] Job J25-0029 finished on M03 (after 21 minutes)
# [Day 2 16:29:00] Job J25-0030 started on M03
# [Day 2 16:31:00] Job J25-0017 finished on M06 (after 80 minutes)
# [Day 2 16:34:00] Job J25-0032 finished on M04 (after 48 minutes)
# [Day 2 16:41:00] Job J25-0029 started on M04
# [Day 2 17:02:00] Job J25-0030 finished on M03 (after 33 minutes)
# [Day 2 17:02:00] Job J25-0020 started on M03
# [Day 2 17:08:00] Job J25-0018 started on M02
# [Day 2 17:12:00] Job J25-0036 finished on M05 (after 51 minutes)
# [Day 2 17:13:00] Job J25-0028 finished on M01 (after 75 minutes)
# [Day 2 17:13:00] Job J25-0027 started on M01
# [Day 2 17:25:00] Job J25-0034 finished on M00 (after 88 minutes)
# [Day 2 17:27:00] Job J25-0025 finished on M08 (after 101 minutes)
# [Day 2 17:27:00] Job J25-0022 finished on M09 (after 84 minutes)
# [Day 2 17:27:00] Job J25-0016 started on M08
# [Day 2 17:27:00] Job J25-0025 started on M05
# [Day 2 17:39:00] Job J25-0029 finished on M04 (after 58 minutes)
# [Day 2 17:39:00] Job J25-0025 finished on M05 (after 12 minutes)
# [Day 2 17:39:00] Job J25-0025 started on M07
# [Day 2 17:42:00] Job J25-0037 started on M05
# [Day 2 17:48:00] Job J25-0025 finished on M07 (after 09 minutes)
# [Day 2 17:48:00] Job J25-0025 started on M06
# [Day 2 17:50:00] Job J25-0019 started on M04
# [Day 2 18:03:00] Job J25-0027 finished on M01 (after 50 minutes)
# [Day 2 18:03:00] Job J25-0034 started on M01
# [Day 2 18:18:00] Job J25-0018 finished on M02 (after 70 minutes)
# [Day 2 18:18:00] Job J25-0028 started on M02
# [Day 2 18:24:00] Job J25-0020 finished on M03 (after 82 minutes)
# [Day 2 18:24:00] Job J25-0036 started on M03
# [Day 2 18:27:00] Job J25-0028 finished on M02 (after 09 minutes)
# [Day 2 18:33:00] Job J25-0023 started on M02
# [Day 2 18:33:00] Job J25-0018 started on M09
# [Day 2 18:47:00] Job J25-0018 finished on M09 (after 14 minutes)
# [Day 2 18:52:00] Job J25-0036 finished on M03 (after 28 minutes)
# [Day 2 18:52:00] Job J25-0028 started on M03
# [Day 2 18:53:00] Job J25-0037 finished on M05 (after 71 minutes)
# [Day 2 18:56:00] Job J25-0022 started on M05
# [Day 2 18:59:00] Job J25-0034 finished on M01 (after 56 minutes)
# [Day 2 18:59:00] Job J25-0020 started on M01
# [Day 2 19:03:00] Job J25-0019 finished on M04 (after 73 minutes)
# [Day 2 19:10:00] Job J25-0016 finished on M08 (after 103 minutes)
# [Day 2 19:10:00] Job J25-0024 started on M08
# [Day 2 19:10:00] Job J25-0016 started on M07
# [Day 2 19:20:00] Job J25-0030 started on M04
# [Day 2 19:25:00] Job J25-0020 finished on M01 (after 26 minutes)
# [Day 2 19:25:00] Job J25-0033 started on M01
# [Day 2 19:26:00] Job J25-0025 finished on M06 (after 98 minutes)
# [Day 2 19:26:00] Job J25-0018 started on M06
# [Day 2 19:26:00] Job J25-0025 started on M09
# [Day 2 19:27:00] Job J25-0028 finished on M03 (after 35 minutes)
# [Day 2 19:27:00] Job J25-0034 started on M03
# [Day 2 19:38:00] Job J25-0023 finished on M02 (after 65 minutes)
# [Day 2 19:39:00] Job J25-0016 finished on M07 (after 29 minutes)
# [Day 2 20:00:00] Job J25-0022 finished on M05 (after 64 minutes)
# [Day 2 20:00:00] Job J25-0027 started on M05
# [Day 2 20:04:00] Job J25-0018 finished on M06 (after 38 minutes)
# [Day 2 20:04:00] Job J25-0020 started on M06
# [Day 2 20:09:00] Job J25-0025 finished on M09 (after 43 minutes)
# [Day 2 20:09:00] Job J25-0023 started on M09
# [Day 2 20:10:00] Job J25-0030 finished on M04 (after 50 minutes)
# [Day 2 20:16:00] Job J25-0024 finished on M08 (after 66 minutes)
# [Day 2 20:16:00] Job J25-0029 started on M08
# [Day 2 20:21:00] Job J25-0023 finished on M09 (after 12 minutes)
# [Day 2 20:21:00] Job J25-0035 started on M07
# [Day 2 20:38:00] Job J25-0034 finished on M03 (after 71 minutes)
# [Day 2 20:38:00] Job J25-0022 started on M03
# [Day 2 20:39:00] Job J25-0037 started on M04
# [Day 2 20:41:00] Job J25-0035 finished on M07 (after 20 minutes)
# [Day 2 20:46:00] Job J25-0018 started on M07
# [Day 2 20:48:00] Job J25-0029 finished on M08 (after 32 minutes)
# [Day 2 20:48:00] Job J25-0017 started on M08
# [Day 2 20:57:00] Job J25-0020 finished on M06 (after 53 minutes)
# [Day 2 20:57:00] Job J25-0023 started on M06
# [Day 2 21:06:00] Job J25-0017 finished on M08 (after 18 minutes)
# [Day 2 21:06:00] Job J25-0017 started on M09
# [Day 2 21:12:00] Job J25-0037 finished on M04 (after 33 minutes)
# [Day 2 21:13:00] Job J25-0027 finished on M05 (after 73 minutes)
# [Day 2 21:13:00] Job J25-0030 started on M05
# [Day 2 21:20:00] Job J25-0033 finished on M01 (after 115 minutes)
# [Day 2 21:20:00] Job J25-0033 started on M00
# [Day 2 21:28:00] Job J25-0030 finished on M05 (after 15 minutes)
# [Day 2 21:28:00] Job J25-0020 started on M05
# [Day 2 21:34:00] Job J25-0022 finished on M03 (after 56 minutes)
# [Day 2 21:34:00] Job J25-0022 started on M04
# [Day 2 21:40:00] Job J25-0023 finished on M06 (after 43 minutes)
# [Day 2 21:40:00] Job J25-0037 started on M06
# [Day 2 21:50:00] Job J25-0017 finished on M09 (after 44 minutes)
# [Day 2 22:01:00] Job J25-0018 finished on M07 (after 75 minutes)
# [Day 2 22:15:00] Job J25-0023 started on M07
# [Day 2 22:21:00] Job J25-0020 finished on M05 (after 53 minutes)
# [Day 2 22:21:00] Job J25-0021 started on M05
# [Day 2 22:38:00] Job J25-0033 finished on M00 (after 78 minutes)
# [Day 2 22:38:00] Job J25-0033 started on M03
# [Day 2 23:12:00] Job J25-0037 finished on M06 (after 92 minutes)
# [Day 2 23:12:00] Job J25-0030 started on M06
# [Day 2 23:12:00] Job J25-0037 started on M08
# [Day 2 23:20:00] Job J25-0022 finished on M04 (after 106 minutes)
# [Day 2 23:20:00] Job J25-0018 started on M04
# [Day 2 23:22:00] Job J25-0033 finished on M03 (after 44 minutes)
# [Day 2 23:22:00] Job J25-0033 started on M02
# [Day 2 23:24:00] Job J25-0021 finished on M05 (after 63 minutes)
# [Day 2 23:24:00] Job J25-0034 started on M05
# [Day 2 23:24:00] Job J25-0021 started on M03
# [Day 2 23:33:00] Job J25-0037 finished on M08 (after 21 minutes)
# [Day 2 23:33:00] Job J25-0037 started on M09
# [Day 2 23:47:00] Job J25-0018 finished on M04 (after 27 minutes)
# [Day 2 23:47:00] Job J25-0028 started on M04
# [Day 2 23:58:00] Job J25-0023 finished on M07 (after 103 minutes)
# [Day 2 23:58:00] Job J25-0024 started on M07

# %%
df_execution2 = simulation.get_finished_operations_df()
df_execution2
# Out:
#           Job  Operation Machine  Arrival   Start  Processing Time     End  \
# 0    J25-0000          7     M07       79  2876.0            110.0  2986.0
# 1    J25-0000          8     M04       79  2986.0             20.0  3006.0
# 2    J25-0000          9     M08       79  3586.0             76.0  3662.0
# 3    J25-0002          9     M09      198  3723.0             19.0  3742.0
# 4    J25-0003          9     M04      243  3346.0             32.0  3378.0
# 5    J25-0004          5     M08      287  2865.0             51.0  2916.0
# ..        ...        ...     ...      ...     ...              ...     ...
# 167  J25-0037          1     M00     2801  3575.0            105.0  3680.0
# 168  J25-0037          2     M01     2801  3682.0             47.0  3729.0
# 169  J25-0037          3     M05     2801  3942.0             71.0  4013.0
# 170  J25-0037          4     M04     2801  4119.0             33.0  4152.0
# 171  J25-0037          5     M06     2801  4180.0             92.0  4272.0
# 172  J25-0037          6     M08     2801  4272.0             21.0  4293.0
#
#      Routing_ID
# 0           NaN
# 1           8.0
# 2           8.0
# 3           0.0
# 4           2.0
# 5           NaN
# ..          ...
# 167         7.0
# 168         7.0
# 169         7.0
# 170         7.0
# 171         7.0
# 172         7.0
#
# [173 rows x 8 columns]

# %%
show.plot_gantt(df_execution2, perspective="Machine")

# %%
df_active2 = simulation.get_active_operations_df()
df_active2
# Out:
#         Job  Operation Machine  Arrival   Start  Planned Duration  \
# 0  J25-0021          3     M03     1952  4284.0                95
# 1  J25-0024          6     M07     2108  4318.0                85
# 2  J25-0028          4     M04     2282  4307.0                49
# 3  J25-0030          6     M06     2313  4272.0                62
# 4  J25-0033          3     M02     2660  4282.0                74
# 5  J25-0034          3     M05     2715  4284.0                51
# 6  J25-0037          7     M09     2801  4293.0                48
#
#    Processing Time  Expected End     End
# 0             72.0        4379.0  4356.0
# 1            101.0        4403.0  4419.0
# 2             49.0        4356.0  4356.0
# 3             48.0        4334.0  4320.0
# 4             60.0        4356.0  4342.0
# 5             47.0        4335.0  4331.0
# 6             46.0        4341.0  4339.0

# %%
df_not_started2 = simulation.get_not_started_operations_df(df_schedule)
df_not_started2
# Out:
#           Job  Routing_ID  Arrival  Ready Time  Deadline  Operation Machine  \
# 0    J25-0000           8       79        1440      3660          0     M00
# 1    J25-0000           8       79        1440      3660          1     M01
# 2    J25-0000           8       79        1440      3660          2     M03
# 3    J25-0000           8       79        1440      3660          3     M05
# 4    J25-0000           8       79        1440      3660          4     M02
# 5    J25-0000           8       79        1440      3660          5     M09
# ..        ...         ...      ...         ...       ...        ...     ...
# 136  J25-0015           5     1436        1440      2981          3     M03
# 137  J25-0015           5     1436        1440      2981          4     M08
# 138  J25-0015           5     1436        1440      2981          5     M09
# 139  J25-0015           5     1436        1440      2981          6     M00
# 140  J25-0015           5     1436        1440      2981          7     M06
# 141  J25-0015           5     1436        1440      2981          8     M04
#
#      Start  Processing Time   End
# 0     1555               76  1631
# 1     1825               69  1894
# 2     2231               76  2307
# 3     2422               51  2473
# 4     2473               85  2558
# 5     2630               11  2641
# ..     ...              ...   ...
# 136   1799               95  1894
# 137   1988               48  2036
# 138   2036               72  2108
# 139   2110               47  2157
# 140   2157               65  2222
# 141   2254                6  2260
#
# [142 rows x 10 columns]

# %% [markdown]
# #### Check der Bedingungen des kombinierten Datensatzes aus den beiden Simulationsdaten

# %%
df_combined = pd.concat([df_execution, df_execution2], ignore_index=True)
show.plot_gantt_machines(df_combined)
check.is_machine_conflict_free(df_combined)
check.is_operation_sequence_correct(df_combined)
check.is_job_timing_correct(df_combined)
check.is_start_correct(df_combined)
# Out:
# + Keine Maschinenkonflikte gefunden
# + Alle Gruppen wurden in korrekter Operationsreihenfolge ausgeführt.
# + Alle technologischen Abhängigkeiten wurden eingehalten.
# + Alle Operation starten erst nach Arrival des Job
# True
