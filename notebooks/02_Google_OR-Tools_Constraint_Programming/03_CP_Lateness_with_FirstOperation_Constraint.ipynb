# %% [markdown]
# # Minimierung der Lateness jedes Produktionsauftrags

# %% [markdown]
# $$
# L_j = C_j - d_j
# $$
#
#
# - $L_j$: Lateness (Verspätung oder Frühfertigung) des Jobs $j$
# - $C_j$: tatsächliche Fertigstellungszeit (Completion Time) von Job $j$
# - $d_j$: Deadline bzw. geplanter Fertigstellungstermin von Job $j$
#
# **Interpretation:**
#
# - $L_j > 0$: Job ist **verspätet**
# - $L_j = 0$: Job ist **pünktlich**
# - $L_j < 0$: Job ist **zu früh** fertig

# %%
# Datenzugriff
from configs.path_manager import get_path

# Utils
from src.utils.rolling_process.rolling_filter import *
import src.utils.visualization.gantt_diagram as gantt
from src.utils.analysis_basics import check_constrains as check


# Solver Model
from src.models.cp import lateness_scheduling as cp_late_schedule
from src.models.cp import lateness_rescheduling as cp_late_reschedule

# Simulation
from src.simulation.ProductionRollingSimulation import ProductionSimulation

# Extern
import pandas as pd

pd.set_option('display.min_rows', 12)
pd.set_option('display.max_rows', 16)

# %%
# Harte Abbruchbedingung für die Scheduler
max_time = 60*30     # 30 min

# Simulation
simulation = ProductionSimulation(sigma = 0.15)

# %% [markdown]
# ## I. Laden des fertigen Job-Shop Scheduling Problems und der dazugehörigen Produktionsauftragsinformationen

# %%
basic_data_path = get_path("data", "basic")
df_jssp = pd.read_csv(basic_data_path / "jssp_final.csv")
df_jssp
# Out:
#             Job  Routing_ID  Operation Machine  Processing Time
# 0      J25-0000           8          0     M00               76
# 1      J25-0000           8          1     M01               69
# 2      J25-0000           8          2     M03               76
# 3      J25-0000           8          3     M05               51
# 4      J25-0000           8          4     M02               85
# 5      J25-0000           8          5     M09               11
# ...         ...         ...        ...     ...              ...
# 72494  J25-7249           4          4     M03               26
# 72495  J25-7249           4          5     M04               69
# 72496  J25-7249           4          6     M08               21
# 72497  J25-7249           4          7     M07               49
# 72498  J25-7249           4          8     M09               72
# 72499  J25-7249           4          9     M06               53
#
# [72500 rows x 5 columns]

# %%
df_jobs_times = pd.read_csv(basic_data_path / "jobs_times_final.csv")
df_jobs_times
# Out:
#            Job  Routing_ID  Arrival  Ready Time       End  \
# 0     J25-0000           8       79        1440    2704.0
# 1     J25-0001           6      129        1440    2336.0
# 2     J25-0002           0      198        1440    2925.0
# 3     J25-0003           2      243        1440    2801.0
# 4     J25-0004           3      287        1440    2697.0
# 5     J25-0005           1      498        1440    2630.0
# ...        ...         ...      ...         ...       ...
# 7244  J25-7244           3   518085      518400  520251.0
# 7245  J25-7245           9   518089      518400  520296.0
# 7246  J25-7246           6   518116      518400  520027.0
# 7247  J25-7247           1   518184      518400  520040.0
# 7248  J25-7248           0   518188      518400  520417.0
# 7249  J25-7249           4   518302      518400  520333.0
#
#       Job Processing Time  Deadline
# 0                     597      3660
# 1                     416      2338
# 2                     395      3744
# 3                     568      3379
# 4                     655      4856
# 5                     510      3106
# ...                   ...       ...
# 7244                  655    520389
# 7245                  540    519640
# 7246                  416    520157
# 7247                  510    520172
# 7248                  395    520490
# 7249                  393    522163
#
# [7250 rows x 7 columns]

# %% [markdown]
# ## Tag 1
# - Am Tag 0 kommen die ersten Produktionsaufträge an, somit kann noch nichts geplant werden
# - Am Tag 1 findet die initiale Planung statt

# %%
day_length = 1440

day_numb = 1
day_start = day_length*day_numb
day_end = day_start + day_length
print(f"Tag {day_numb:02d}: [{day_start}, {day_end})")
# Out:
# Tag 01: [1440, 2880)

# %%
# "neue" und unerledigte Jobs
df_jobs_times_current = get_current_jobs(
    df_jobs_times, df_previous_not_started = None, ready_time=day_start
)
df_jobs_times_current
# Out:
#          Job  Routing_ID  Arrival  Ready Time     End  Job Processing Time  \
# 0   J25-0000           8       79        1440  2704.0                  597
# 1   J25-0001           6      129        1440  2336.0                  416
# 2   J25-0002           0      198        1440  2925.0                  395
# 3   J25-0003           2      243        1440  2801.0                  568
# 4   J25-0004           3      287        1440  2697.0                  655
# 5   J25-0005           1      498        1440  2630.0                  510
# 6   J25-0006           9      790        1440  2905.0                  540
# 7   J25-0007           5      925        1440  2930.0                  496
# 8   J25-0008           4      988        1440  2986.0                  393
# 9   J25-0009           7     1004        1440  3045.0                  539
# 10  J25-0010           0     1025        1440  3087.0                  395
# 11  J25-0011           1     1030        1440  2773.0                  510
# 12  J25-0012           2     1103        1440  3011.0                  568
# 13  J25-0013           3     1192        1440  2834.0                  655
# 14  J25-0014           4     1222        1440  3212.0                  393
# 15  J25-0015           5     1436        1440  3096.0                  496
#
#     Deadline
# 0       3660
# 1       2338
# 2       3744
# 3       3379
# 4       4856
# 5       3106
# 6       3539
# 7       2929
# 8       3541
# 9       3578
# 10      3345
# 11      3210
# 12      4385
# 13      2567
# 14      3315
# 15      2981

# %%
df_jssp_current = filter_current_jssp(df_jssp, df_jobs_times_current)
df_jssp_current
# Out:
#           Job  Routing_ID  Operation Machine  Processing Time
# 0    J25-0000           8          0     M00               76
# 1    J25-0000           8          1     M01               69
# 2    J25-0000           8          2     M03               76
# 3    J25-0000           8          3     M05               51
# 4    J25-0000           8          4     M02               85
# 5    J25-0000           8          5     M09               11
# ..        ...         ...        ...     ...              ...
# 154  J25-0015           5          4     M08               48
# 155  J25-0015           5          5     M09               72
# 156  J25-0015           5          6     M00               47
# 157  J25-0015           5          7     M06               65
# 158  J25-0015           5          8     M04                6
# 159  J25-0015           5          9     M07               25
#
# [160 rows x 5 columns]

# %% [markdown]
# ### Scheduling

# %% [markdown]
# #### Summe der Lateness (gewichtete Tardiness und Earliness) minimieren

# %% [markdown]
# ### Zielfunktion
#
# $$
# \min \sum_{j \in J} \left( w_t \cdot \max(C_j - d_j,\ 0) + w_e \cdot \max(d_j - C_j,\ 0) \right)
# $$
#
#
# - $J$: Menge aller Jobs
# - $C_j$: tatsächliche Endzeit (Completion Time) des letzten Arbeitsschritts von Job $j$
# - $d_j$: Deadline (Soll-Endzeitpunkt) von Job $j$
# - $w_t$: Gewichtung der **Tardiness** (Verspätung)
# - $w_e$: Gewichtung der **Earliness** (Frühfertigkeit)
# - $\max(C_j - d_j,\ 0)$: positive Verspätung
# - $\max(d_j - C_j,\ 0)$: positive Frühfertigkeit
#
# ### Erklärung
#
# Diese Zielfunktion minimiert die gewichtete Summe aus **Tardiness** (Verspätung) und **Earliness** (Frühfertigkeit) aller Jobs.
# Dabei wird jede Abweichung zur Deadline einzeln bewertet:
#
# - **Tardiness** wird mit $w_t$ gewichtet und tritt auf, wenn ein Job **nach** seiner Deadline fertig wird.
# - **Earliness** wird mit $w_e$ gewichtet und tritt auf, wenn ein Job **vor** seiner Deadline fertig wird.
#
# Durch die Wahl von $w_t \gg w_e$ kannst du **Verspätungen deutlich stärker bestrafen** als Frühfertigkeiten.

# %%
# Scheduling
df_schedule = cp_late_schedule.solve_jssp_sum_by_tardiness_and_earliness(
    df_jssp_current, df_jobs_times_current, earliest_start_column = "Ready Time", w_t= 5,
    msg=False, timeLimit=max_time, gapRel=0.01)
df_schedule
# Out:
# Solver-Status         : OPTIMAL
# Objective Value       : 0.00
# Best Objective Bound  : 0.00
# Laufzeit              : 0.03 Sekunden
#           Job  Routing_ID  Arrival  Ready Time  Deadline  Operation Machine  \
# 0    J25-0005           1      498        1440      3106          0     M00
# 1    J25-0007           5      925        1440      2929          0     M02
# 2    J25-0013           3     1192        1440      2567          0     M01
# 3    J25-0011           1     1030        1440      3210          0     M00
# 4    J25-0001           6      129        1440      2338          0     M01
# 5    J25-0013           3     1192        1440      2567          1     M02
# ..        ...         ...      ...         ...       ...        ...     ...
# 154  J25-0006           9      790        1440      3539          9     M07
# 155  J25-0009           7     1004        1440      3578          9     M03
# 156  J25-0000           8       79        1440      3660          9     M08
# 157  J25-0002           0      198        1440      3744          9     M09
# 158  J25-0012           2     1103        1440      4385          9     M04
# 159  J25-0004           3      287        1440      4856          9     M05
#
#      Start  Processing Time   End
# 0     1440               43  1483
# 1     1440               84  1524
# 2     1440               81  1521
# 3     1483               43  1526
# 4     1521               46  1567
# 5     1524               95  1619
# ..     ...              ...   ...
# 154   3494               45  3539
# 155   3499               79  3578
# 156   3586               74  3660
# 157   3723               21  3744
# 158   4352               33  4385
# 159   4813               43  4856
#
# [160 rows x 10 columns]

# %% [markdown]
# ### Simulation

# %%
simulation.run(dframe_schedule_plan = df_schedule, start_time = day_start, end_time=day_end)
# Out:
# [Day 1 00:00:00] Job J25-0005 started on M00
# [Day 1 00:00:00] Job J25-0007 started on M02
# [Day 1 00:00:00] Job J25-0013 started on M01
# [Day 1 00:45:00] Job J25-0005 finished on M00 (after 45 minutes)
# [Day 1 00:45:00] Job J25-0011 started on M00
# [Day 1 01:17:00] Job J25-0007 finished on M02 (after 77 minutes)
# [Day 1 01:21:00] Job J25-0011 finished on M00 (after 36 minutes)
# [Day 1 01:26:00] Job J25-0010 started on M00
# [Day 1 01:28:00] Job J25-0013 finished on M01 (after 88 minutes)
# [Day 1 01:28:00] Job J25-0001 started on M01
# [Day 1 01:28:00] Job J25-0013 started on M02
# [Day 1 01:50:00] Job J25-0010 finished on M00 (after 24 minutes)
# [Day 1 01:55:00] Job J25-0000 started on M00
# [Day 1 02:11:00] Job J25-0001 finished on M01 (after 43 minutes)
# [Day 1 02:11:00] Job J25-0007 started on M01
# [Day 1 02:13:00] Job J25-0007 finished on M01 (after 02 minutes)
# [Day 1 02:13:00] Job J25-0003 started on M01
# [Day 1 02:13:00] Job J25-0007 started on M05
# [Day 1 03:05:00] Job J25-0013 finished on M02 (after 97 minutes)
# [Day 1 03:05:00] Job J25-0015 started on M02
# [Day 1 03:08:00] Job J25-0000 finished on M00 (after 73 minutes)
# [Day 1 03:09:00] Job J25-0007 finished on M05 (after 56 minutes)
# [Day 1 03:09:00] Job J25-0007 started on M03
# [Day 1 03:11:00] Job J25-0001 started on M00
# [Day 1 03:32:00] Job J25-0003 finished on M01 (after 79 minutes)
# [Day 1 03:40:00] Job J25-0006 started on M01
# [Day 1 03:54:00] Job J25-0001 finished on M00 (after 43 minutes)
# [Day 1 03:54:00] Job J25-0013 started on M00
# [Day 1 04:37:00] Job J25-0015 finished on M02 (after 92 minutes)
# [Day 1 04:37:00] Job J25-0005 started on M02
# [Day 1 04:42:00] Job J25-0007 finished on M03 (after 93 minutes)
# [Day 1 04:42:00] Job J25-0001 started on M03
# [Day 1 04:42:00] Job J25-0007 started on M08
# [Day 1 04:55:00] Job J25-0013 finished on M00 (after 61 minutes)
# [Day 1 04:59:00] Job J25-0003 started on M00
# [Day 1 04:59:00] Job J25-0013 started on M04
# [Day 1 05:17:00] Job J25-0006 finished on M01 (after 97 minutes)
# [Day 1 05:17:00] Job J25-0015 started on M01
# [Day 1 05:19:00] Job J25-0015 finished on M01 (after 02 minutes)
# [Day 1 05:19:00] Job J25-0010 started on M01
# [Day 1 05:19:00] Job J25-0015 started on M05
# [Day 1 05:34:00] Job J25-0007 finished on M08 (after 52 minutes)
# [Day 1 05:34:00] Job J25-0007 started on M09
# [Day 1 05:41:00] Job J25-0001 finished on M03 (after 59 minutes)
# [Day 1 06:07:00] Job J25-0005 finished on M02 (after 90 minutes)
# [Day 1 06:07:00] Job J25-0001 started on M02
# [Day 1 06:14:00] Job J25-0003 finished on M00 (after 75 minutes)
# [Day 1 06:17:00] Job J25-0015 finished on M05 (after 58 minutes)
# [Day 1 06:17:00] Job J25-0015 started on M03
# [Day 1 06:19:00] Job J25-0001 finished on M02 (after 12 minutes)
# [Day 1 06:19:00] Job J25-0011 started on M02
# [Day 1 06:19:00] Job J25-0001 started on M06
# [Day 1 06:24:00] Job J25-0006 started on M00
# [Day 1 06:29:00] Job J25-0013 finished on M04 (after 90 minutes)
# [Day 1 06:34:00] Job J25-0010 finished on M01 (after 75 minutes)
# [Day 1 06:34:00] Job J25-0006 finished on M00 (after 10 minutes)
# [Day 1 06:34:00] Job J25-0000 started on M01
# [Day 1 06:38:00] Job J25-0005 started on M04
# [Day 1 06:59:00] Job J25-0001 finished on M06 (after 40 minutes)
# [Day 1 06:59:00] Job J25-0013 started on M06
# [Day 1 06:59:00] Job J25-0001 started on M05
# [Day 1 07:01:00] Job J25-0007 finished on M09 (after 87 minutes)
# [Day 1 07:01:00] Job J25-0007 started on M00
# [Day 1 07:07:00] Job J25-0013 finished on M06 (after 08 minutes)
# [Day 1 07:07:00] Job J25-0013 started on M08
# [Day 1 07:19:00] Job J25-0001 finished on M05 (after 20 minutes)
# [Day 1 07:19:00] Job J25-0001 started on M09
# [Day 1 07:22:00] Job J25-0015 finished on M03 (after 65 minutes)
# [Day 1 07:27:00] Job J25-0011 finished on M02 (after 68 minutes)
# [Day 1 07:34:00] Job J25-0003 started on M03
# [Day 1 07:36:00] Job J25-0009 started on M02
# [Day 1 07:41:00] Job J25-0000 finished on M01 (after 67 minutes)
# [Day 1 07:41:00] Job J25-0012 started on M01
# [Day 1 07:44:00] Job J25-0001 finished on M09 (after 25 minutes)
# [Day 1 07:46:00] Job J25-0007 finished on M00 (after 45 minutes)
# [Day 1 07:46:00] Job J25-0002 started on M00
# [Day 1 07:46:00] Job J25-0007 started on M06
# [Day 1 08:01:00] Job J25-0005 finished on M04 (after 83 minutes)
# [Day 1 08:01:00] Job J25-0011 started on M04
# [Day 1 08:01:00] Job J25-0005 started on M09
# [Day 1 08:03:00] Job J25-0003 finished on M03 (after 29 minutes)
# [Day 1 08:04:00] Job J25-0009 finished on M02 (after 28 minutes)
# [Day 1 08:07:00] Job J25-0014 started on M02
# [Day 1 08:10:00] Job J25-0002 finished on M00 (after 24 minutes)
# [Day 1 08:10:00] Job J25-0009 started on M00
# [Day 1 08:11:00] Job J25-0013 finished on M08 (after 64 minutes)
# [Day 1 08:11:00] Job J25-0005 finished on M09 (after 10 minutes)
# [Day 1 08:11:00] Job J25-0001 started on M08
# [Day 1 08:11:00] Job J25-0013 started on M07
# [Day 1 08:13:00] Job J25-0005 started on M03
# [Day 1 08:21:00] Job J25-0014 finished on M02 (after 14 minutes)
# [Day 1 08:21:00] Job J25-0003 started on M02
# [Day 1 08:54:00] Job J25-0012 finished on M01 (after 73 minutes)
# [Day 1 08:59:00] Job J25-0007 finished on M06 (after 73 minutes)
# [Day 1 09:05:00] Job J25-0002 started on M01
# [Day 1 09:14:00] Job J25-0005 finished on M03 (after 61 minutes)
# [Day 1 09:23:00] Job J25-0011 finished on M04 (after 82 minutes)
# [Day 1 09:23:00] Job J25-0007 started on M04
# [Day 1 09:23:00] Job J25-0011 started on M09
# [Day 1 09:27:00] Job J25-0009 finished on M00 (after 77 minutes)
# [Day 1 09:28:00] Job J25-0007 finished on M04 (after 05 minutes)
# [Day 1 09:33:00] Job J25-0011 finished on M09 (after 10 minutes)
# [Day 1 09:33:00] Job J25-0014 started on M00
# [Day 1 09:34:00] Job J25-0003 finished on M02 (after 73 minutes)
# [Day 1 09:35:00] Job J25-0006 started on M02
# [Day 1 09:38:00] Job J25-0014 finished on M00 (after 05 minutes)
# [Day 1 09:39:00] Job J25-0013 finished on M07 (after 88 minutes)
# [Day 1 09:39:00] Job J25-0012 started on M00
# [Day 1 09:39:00] Job J25-0013 started on M03
# [Day 1 10:09:00] Job J25-0001 finished on M08 (after 118 minutes)
# [Day 1 10:09:00] Job J25-0015 started on M08
# [Day 1 10:09:00] Job J25-0001 started on M07
# [Day 1 10:12:00] Job J25-0002 finished on M01 (after 67 minutes)
# [Day 1 10:23:00] Job J25-0005 started on M01
# [Day 1 10:40:00] Job J25-0001 finished on M07 (after 31 minutes)
# [Day 1 10:52:00] Job J25-0005 finished on M01 (after 29 minutes)
# [Day 1 10:52:00] Job J25-0014 started on M01
# [Day 1 10:52:00] Job J25-0005 started on M06
# [Day 1 10:53:00] Job J25-0015 finished on M08 (after 44 minutes)
# [Day 1 10:53:00] Job J25-0003 started on M08
# [Day 1 10:53:00] Job J25-0015 started on M09
# [Day 1 10:58:00] Job J25-0006 finished on M02 (after 83 minutes)
# [Day 1 10:58:00] Job J25-0010 started on M02
# [Day 1 11:07:00] Job J25-0010 finished on M02 (after 09 minutes)
# [Day 1 11:07:00] Job J25-0008 started on M02
# [Day 1 11:08:00] Job J25-0012 finished on M00 (after 89 minutes)
# [Day 1 11:18:00] Job J25-0014 finished on M01 (after 26 minutes)
# [Day 1 11:18:00] Job J25-0009 started on M01
# [Day 1 11:18:00] Job J25-0014 started on M05
# [Day 1 11:19:00] Job J25-0013 finished on M03 (after 100 minutes)
# [Day 1 11:19:00] Job J25-0011 started on M03
# [Day 1 11:21:00] Job J25-0008 finished on M02 (after 14 minutes)
# [Day 1 11:21:00] Job J25-0002 started on M02
# [Day 1 11:21:00] Job J25-0008 started on M00
# [Day 1 11:28:00] Job J25-0008 finished on M00 (after 07 minutes)
# [Day 1 11:32:00] Job J25-0002 finished on M02 (after 11 minutes)
# [Day 1 11:41:00] Job J25-0005 finished on M06 (after 49 minutes)
# [Day 1 11:41:00] Job J25-0006 started on M06
# [Day 1 11:47:00] Job J25-0006 finished on M06 (after 06 minutes)
# [Day 1 11:59:00] Job J25-0015 finished on M09 (after 66 minutes)
# [Day 1 11:59:00] Job J25-0013 started on M09
# [Day 1 11:59:00] Job J25-0015 started on M00
# [Day 1 12:17:00] Job J25-0009 finished on M01 (after 59 minutes)
# [Day 1 12:17:00] Job J25-0008 started on M01
# [Day 1 12:18:00] Job J25-0014 finished on M05 (after 60 minutes)
# [Day 1 12:18:00] Job J25-0005 started on M05
# [Day 1 12:21:00] Job J25-0011 finished on M03 (after 62 minutes)
# [Day 1 12:21:00] Job J25-0013 finished on M09 (after 22 minutes)
# [Day 1 12:21:00] Job J25-0010 started on M03
# [Day 1 12:27:00] Job J25-0003 finished on M08 (after 94 minutes)
# [Day 1 12:27:00] Job J25-0006 started on M08
# [Day 1 12:41:00] Job J25-0015 finished on M00 (after 42 minutes)
# [Day 1 12:41:00] Job J25-0015 started on M06
# [Day 1 12:42:00] Job J25-0008 finished on M01 (after 25 minutes)
# [Day 1 12:42:00] Job J25-0011 started on M01
# [Day 1 13:02:00] Job J25-0010 finished on M03 (after 41 minutes)
# [Day 1 13:02:00] Job J25-0014 started on M03
# [Day 1 13:02:00] Job J25-0010 started on M04
# [Day 1 13:05:00] Job J25-0005 finished on M05 (after 47 minutes)
# [Day 1 13:05:00] Job J25-0009 started on M05
# [Day 1 13:05:00] Job J25-0005 started on M07
# [Day 1 13:11:00] Job J25-0011 finished on M01 (after 29 minutes)
# [Day 1 13:11:00] Job J25-0004 started on M01
# [Day 1 13:24:00] Job J25-0006 finished on M08 (after 57 minutes)
# [Day 1 13:24:00] Job J25-0006 started on M09
# [Day 1 13:26:00] Job J25-0014 finished on M03 (after 24 minutes)
# [Day 1 13:26:00] Job J25-0000 started on M03
# [Day 1 13:41:00] Job J25-0015 finished on M06 (after 60 minutes)
# [Day 1 13:41:00] Job J25-0011 started on M06
# [Day 1 13:52:00] Job J25-0010 finished on M04 (after 50 minutes)
# [Day 1 13:52:00] Job J25-0015 started on M04
# [Day 1 13:58:00] Job J25-0015 finished on M04 (after 06 minutes)
# [Day 1 14:03:00] Job J25-0001 started on M04
# [Day 1 14:19:00] Job J25-0011 finished on M06 (after 38 minutes)
# [Day 1 14:26:00] Job J25-0009 finished on M05 (after 81 minutes)
# [Day 1 14:26:00] Job J25-0011 started on M05
# [Day 1 14:31:00] Job J25-0004 finished on M01 (after 80 minutes)
# [Day 1 14:31:00] Job J25-0004 started on M02
# [Day 1 14:40:00] Job J25-0000 finished on M03 (after 74 minutes)
# [Day 1 14:40:00] Job J25-0002 started on M03
# [Day 1 14:43:00] Job J25-0005 finished on M07 (after 98 minutes)
# [Day 1 14:43:00] Job J25-0006 finished on M09 (after 79 minutes)
# [Day 1 15:11:00] Job J25-0001 finished on M04 (after 68 minutes)
# [Day 1 15:11:00] Job J25-0014 started on M04
# [Day 1 15:20:00] Job J25-0002 finished on M03 (after 40 minutes)
# [Day 1 15:20:00] Job J25-0012 started on M03
# [Day 1 15:26:00] Job J25-0011 finished on M05 (after 60 minutes)
# [Day 1 15:26:00] Job J25-0003 started on M05
# [Day 1 15:26:00] Job J25-0011 started on M07
# [Day 1 15:36:00] Job J25-0003 finished on M05 (after 10 minutes)
# [Day 1 15:36:00] Job J25-0010 started on M05
# [Day 1 15:46:00] Job J25-0010 finished on M05 (after 10 minutes)
# [Day 1 15:46:00] Job J25-0008 started on M05
# [Day 1 15:46:00] Job J25-0010 started on M06
# [Day 1 15:50:00] Job J25-0012 finished on M03 (after 30 minutes)
# [Day 1 16:07:00] Job J25-0004 finished on M02 (after 96 minutes)
# [Day 1 16:07:00] Job J25-0012 started on M02
# [Day 1 16:07:00] Job J25-0004 started on M00
# [Day 1 16:10:00] Job J25-0014 finished on M04 (after 59 minutes)
# [Day 1 16:10:00] Job J25-0009 started on M04
# [Day 1 16:10:00] Job J25-0014 started on M08
# [Day 1 16:36:00] Job J25-0011 finished on M07 (after 70 minutes)
# [Day 1 16:36:00] Job J25-0003 started on M07
# [Day 1 16:39:00] Job J25-0014 finished on M08 (after 29 minutes)
# [Day 1 16:45:00] Job J25-0009 finished on M04 (after 35 minutes)
# [Day 1 16:45:00] Job J25-0002 started on M04
# [Day 1 16:49:00] Job J25-0008 finished on M05 (after 63 minutes)
# [Day 1 16:49:00] Job J25-0003 finished on M07 (after 13 minutes)
# [Day 1 16:49:00] Job J25-0000 started on M05
# [Day 1 16:49:00] Job J25-0008 started on M03
# [Day 1 16:53:00] Job J25-0010 finished on M06 (after 67 minutes)
# [Day 1 16:53:00] Job J25-0003 started on M06
# [Day 1 16:53:00] Job J25-0010 started on M07
# [Day 1 17:10:00] Job J25-0004 finished on M00 (after 63 minutes)
# [Day 1 17:15:00] Job J25-0008 finished on M03 (after 26 minutes)
# [Day 1 17:25:00] Job J25-0002 finished on M04 (after 40 minutes)
# [Day 1 17:26:00] Job J25-0012 finished on M02 (after 79 minutes)
# [Day 1 17:26:00] Job J25-0012 started on M08
# [Day 1 17:28:00] Job J25-0008 started on M04
# [Day 1 17:34:00] Job J25-0000 finished on M05 (after 45 minutes)
# [Day 1 17:34:00] Job J25-0006 started on M05
# [Day 1 17:34:00] Job J25-0000 started on M02
# [Day 1 17:55:00] Job J25-0010 finished on M07 (after 62 minutes)
# [Day 1 17:55:00] Job J25-0014 started on M07
# [Day 1 18:24:00] Job J25-0006 finished on M05 (after 50 minutes)
# [Day 1 18:24:00] Job J25-0013 started on M05
# [Day 1 18:24:00] Job J25-0006 started on M03
# [Day 1 18:25:00] Job J25-0014 finished on M07 (after 30 minutes)
# [Day 1 18:38:00] Job J25-0014 started on M09
# [Day 1 18:39:00] Job J25-0008 finished on M04 (after 71 minutes)
# [Day 1 18:39:00] Job J25-0004 started on M04
# [Day 1 18:41:00] Job J25-0003 finished on M06 (after 108 minutes)
# [Day 1 18:41:00] Job J25-0009 started on M06
# [Day 1 18:56:00] Job J25-0012 finished on M08 (after 90 minutes)
# [Day 1 18:56:00] Job J25-0010 started on M08
# [Day 1 19:13:00] Job J25-0000 finished on M02 (after 99 minutes)
# [Day 1 19:17:00] Job J25-0006 finished on M03 (after 53 minutes)
# [Day 1 19:22:00] Job J25-0013 finished on M05 (after 58 minutes)
# [Day 1 19:22:00] Job J25-0002 started on M05
# [Day 1 19:28:00] Job J25-0014 finished on M09 (after 50 minutes)
# [Day 1 19:28:00] Job J25-0003 started on M09
# [Day 1 19:35:00] Job J25-0002 finished on M05 (after 13 minutes)
# [Day 1 19:35:00] Job J25-0012 started on M05
# [Day 1 19:42:00] Job J25-0010 finished on M08 (after 46 minutes)
# [Day 1 19:42:00] Job J25-0008 started on M08
# [Day 1 19:45:00] Job J25-0012 finished on M05 (after 10 minutes)
# [Day 1 19:45:00] Job J25-0012 started on M07
# [Day 1 19:57:00] Job J25-0012 finished on M07 (after 12 minutes)
# [Day 1 20:09:00] Job J25-0009 finished on M06 (after 88 minutes)
# [Day 1 20:09:00] Job J25-0002 started on M06
# [Day 1 20:10:00] Job J25-0008 finished on M08 (after 28 minutes)
# [Day 1 20:10:00] Job J25-0009 started on M08
# [Day 1 20:10:00] Job J25-0008 started on M07
# [Day 1 20:15:00] Job J25-0003 finished on M09 (after 47 minutes)
# [Day 1 20:15:00] Job J25-0000 started on M09
# [Day 1 20:18:00] Job J25-0004 finished on M04 (after 99 minutes)
# [Day 1 20:18:00] Job J25-0006 started on M04
# [Day 1 20:27:00] Job J25-0000 finished on M09 (after 12 minutes)
# [Day 1 20:33:00] Job J25-0009 finished on M08 (after 23 minutes)
# [Day 1 20:33:00] Job J25-0009 started on M09
# [Day 1 20:52:00] Job J25-0002 finished on M06 (after 43 minutes)
# [Day 1 20:52:00] Job J25-0000 started on M06
# [Day 1 21:05:00] Job J25-0008 finished on M07 (after 55 minutes)
# [Day 1 21:05:00] Job J25-0002 started on M07
# [Day 1 21:31:00] Job J25-0000 finished on M06 (after 39 minutes)
# [Day 1 21:31:00] Job J25-0012 started on M06
# [Day 1 21:34:00] Job J25-0009 finished on M09 (after 61 minutes)
# [Day 1 21:34:00] Job J25-0008 started on M09
# [Day 1 21:39:00] Job J25-0006 finished on M04 (after 81 minutes)
# [Day 1 21:52:00] Job J25-0002 finished on M07 (after 47 minutes)
# [Day 1 21:52:00] Job J25-0000 started on M07
# [Day 1 21:52:00] Job J25-0002 started on M08
# [Day 1 22:42:00] Job J25-0008 finished on M09 (after 68 minutes)
# [Day 1 22:42:00] Job J25-0002 finished on M08 (after 50 minutes)
# [Day 1 22:46:00] Job J25-0012 finished on M06 (after 75 minutes)
# [Day 1 22:46:00] Job J25-0004 started on M06
# [Day 1 22:46:00] Job J25-0012 started on M09
# [Day 1 22:56:00] Job J25-0004 finished on M06 (after 10 minutes)
# [Day 1 22:56:00] Job J25-0004 started on M08
# [Day 1 23:22:00] Job J25-0012 finished on M09 (after 36 minutes)
# [Day 1 23:26:00] Job J25-0000 finished on M07 (after 94 minutes)
# [Day 1 23:26:00] Job J25-0009 started on M07
# [Day 1 23:26:00] Job J25-0000 started on M04
# [Day 1 23:49:00] Job J25-0000 finished on M04 (after 23 minutes)
# [Day 1 23:51:00] Job J25-0004 finished on M08 (after 55 minutes)

# %%
df_execution = simulation.get_finished_operations_df()
gantt.get_plot(df_execution, perspective="Machine")

# %%
df_active = simulation.get_active_operations_df()
if df_active is not None:
    gantt.get_plot(df_active, perspective="Machine", duration_column="Planned Duration")
# Out:
# C:\Users\konra\Coding\HTWD_Minimalinvasives_Job-Shop_Scheduling\src\utils\visualization\gantt_diagram.py:111: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
df_not_started = simulation.get_not_started_operations_df(df_schedule)
df_not_started
# Out:
#          Job  Routing_ID  Arrival  Ready Time  Deadline  Operation Machine  \
# 0   J25-0000           8       79        1440      3660          9     M08
# 1   J25-0002           0      198        1440      3744          9     M09
# 2   J25-0003           2      243        1440      3379          9     M04
# 3   J25-0004           3      287        1440      4856          6     M07
# 4   J25-0004           3      287        1440      4856          7     M03
# 5   J25-0004           3      287        1440      4856          8     M09
# ..       ...         ...      ...         ...       ...        ...     ...
# 11  J25-0009           7     1004        1440      3578          9     M03
# 12  J25-0010           0     1025        1440      3345          9     M09
# 13  J25-0011           1     1030        1440      3210          9     M08
# 14  J25-0012           2     1103        1440      4385          9     M04
# 15  J25-0014           4     1222        1440      3315          9     M06
# 16  J25-0015           5     1436        1440      2981          9     M07
#
#     Start  Processing Time   End
# 0    3586               74  3660
# 1    3723               21  3744
# 2    3346               33  3379
# 3    2981               85  3066
# 4    3066               98  3164
# 5    3164               22  3186
# ..    ...              ...   ...
# 11   3499               79  3578
# 12   3324               21  3345
# 13   3180               30  3210
# 14   4352               33  4385
# 15   3262               53  3315
# 16   2956               25  2981
#
# [17 rows x 10 columns]

# %%
columns = ["Job", "Operation", "Machine", "Arrival", "Start", "Processing Time", "End"]
df_combined = pd.concat([df_execution, df_active[columns]], ignore_index=True)
gantt.get_plot(df_combined, perspective="Machine")
check.is_machine_conflict_free(df_combined)
check.is_operation_sequence_correct(df_combined)
check.is_job_timing_correct(df_combined)
check.is_start_correct(df_combined)
# Out:
# + Keine Maschinenkonflikte gefunden
# + Alle Gruppen wurden in korrekter Operationsreihenfolge ausgeführt.
# + Alle technologischen Abhängigkeiten wurden eingehalten.
# + Alle Operation starten erst nach Arrival des Job
# True

# %% [markdown]
# ## Tag 2
# - hier findet die Neuplanung statt, also das Scheduling mit bestimmter Berücksichtigung der Simulation

# %%
day_numb = 2
day_start = day_length*day_numb
day_end = day_start + day_length
print(f"Tag {day_numb:02d}: [{day_start}, {day_end})")
# Out:
# Tag 02: [2880, 4320)

# %%
# "neue" und unerledigte Jobs
df_jobs_times_current = get_current_jobs(df_jobs_times, df_not_started, ready_time=day_start)
df_jobs_times_current
# Out:
#          Job  Routing_ID  Arrival  Ready Time     End  Job Processing Time  \
# 0   J25-0000           8       79        1440  2704.0                  597
# 2   J25-0002           0      198        1440  2925.0                  395
# 3   J25-0003           2      243        1440  2801.0                  568
# 4   J25-0004           3      287        1440  2697.0                  655
# 5   J25-0005           1      498        1440  2630.0                  510
# 6   J25-0006           9      790        1440  2905.0                  540
# ..       ...         ...      ...         ...     ...                  ...
# 32  J25-0032           6     2654        2880  4856.0                  416
# 33  J25-0033           2     2660        2880  5305.0                  568
# 34  J25-0034           8     2715        2880  5271.0                  597
# 35  J25-0035           5     2726        2880  4689.0                  496
# 36  J25-0036           4     2734        2880  5135.0                  393
# 37  J25-0037           7     2801        2880  5046.0                  539
#
#     Deadline
# 0       3660
# 2       3744
# 3       3379
# 4       4856
# 5       3106
# 6       3539
# ..       ...
# 32      3881
# 33      6738
# 34      6387
# 35      4126
# 36      5231
# 37      5173
#
# [36 rows x 7 columns]

# %%
df_jssp_current = filter_current_jssp(
    df_jssp = df_jssp,
    df_jobs_times_current = df_jobs_times_current,
    exclusion_dataframes_list = [df_active, df_execution]
)
df_jssp_current
# Out:
#           Job  Routing_ID  Operation Machine  Processing Time
# 9    J25-0000           8          9     M08               74
# 29   J25-0002           0          9     M09               21
# 39   J25-0003           2          9     M04               33
# 46   J25-0004           3          6     M07               85
# 47   J25-0004           3          7     M03               98
# 48   J25-0004           3          8     M09               22
# ..        ...         ...        ...     ...              ...
# 374  J25-0037           7          4     M04               32
# 375  J25-0037           7          5     M06               88
# 376  J25-0037           7          6     M08               19
# 377  J25-0037           7          7     M09               48
# 378  J25-0037           7          8     M07               36
# 379  J25-0037           7          9     M03               79
#
# [237 rows x 5 columns]

# %% [markdown]
# ### A) Neuplanung mit zusätzlich Minimierung der Planabweichung für die zuvor geplante Arbeitsgänge

# %% [markdown]
# $$
# min
# Z = r \cdot \sum_
# {j \ in  \text
# {Jobs}} \left(w_t \cdot \text
# {Tardiness}
# _j + w_e \cdot \text
# {Earliness}
# _j \right) + (1 - r) \cdot \sum_
# {(j, o) \ in  \text
# {DevOps}} \left | \text
# {Start}
# _
# {j, o} - \text
# {Start}
# _
# {j, o} ^ {\text
# {original}} \right |
# $$

# %%
df_schedule_devpen = cp_late_reschedule.solve_jssp_by_tardiness_and_earliness_with_devpen(
    df_jssp = df_jssp_current, df_times = df_jobs_times_current,
    df_original_plan = df_schedule,                     # prev. Plan
    df_active = df_active,
    w_t = 5,
    r = 0.60,                                           # 60% Flowtime, 40% Abweichung
    reschedule_start = day_start,
    msg=False, timeLimit=max_time, gapRel= 0.02
)
df_schedule_devpen
# Out:
# Solver-Status         : OPTIMAL
# Objective Value       : 2500.00
# Best Objective Bound  : 2460.00
# Laufzeit              : 0.15 Sekunden
# Deviation terms       : 17
#           Job  Routing_ID  Arrival  Ready Time  Deadline  Operation Machine  \
# 0    J25-0031           1     2567        2880      4377          0     M00
# 1    J25-0032           6     2654        2880      3881          0     M01
# 2    J25-0035           5     2726        2880      4126          0     M02
# 3    J25-0007           5      925        1440      2929          9     M07
# 4    J25-0018           8     1919        2880      4772          0     M00
# 5    J25-0019           9     1925        2880      4621          0     M01
# ..        ...         ...      ...         ...       ...        ...     ...
# 231  J25-0028           0     2282        2880      5291          9     M09
# 232  J25-0021           5     1952        2880      5368          9     M07
# 233  J25-0027           7     2277        2880      5711          9     M03
# 234  J25-0030           0     2313        2880      6015          9     M09
# 235  J25-0034           8     2715        2880      6387          9     M08
# 236  J25-0033           2     2660        2880      6738          9     M04
#
#      Start  Processing Time   End
# 0     2880               43  2923
# 1     2880               46  2926
# 2     2880               84  2964
# 3     2904               25  2929
# 4     2923               76  2999
# 5     2926               85  3011
# ..     ...              ...   ...
# 231   5270               21  5291
# 232   5343               25  5368
# 233   5632               79  5711
# 234   5994               21  6015
# 235   6313               74  6387
# 236   6705               33  6738
#
# [237 rows x 10 columns]

# %%
df_temp =  df_schedule_devpen

gantt.get_plot(df_temp, perspective="Machine")
check.is_machine_conflict_free(df_temp)
check.is_operation_sequence_correct(df_temp)
check.is_job_timing_correct(df_temp)
check.is_start_correct(df_temp)
# Out:
# + Keine Maschinenkonflikte gefunden
# + Alle Gruppen wurden in korrekter Operationsreihenfolge ausgeführt.
# + Alle technologischen Abhängigkeiten wurden eingehalten.
# + Alle Operation starten erst nach Arrival des Job
# True

# %%
gantt.get_plot(df_temp, perspective="Job")

# %% [markdown]
# ### B) Neuplanung mit zusätzlich Minimierung der Planabweichung für die zuvor geplante Arbeitsgänge & Maximierung des ersten Arbeitsgangen

# %% [markdown]
# $$
# Z = \alpha \cdot \left[
# r \cdot \sum_{j \in \text{Jobs}} \left( w_t \cdot \max(0, C_j - D_j) + w_e \cdot \max(0, D_j - C_j) \right)
# + (1 - r) \cdot \sum_{(j,o) \in \text{DevOps}} \left| S_{j,o} - S_{j,o}^{\text{orig}} \right|
# \right]
# - (1 - \alpha) \cdot \sum_{j \in \text{Jobs}} S_j^{\text{first}}
# $$

# %%
df_schedule_advanced = cp_late_reschedule.solve_jssp_advanced(
    df_jssp = df_jssp_current, df_times = df_jobs_times_current,
    df_original_plan = df_schedule,                     # prev. Plan
    df_active = df_active,
    w_t = 5,
    r = 0.60,                                           # 60 % Flowtime, 40 % Abweichung
    alpha= 0.9,                                         # 90 % Haupt-Zielfunktion, 10 % Start des ersten Arbeitsganges
    reschedule_start = day_start,
    msg=False, timeLimit=max_time, gapRel= 0.02
)
df_schedule_advanced
# Out:
# Solver-Status         : OPTIMAL
# Objective Value       : 0.00
# Best Objective Bound  : 0.00
# Laufzeit              : 5.05 Sekunden
# Deviation terms       : 17
#           Job  Routing_ID  Arrival  Ready Time  Deadline  Operation Machine  \
# 0    J25-0035           5     2726        2880      4126          0     M02
# 1    J25-0032           6     2654        2880      3881          0     M01
# 2    J25-0031           1     2567        2880      4377          0     M00
# 3    J25-0007           5      925        1440      2929          9     M07
# 4    J25-0015           5     1436        1440      2981          9     M07
# 5    J25-0031           1     2567        2880      4377          1     M02
# ..        ...         ...      ...         ...       ...        ...     ...
# 231  J25-0033           2     2660        2880      6738          4     M08
# 232  J25-0033           2     2660        2880      6738          5     M05
# 233  J25-0033           2     2660        2880      6738          6     M07
# 234  J25-0033           2     2660        2880      6738          7     M06
# 235  J25-0033           2     2660        2880      6738          8     M09
# 236  J25-0033           2     2660        2880      6738          9     M04
#
#      Start  Processing Time   End
# 0     2880               84  2964
# 1     2918               46  2964
# 2     2921               43  2964
# 3     2927               25  2952
# 4     2952               25  2977
# 5     2964               90  3054
# ..     ...              ...   ...
# 231   6387               90  6477
# 232   6477               10  6487
# 233   6487               12  6499
# 234   6499               89  6588
# 235   6588               45  6633
# 236   6705               33  6738
#
# [237 rows x 10 columns]

# %%
df_temp =  df_schedule_advanced

gantt.get_plot(df_temp, perspective="Machine")
check.is_machine_conflict_free(df_temp)
check.is_operation_sequence_correct(df_temp)
check.is_job_timing_correct(df_temp)
check.is_start_correct(df_temp)
# Out:
# + Keine Maschinenkonflikte gefunden
# + Alle Gruppen wurden in korrekter Operationsreihenfolge ausgeführt.
# + Alle technologischen Abhängigkeiten wurden eingehalten.
# + Alle Operation starten erst nach Arrival des Job
# True

# %%
gantt.get_plot(df_temp, perspective="Job")

# %% [markdown]
# #### Check der Bedingungen des kombinierten Datensatzes aus den Simulationsdaten mit dem neuen Schedule

# %%
df_reschedule = df_schedule_advanced

columns = ["Job", "Operation", "Machine", "Arrival", "Start", "Processing Time", "End"]
df_combined = pd.concat([df_execution, df_active[columns], df_reschedule[columns]], ignore_index=True)
gantt.get_plot(df_combined, perspective="Machine")
check.is_machine_conflict_free(df_combined)
check.is_operation_sequence_correct(df_combined)
check.is_job_timing_correct(df_combined)
check.is_start_correct(df_combined)
# Out:
# + Keine Maschinenkonflikte gefunden
# + Alle Gruppen wurden in korrekter Operationsreihenfolge ausgeführt.
# + Alle technologischen Abhängigkeiten wurden eingehalten.
# + Alle Operation starten erst nach Arrival des Job
# True

# %% [markdown]
# ### Simulation

# %%
simulation.run(dframe_schedule_plan = df_schedule_advanced, start_time = day_start, end_time = day_end)
# Out:
# Remaining time: 8.0
# Start time: 2880
# End time: 2888.0
# [Day 2 00:00:00] Job J25-0009, Operation 8 resumed on M07 (with 08 minutes left)
# [Day 2 00:00:00] Job J25-0035 started on M02
# [Day 2 00:08:00] Job J25-0009 finished on M07 (after 08 minutes)
# [Day 2 00:38:00] Job J25-0032 started on M01
# [Day 2 00:41:00] Job J25-0031 started on M00
# [Day 2 00:47:00] Job J25-0007 started on M07
# [Day 2 01:13:00] Job J25-0007 finished on M07 (after 26 minutes)
# [Day 2 01:13:00] Job J25-0015 started on M07
# [Day 2 01:21:00] Job J25-0032 finished on M01 (after 43 minutes)
# [Day 2 01:21:00] Job J25-0031 finished on M00 (after 40 minutes)
# [Day 2 01:24:00] Job J25-0032 started on M00
# [Day 2 01:34:00] Job J25-0015 finished on M07 (after 21 minutes)
# [Day 2 01:37:00] Job J25-0004 started on M07
# [Day 2 01:47:00] Job J25-0019 started on M01
# [Day 2 01:56:00] Job J25-0035 finished on M02 (after 116 minutes)
# [Day 2 01:56:00] Job J25-0031 started on M02
# [Day 2 02:07:00] Job J25-0032 finished on M00 (after 43 minutes)
# [Day 2 02:07:00] Job J25-0032 started on M03
# [Day 2 02:10:00] Job J25-0023 started on M00
# [Day 2 02:59:00] Job J25-0032 finished on M03 (after 52 minutes)
# [Day 2 03:01:00] Job J25-0019 finished on M01 (after 74 minutes)
# [Day 2 03:01:00] Job J25-0035 started on M01
# [Day 2 03:03:00] Job J25-0035 finished on M01 (after 02 minutes)
# [Day 2 03:03:00] Job J25-0035 started on M05
# [Day 2 03:09:00] Job J25-0004 finished on M07 (after 92 minutes)
# [Day 2 03:09:00] Job J25-0004 started on M03
# [Day 2 03:14:00] Job J25-0031 finished on M02 (after 78 minutes)
# [Day 2 03:14:00] Job J25-0032 started on M02
# [Day 2 03:14:00] Job J25-0031 started on M04
# [Day 2 03:21:00] Job J25-0005 started on M08
# [Day 2 03:23:00] Job J25-0023 finished on M00 (after 73 minutes)
# [Day 2 03:26:00] Job J25-0019 started on M00
# [Day 2 03:27:00] Job J25-0032 finished on M02 (after 13 minutes)
# [Day 2 03:27:00] Job J25-0032 started on M06
# [Day 2 03:37:00] Job J25-0019 finished on M00 (after 11 minutes)
# [Day 2 03:39:00] Job J25-0019 started on M02
# [Day 2 03:40:00] Job J25-0024 started on M01
# [Day 2 03:54:00] Job J25-0005 finished on M08 (after 33 minutes)
# [Day 2 03:58:00] Job J25-0032 finished on M06 (after 31 minutes)
# [Day 2 04:00:00] Job J25-0035 finished on M05 (after 57 minutes)
# [Day 2 04:00:00] Job J25-0032 started on M05
# [Day 2 04:03:00] Job J25-0018 started on M00
# [Day 2 04:24:00] Job J25-0031 finished on M04 (after 70 minutes)
# [Day 2 04:27:00] Job J25-0032 finished on M05 (after 27 minutes)
# [Day 2 04:27:00] Job J25-0032 started on M09
# [Day 2 04:40:00] Job J25-0004 finished on M03 (after 91 minutes)
# [Day 2 04:40:00] Job J25-0035 started on M03
# [Day 2 04:43:00] Job J25-0019 finished on M02 (after 64 minutes)
# [Day 2 04:43:00] Job J25-0019 started on M06
# [Day 2 04:50:00] Job J25-0019 finished on M06 (after 07 minutes)
# [Day 2 04:54:00] Job J25-0032 finished on M09 (after 27 minutes)
# [Day 2 04:54:00] Job J25-0004 started on M09
# [Day 2 05:00:00] Job J25-0011 started on M08
# [Day 2 05:16:00] Job J25-0004 finished on M09 (after 22 minutes)
# [Day 2 05:16:00] Job J25-0031 started on M09
# [Day 2 05:22:00] Job J25-0018 finished on M00 (after 79 minutes)
# [Day 2 05:27:00] Job J25-0031 finished on M09 (after 11 minutes)
# [Day 2 05:28:00] Job J25-0011 finished on M08 (after 28 minutes)
# [Day 2 05:29:00] Job J25-0024 finished on M01 (after 109 minutes)
# [Day 2 05:29:00] Job J25-0026 started on M01
# [Day 2 05:29:00] Job J25-0024 started on M02
# [Day 2 05:30:00] Job J25-0032 started on M08
# [Day 2 05:58:00] Job J25-0035 finished on M03 (after 78 minutes)
# [Day 2 06:15:00] Job J25-0031 started on M03
# [Day 2 06:18:00] Job J25-0026 finished on M01 (after 49 minutes)
# [Day 2 06:18:00] Job J25-0023 started on M01
# [Day 2 06:18:00] Job J25-0026 started on M00
# [Day 2 06:22:00] Job J25-0014 started on M06
# [Day 2 06:56:00] Job J25-0026 finished on M00 (after 38 minutes)
# [Day 2 06:58:00] Job J25-0032 finished on M08 (after 88 minutes)
# [Day 2 06:59:00] Job J25-0035 started on M08
# [Day 2 06:59:00] Job J25-0032 started on M07
# [Day 2 07:03:00] Job J25-0024 finished on M02 (after 94 minutes)
# [Day 2 07:03:00] Job J25-0029 started on M02
# [Day 2 07:03:00] Job J25-0024 started on M00
# [Day 2 07:15:00] Job J25-0014 finished on M06 (after 53 minutes)
# [Day 2 07:18:00] Job J25-0023 finished on M01 (after 60 minutes)
# [Day 2 07:18:00] Job J25-0029 finished on M02 (after 15 minutes)
# [Day 2 07:18:00] Job J25-0018 started on M01
# [Day 2 07:23:00] Job J25-0031 finished on M03 (after 68 minutes)
# [Day 2 07:24:00] Job J25-0026 started on M03
# [Day 2 07:26:00] Job J25-0010 started on M09
# [Day 2 07:35:00] Job J25-0032 finished on M07 (after 36 minutes)
# [Day 2 07:46:00] Job J25-0003 started on M04
# [Day 2 07:47:00] Job J25-0010 finished on M09 (after 21 minutes)
# [Day 2 07:49:00] Job J25-0035 finished on M08 (after 50 minutes)
# [Day 2 07:49:00] Job J25-0019 started on M08
# [Day 2 07:49:00] Job J25-0035 started on M09
# [Day 2 08:06:00] Job J25-0017 started on M02
# [Day 2 08:09:00] Job J25-0018 finished on M01 (after 51 minutes)
# [Day 2 08:16:00] Job J25-0031 started on M01
# [Day 2 08:17:00] Job J25-0026 finished on M03 (after 53 minutes)
# [Day 2 08:22:00] Job J25-0024 finished on M00 (after 79 minutes)
# [Day 2 08:22:00] Job J25-0029 started on M00
# [Day 2 08:25:00] Job J25-0003 finished on M04 (after 39 minutes)
# [Day 2 08:25:00] Job J25-0023 started on M03
# [Day 2 08:25:00] Job J25-0024 started on M04
# [Day 2 08:27:00] Job J25-0029 finished on M00 (after 05 minutes)
# [Day 2 08:37:00] Job J25-0017 finished on M02 (after 31 minutes)
# [Day 2 08:37:00] Job J25-0026 started on M02
# [Day 2 08:37:00] Job J25-0017 started on M00
# [Day 2 08:41:00] Job J25-0019 finished on M08 (after 52 minutes)
# [Day 2 08:49:00] Job J25-0031 finished on M01 (after 33 minutes)
# [Day 2 08:49:00] Job J25-0026 finished on M02 (after 12 minutes)
# [Day 2 08:49:00] Job J25-0022 started on M01
# [Day 2 08:49:00] Job J25-0031 started on M06
# [Day 2 08:57:00] Job J25-0035 finished on M09 (after 68 minutes)
# [Day 2 08:59:00] Job J25-0019 started on M09
# [Day 2 09:16:00] Job J25-0036 started on M02
# [Day 2 09:30:00] Job J25-0036 finished on M02 (after 14 minutes)
# [Day 2 09:31:00] Job J25-0023 finished on M03 (after 66 minutes)
# [Day 2 09:39:00] Job J25-0031 finished on M06 (after 50 minutes)
# [Day 2 09:39:00] Job J25-0026 started on M06
# [Day 2 09:39:00] Job J25-0031 started on M05
# [Day 2 09:52:00] Job J25-0037 started on M02
# [Day 2 09:59:00] Job J25-0024 finished on M04 (after 94 minutes)
# [Day 2 10:03:00] Job J25-0017 finished on M00 (after 86 minutes)
# [Day 2 10:03:00] Job J25-0035 started on M00
# [Day 2 10:08:00] Job J25-0026 finished on M06 (after 29 minutes)
# [Day 2 10:08:00] Job J25-0008 started on M06
# [Day 2 10:14:00] Job J25-0022 finished on M01 (after 85 minutes)
# [Day 2 10:14:00] Job J25-0006 started on M07
# [Day 2 10:14:00] Job J25-0029 started on M01
# [Day 2 10:19:00] Job J25-0009 started on M03
# [Day 2 10:20:00] Job J25-0037 finished on M02 (after 28 minutes)
# [Day 2 10:25:00] Job J25-0031 finished on M05 (after 46 minutes)
# [Day 2 10:25:00] Job J25-0026 started on M05
# [Day 2 10:31:00] Job J25-0019 finished on M09 (after 92 minutes)
# [Day 2 10:34:00] Job J25-0029 finished on M01 (after 20 minutes)
# [Day 2 10:34:00] Job J25-0017 started on M01
# [Day 2 10:46:00] Job J25-0006 finished on M07 (after 32 minutes)
# [Day 2 10:47:00] Job J25-0026 finished on M05 (after 22 minutes)
# [Day 2 10:47:00] Job J25-0029 started on M05
# [Day 2 10:47:00] Job J25-0026 started on M09
# [Day 2 10:56:00] Job J25-0035 finished on M00 (after 53 minutes)
# [Day 2 10:56:00] Job J25-0022 started on M00
# [Day 2 10:59:00] Job J25-0031 started on M07
# [Day 2 11:00:00] Job J25-0008 finished on M06 (after 52 minutes)
# [Day 2 11:01:00] Job J25-0035 started on M06
# [Day 2 11:07:00] Job J25-0022 finished on M00 (after 11 minutes)
# [Day 2 11:07:00] Job J25-0020 started on M00
# [Day 2 11:07:00] Job J25-0022 started on M02
# [Day 2 11:17:00] Job J25-0026 finished on M09 (after 30 minutes)
# [Day 2 11:21:00] Job J25-0017 finished on M01 (after 47 minutes)
# [Day 2 11:31:00] Job J25-0009 finished on M03 (after 72 minutes)
# [Day 2 11:35:00] Job J25-0025 started on M01
# [Day 2 11:38:00] Job J25-0018 started on M03
# [Day 2 11:46:00] Job J25-0000 started on M08
# [Day 2 11:47:00] Job J25-0031 finished on M07 (after 48 minutes)
# [Day 2 11:57:00] Job J25-0029 finished on M05 (after 70 minutes)
# [Day 2 11:57:00] Job J25-0023 started on M05
# [Day 2 11:59:00] Job J25-0022 finished on M02 (after 52 minutes)
# [Day 2 12:01:00] Job J25-0020 finished on M00 (after 54 minutes)
# [Day 2 12:01:00] Job J25-0037 started on M00
# [Day 2 12:03:00] Job J25-0035 finished on M06 (after 62 minutes)
# [Day 2 12:06:00] Job J25-0022 started on M06
# [Day 2 12:06:00] Job J25-0035 started on M04
# [Day 2 12:12:00] Job J25-0035 finished on M04 (after 06 minutes)
# [Day 2 12:13:00] Job J25-0022 finished on M06 (after 07 minutes)
# [Day 2 12:13:00] Job J25-0024 started on M06
# [Day 2 12:24:00] Job J25-0024 finished on M06 (after 11 minutes)
# [Day 2 12:40:00] Job J25-0023 finished on M05 (after 43 minutes)
# [Day 2 12:40:00] Job J25-0019 started on M05
# [Day 2 12:54:00] Job J25-0025 finished on M01 (after 79 minutes)
# [Day 2 12:59:00] Job J25-0037 finished on M00 (after 58 minutes)
# [Day 2 13:03:00] Job J25-0000 finished on M08 (after 77 minutes)
# [Day 2 13:03:00] Job J25-0026 started on M08
# [Day 2 13:06:00] Job J25-0016 started on M01
# [Day 2 13:08:00] Job J25-0018 finished on M03 (after 90 minutes)
# [Day 2 13:08:00] Job J25-0029 started on M03
# [Day 2 13:14:00] Job J25-0025 started on M00
# [Day 2 13:26:00] Job J25-0021 started on M02
# [Day 2 13:28:00] Job J25-0019 finished on M05 (after 48 minutes)
# [Day 2 13:28:00] Job J25-0018 started on M05
# [Day 2 13:37:00] Job J25-0029 finished on M03 (after 29 minutes)
# [Day 2 13:37:00] Job J25-0019 started on M03
# [Day 2 13:37:00] Job J25-0029 started on M04
# [Day 2 13:52:00] Job J25-0016 finished on M01 (after 46 minutes)
# [Day 2 13:52:00] Job J25-0037 started on M01
# [Day 2 13:57:00] Job J25-0002 started on M09
# [Day 2 14:20:00] Job J25-0002 finished on M09 (after 23 minutes)
# [Day 2 14:24:00] Job J25-0018 finished on M05 (after 56 minutes)
# [Day 2 14:24:00] Job J25-0017 started on M05
# [Day 2 14:28:00] Job J25-0026 finished on M08 (after 85 minutes)
# [Day 2 14:29:00] Job J25-0022 started on M08
# [Day 2 14:29:00] Job J25-0026 started on M07
# [Day 2 14:32:00] Job J25-0025 finished on M00 (after 78 minutes)
# [Day 2 14:33:00] Job J25-0037 finished on M01 (after 41 minutes)
# [Day 2 14:35:00] Job J25-0021 finished on M02 (after 69 minutes)
# [Day 2 14:35:00] Job J25-0019 finished on M03 (after 58 minutes)
# [Day 2 14:39:00] Job J25-0016 started on M00
# [Day 2 14:39:00] Job J25-0025 started on M03
# [Day 2 14:50:00] Job J25-0020 started on M02
# [Day 2 14:50:00] Job J25-0021 started on M01
# [Day 2 14:52:00] Job J25-0021 finished on M01 (after 02 minutes)
# [Day 2 14:53:00] Job J25-0029 finished on M04 (after 76 minutes)
# [Day 2 15:03:00] Job J25-0026 finished on M07 (after 34 minutes)
# [Day 2 15:10:00] Job J25-0016 finished on M00 (after 31 minutes)
# [Day 2 15:12:00] Job J25-0022 finished on M08 (after 43 minutes)
# [Day 2 15:16:00] Job J25-0036 started on M00
# [Day 2 15:17:00] Job J25-0025 finished on M03 (after 38 minutes)
# [Day 2 15:18:00] Job J25-0016 started on M03
# [Day 2 15:23:00] Job J25-0036 finished on M00 (after 07 minutes)
# [Day 2 15:23:00] Job J25-0036 started on M01
# [Day 2 15:33:00] Job J25-0024 started on M08
# [Day 2 15:33:00] Job J25-0022 started on M09
# [Day 2 15:41:00] Job J25-0036 finished on M01 (after 18 minutes)
# [Day 2 15:46:00] Job J25-0032 started on M04
# [Day 2 16:08:00] Job J25-0017 finished on M05 (after 104 minutes)
# [Day 2 16:08:00] Job J25-0037 started on M05
# [Day 2 16:11:00] Job J25-0016 finished on M03 (after 53 minutes)
# [Day 2 16:15:00] Job J25-0024 finished on M08 (after 42 minutes)
# [Day 2 16:25:00] Job J25-0029 started on M08
# [Day 2 16:25:00] Job J25-0024 started on M07
# [Day 2 16:28:00] Job J25-0020 finished on M02 (after 98 minutes)
# [Day 2 16:28:00] Job J25-0016 started on M02
# [Day 2 16:42:00] Job J25-0016 finished on M02 (after 14 minutes)
# [Day 2 16:42:00] Job J25-0025 started on M02
# [Day 2 16:42:00] Job J25-0016 started on M06
# [Day 2 16:45:00] Job J25-0032 finished on M04 (after 59 minutes)
# [Day 2 16:45:00] Job J25-0020 started on M04
# [Day 2 16:46:00] Job J25-0029 finished on M08 (after 21 minutes)
# [Day 2 16:59:00] Job J25-0037 finished on M05 (after 51 minutes)
# [Day 2 16:59:00] Job J25-0036 started on M05
# [Day 2 17:13:00] Job J25-0016 finished on M06 (after 31 minutes)
# [Day 2 17:14:00] Job J25-0022 finished on M09 (after 101 minutes)
# [Day 2 17:38:00] Job J25-0024 finished on M07 (after 73 minutes)
# [Day 2 17:50:00] Job J25-0029 started on M07
# [Day 2 17:54:00] Job J25-0020 finished on M04 (after 69 minutes)
# [Day 2 17:56:00] Job J25-0019 started on M04
# [Day 2 17:56:00] Job J25-0020 started on M09
# [Day 2 17:57:00] Job J25-0025 finished on M02 (after 75 minutes)
# [Day 2 17:57:00] Job J25-0018 started on M02
# [Day 2 17:57:00] Job J25-0025 started on M08
# [Day 2 18:02:00] Job J25-0024 started on M03
# [Day 2 18:05:00] Job J25-0036 finished on M05 (after 66 minutes)
# [Day 2 18:05:00] Job J25-0016 started on M05
# [Day 2 18:07:00] Job J25-0020 finished on M09 (after 11 minutes)
# [Day 2 18:26:00] Job J25-0016 finished on M05 (after 21 minutes)
# [Day 2 18:26:00] Job J25-0022 started on M05
# [Day 2 18:26:00] Job J25-0016 started on M09
# [Day 2 18:42:00] Job J25-0029 finished on M07 (after 52 minutes)
# [Day 2 18:57:00] Job J25-0016 finished on M09 (after 31 minutes)
# [Day 2 18:57:00] Job J25-0029 started on M09
# [Day 2 19:04:00] Job J25-0022 finished on M05 (after 38 minutes)
# [Day 2 19:04:00] Job J25-0021 started on M05
# [Day 2 19:30:00] Job J25-0018 finished on M02 (after 93 minutes)
# [Day 2 19:30:00] Job J25-0023 started on M02
# [Day 2 19:35:00] Job J25-0025 finished on M08 (after 98 minutes)
# [Day 2 19:35:00] Job J25-0016 started on M08
# [Day 2 19:36:00] Job J25-0019 finished on M04 (after 100 minutes)
# [Day 2 19:36:00] Job J25-0017 started on M04
# [Day 2 19:38:00] Job J25-0024 finished on M03 (after 96 minutes)
# [Day 2 19:38:00] Job J25-0036 started on M03
# [Day 2 19:55:00] Job J25-0021 finished on M05 (after 51 minutes)
# [Day 2 19:55:00] Job J25-0025 started on M05
# [Day 2 20:05:00] Job J25-0025 finished on M05 (after 10 minutes)
# [Day 2 20:05:00] Job J25-0025 started on M07
# [Day 2 20:10:00] Job J25-0017 finished on M04 (after 34 minutes)
# [Day 2 20:10:00] Job J25-0036 finished on M03 (after 32 minutes)
# [Day 2 20:10:00] Job J25-0037 started on M04
# [Day 2 20:10:00] Job J25-0020 started on M03
# [Day 2 20:15:00] Job J25-0029 finished on M09 (after 78 minutes)
# [Day 2 20:15:00] Job J25-0018 started on M09
# [Day 2 20:16:00] Job J25-0025 finished on M07 (after 11 minutes)
# [Day 2 20:16:00] Job J25-0025 started on M06
# [Day 2 20:21:00] Job J25-0035 started on M07
# [Day 2 20:25:00] Job J25-0018 finished on M09 (after 10 minutes)
# [Day 2 20:25:00] Job J25-0024 started on M09
# [Day 2 20:41:00] Job J25-0037 finished on M04 (after 31 minutes)
# [Day 2 20:41:00] Job J25-0036 started on M04
# [Day 2 20:43:00] Job J25-0023 finished on M02 (after 73 minutes)
# [Day 2 20:43:00] Job J25-0024 finished on M09 (after 18 minutes)
# [Day 2 20:43:00] Job J25-0023 started on M09
# [Day 2 20:46:00] Job J25-0035 finished on M07 (after 25 minutes)
# [Day 2 20:55:00] Job J25-0023 finished on M09 (after 12 minutes)
# [Day 2 21:05:00] Job J25-0016 finished on M08 (after 90 minutes)
# [Day 2 21:05:00] Job J25-0016 started on M07
# [Day 2 21:12:00] Job J25-0020 finished on M03 (after 62 minutes)
# [Day 2 21:12:00] Job J25-0022 started on M03
# [Day 2 21:12:00] Job J25-0020 started on M01
# [Day 2 21:36:00] Job J25-0016 finished on M07 (after 31 minutes)
# [Day 2 21:38:00] Job J25-0025 finished on M06 (after 82 minutes)
# [Day 2 21:38:00] Job J25-0023 started on M06
# [Day 2 21:38:00] Job J25-0025 started on M09
# [Day 2 21:51:00] Job J25-0020 finished on M01 (after 39 minutes)
# [Day 2 21:54:00] Job J25-0036 finished on M04 (after 73 minutes)
# [Day 2 21:54:00] Job J25-0036 started on M08
# [Day 2 22:04:00] Job J25-0022 finished on M03 (after 52 minutes)
# [Day 2 22:04:00] Job J25-0021 started on M03
# [Day 2 22:04:00] Job J25-0022 started on M04
# [Day 2 22:16:00] Job J25-0036 finished on M08 (after 22 minutes)
# [Day 2 22:16:00] Job J25-0036 started on M07
# [Day 2 22:18:00] Job J25-0023 finished on M06 (after 40 minutes)
# [Day 2 22:18:00] Job J25-0018 started on M06
# [Day 2 22:25:00] Job J25-0025 finished on M09 (after 47 minutes)
# [Day 2 22:56:00] Job J25-0018 finished on M06 (after 38 minutes)
# [Day 2 22:56:00] Job J25-0020 started on M06
# [Day 2 22:59:00] Job J25-0036 finished on M07 (after 43 minutes)
# [Day 2 22:59:00] Job J25-0023 started on M07
# [Day 2 22:59:00] Job J25-0036 started on M09
# [Day 2 23:02:00] Job J25-0028 started on M00
# [Day 2 23:18:00] Job J25-0022 finished on M04 (after 74 minutes)
# [Day 2 23:29:00] Job J25-0021 finished on M03 (after 85 minutes)
# [Day 2 23:29:00] Job J25-0021 started on M08
# [Day 2 23:36:00] Job J25-0028 finished on M00 (after 34 minutes)
# [Day 2 23:36:00] Job J25-0028 started on M01
# [Day 2 23:43:00] Job J25-0020 finished on M06 (after 47 minutes)
# [Day 2 23:43:00] Job J25-0017 started on M06
# [Day 2 23:43:00] Job J25-0020 started on M05

# %%
df_execution2 = simulation.get_finished_operations_df()
df_execution2
# Out:
#           Job  Routing_ID  Arrival  Operation Machine   Start  \
# 0    J25-0000           8       79          9     M08  3586.0
# 1    J25-0002           0      198          9     M09  3717.0
# 2    J25-0003           2      243          9     M04  3346.0
# 3    J25-0004           3      287          6     M07  2977.0
# 4    J25-0004           3      287          7     M03  3069.0
# 5    J25-0004           3      287          8     M09  3174.0
# ..        ...         ...      ...        ...     ...     ...
# 146  J25-0036           4     2734          7     M07  4216.0
# 147  J25-0037           7     2801          0     M02  3472.0
# 148  J25-0037           7     2801          1     M00  3601.0
# 149  J25-0037           7     2801          2     M01  3712.0
# 150  J25-0037           7     2801          3     M05  3848.0
# 151  J25-0037           7     2801          4     M04  4090.0
#
#      Processing Time     End
# 0               77.0  3663.0
# 1               23.0  3740.0
# 2               39.0  3385.0
# 3               92.0  3069.0
# 4               91.0  3160.0
# 5               22.0  3196.0
# ..               ...     ...
# 146             43.0  4259.0
# 147             28.0  3500.0
# 148             58.0  3659.0
# 149             41.0  3753.0
# 150             51.0  3899.0
# 151             31.0  4121.0
#
# [152 rows x 8 columns]

# %%
gantt.get_plot(df_execution2, perspective="Machine")

# %%
df_active2 = simulation.get_active_operations_df()
df_active2
# Out:
#    Routing_ID       Job  Operation Machine  Arrival   Start  Planned Duration  \
# 0           7  J25-0017          5     M06     1864  4303.0                88
# 1           1  J25-0020          7     M05     1935  4303.0                46
# 2           5  J25-0021          4     M08     1952  4289.0                48
# 3           8  J25-0023          7     M07     2055  4259.0                89
# 4           0  J25-0028          1     M01     2282  4296.0                78
# 5           4  J25-0036          8     M09     2734  4259.0                72
#
#    Processing Time  Expected End     End
# 0             80.0        4391.0  4383.0
# 1             38.0        4349.0  4341.0
# 2             51.0        4337.0  4340.0
# 3             89.0        4348.0  4348.0
# 4             84.0        4374.0  4380.0
# 5             74.0        4331.0  4333.0

# %%
df_not_started2 = simulation.get_not_started_operations_df(df_schedule)
df_not_started2
# Out:
#           Job  Routing_ID  Arrival  Ready Time  Deadline  Operation Machine  \
# 0    J25-0000           8       79        1440      3660          0     M00
# 1    J25-0000           8       79        1440      3660          1     M01
# 2    J25-0000           8       79        1440      3660          2     M03
# 3    J25-0000           8       79        1440      3660          3     M05
# 4    J25-0000           8       79        1440      3660          4     M02
# 5    J25-0000           8       79        1440      3660          5     M09
# ..        ...         ...      ...         ...       ...        ...     ...
# 138  J25-0015           5     1436        1440      2981          3     M03
# 139  J25-0015           5     1436        1440      2981          4     M08
# 140  J25-0015           5     1436        1440      2981          5     M09
# 141  J25-0015           5     1436        1440      2981          6     M00
# 142  J25-0015           5     1436        1440      2981          7     M06
# 143  J25-0015           5     1436        1440      2981          8     M04
#
#      Start  Processing Time   End
# 0     1555               76  1631
# 1     1825               69  1894
# 2     2231               76  2307
# 3     2422               51  2473
# 4     2473               85  2558
# 5     2630               11  2641
# ..     ...              ...   ...
# 138   1799               95  1894
# 139   1988               48  2036
# 140   2036               72  2108
# 141   2110               47  2157
# 142   2157               65  2222
# 143   2254                6  2260
#
# [144 rows x 10 columns]

# %% [markdown]
# #### Check der Bedingungen des kombinierten Datensatzes aus den beiden Simulationsdaten

# %%
df_combined = pd.concat([df_execution, df_execution2], ignore_index=True)
gantt.get_plot(df_combined, perspective="Machine")
check.is_machine_conflict_free(df_combined)
check.is_operation_sequence_correct(df_combined)
check.is_job_timing_correct(df_combined)
check.is_start_correct(df_combined)
# Out:
# + Keine Maschinenkonflikte gefunden
# + Alle Gruppen wurden in korrekter Operationsreihenfolge ausgeführt.
# + Alle technologischen Abhängigkeiten wurden eingehalten.
# + Alle Operation starten erst nach Arrival des Job
# True
