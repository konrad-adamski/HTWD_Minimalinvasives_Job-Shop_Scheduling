# %% [markdown]
# # Rescheduling mit Tardiness (Summe)
# > Planunghorizont Tag 0: 2 Tage
# > Rescheduling des Tages 1

# %%
# Datenzugriff
from configs.config import get_path

# Utils
import src.utils.presenter as show
from src.utils.production_process import convert
from src.utils.production_process import initialize as init
from src.utils.analize import check_constrains as check

from src.utils.production_process import time_determination as term
from src.utils.production_process import gen_deadline as gen_deadline
from src.utils.production_process import filter as process_filter

# Solver Model
from src.models.cp import lateness_scheduling as cp_late_schedule
from src.models.cp import lateness_rescheduling as cp_late_reschedule
import src.models.heuristics.fcfs as fcfs


# Simulation
from src.simulation.ProductionDaySimulation import ProductionDaySimulation


# Extern
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 21)

# %%
max_time = 60 * 10 # 10 min

# %%
basic_data_path = get_path("data", "basic")
day_count = 1

df_instance = pd.read_csv(basic_data_path / "instance.csv")
df_jssp, df_job_arrivals = init.create_production_orders_for_shifts(df_template=df_instance, shift_count=day_count,
                                                                 u_b_mmax= 0.94, shift_length=1440, shuffle=True,
                                                                 job_seed=40, arrival_seed=80)

df_job_times = gen_deadline.get_times_df(df_jssp, df_job_arrivals, fcfs.schedule_with_arrivals, target_service=1.0)
df_job_times
# Out:
# Schedule-Informationen:
#   Makespan: 2400
#     Job  Production_Plan_ID  Arrival  Deadline
# 0     0                   0       49     848.0
# 1     1                   1      130    1162.0
# 2     2                   2      151    1300.0
# 3     3                   3      226    1551.0
# 4     4                   4      386    1181.0
# 5     5                   5      464    1467.0
# 6     6                   6      480    1322.0
# 7     7                   7      506    1596.0
# 8     8                   8      526    1734.0
# 9     9                   9      535    1627.0
# 10   10                   0      922    1721.0
# 11   11                   9      928    2020.0
# 12   12                   8      950    2158.0
# 13   13                   2     1001    2150.0
# 14   14                   4     1127    1922.0
# 15   15                   7     1142    2232.0
# 16   16                   1     1254    2286.0
# 17   17                   3     1285    2610.0
# 18   18                   5     1397    2400.0
# 19   19                   6     1398    2240.0

# %%
df_job_times['Job'] = df_job_times['Job'].astype(str)
df_jssp['Job'] = df_jssp['Job'].astype(str)

# %%
# Rundung für CP 
df_job_times["Arrival"] = np.floor(df_job_times["Arrival"]).astype(int)
df_job_times["Deadline"] = np.ceil(df_job_times["Deadline"]).astype(int)
df_job_times
# Out:
#    Job  Production_Plan_ID  Arrival  Deadline
# 0    0                   0       49       848
# 1    1                   1      130      1162
# 2    2                   2      151      1300
# 3    3                   3      226      1551
# 4    4                   4      386      1181
# 5    5                   5      464      1467
# 6    6                   6      480      1322
# 7    7                   7      506      1596
# 8    8                   8      526      1734
# 9    9                   9      535      1627
# 10  10                   0      922      1721
# 11  11                   9      928      2020
# 12  12                   8      950      2158
# 13  13                   2     1001      2150
# 14  14                   4     1127      1922
# 15  15                   7     1142      2232
# 16  16                   1     1254      2286
# 17  17                   3     1285      2610
# 18  18                   5     1397      2400
# 19  19                   6     1398      2240

# %%
# b) Bestimmung der "Ready Time"
df_job_times['Ready Time'] = ((df_job_times['Arrival'] // 1440) + 1) * 1440

# c) Processing Time
processing_time = df_jssp.groupby('Job')['Processing Time'].sum()
df_job_times = pd.merge(df_job_times, processing_time, on='Job')

# d) Bestimmung des Slacks
df_job_times['Slack'] = df_job_times['Deadline'] - (df_job_times['Ready Time'] + df_job_times['Processing Time'])

# e) Anpassung der Deadlines
min_slack = df_job_times['Slack'].min()

if min_slack < 0:
    df_job_times["Deadline"] = df_job_times["Deadline"] + abs(min_slack) + 120
df_job_times

# f) erneute Bestimmung des Slacks
df_job_times['Slack'] = df_job_times['Deadline'] - (df_job_times['Ready Time'] + df_job_times['Processing Time'])
df_job_times
# Out:
#    Job  Production_Plan_ID  Arrival  Deadline  Ready Time  Processing Time  \
# 0    0                   0       49      1955        1440              395
# 1    1                   1      130      2269        1440              510
# 2    2                   2      151      2407        1440              568
# 3    3                   3      226      2658        1440              655
# 4    4                   4      386      2288        1440              393
# 5    5                   5      464      2574        1440              496
# 6    6                   6      480      2429        1440              416
# 7    7                   7      506      2703        1440              539
# 8    8                   8      526      2841        1440              597
# 9    9                   9      535      2734        1440              540
# 10  10                   0      922      2828        1440              395
# 11  11                   9      928      3127        1440              540
# 12  12                   8      950      3265        1440              597
# 13  13                   2     1001      3257        1440              568
# 14  14                   4     1127      3029        1440              393
# 15  15                   7     1142      3339        1440              539
# 16  16                   1     1254      3393        1440              510
# 17  17                   3     1285      3717        1440              655
# 18  18                   5     1397      3507        1440              496
# 19  19                   6     1398      3347        1440              416
#
#     Slack
# 0     120
# 1     319
# 2     399
# 3     563
# 4     455
# 5     638
# 6     573
# 7     724
# 8     804
# 9     754
# 10    993
# 11   1147
# 12   1228
# 13   1249
# 14   1196
# 15   1360
# 16   1443
# 17   1622
# 18   1571
# 19   1491

# %%
day_length = 1440

# %% [markdown]
# ## I) Tag 1

# %%
day_numb = 1

day_start = day_length*day_numb 
day_end = day_start + day_length
print(f"Tag {day_numb:02d}: [{day_start}, {day_end})")
# Out:
# Tag 01: [1440, 2880)

# %%
def filter_ops_and_jobs_by_ready_time(df_job_times: pd.DataFrame, df_jssp: pd.DataFrame, 
                              ready_time_col = "Ready Time", ready_time: int = 0) -> tuple[pd.DataFrame, pd.DataFrame]:

    # Jobs zeitlich filtern
    time_filter = df_job_times[ready_time_col] == ready_time
    df_job_times_filtered = df_job_times[time_filter].copy()

    # Operationen nach (gefilterten) Jobs filtern
    jobs = df_job_times_filtered["Job"]
    df_jssp_filtered = df_jssp[df_jssp["Job"].isin(jobs)].copy()
    return df_job_times_filtered, df_jssp_filtered

# %%
df_job_times_curr, df_jssp_curr = filter_ops_and_jobs_by_ready_time(df_job_times, df_jssp, ready_time = day_start)
df_job_times_curr
# Out:
#    Job  Production_Plan_ID  Arrival  Deadline  Ready Time  Processing Time  \
# 0    0                   0       49      1955        1440              395
# 1    1                   1      130      2269        1440              510
# 2    2                   2      151      2407        1440              568
# 3    3                   3      226      2658        1440              655
# 4    4                   4      386      2288        1440              393
# 5    5                   5      464      2574        1440              496
# 6    6                   6      480      2429        1440              416
# 7    7                   7      506      2703        1440              539
# 8    8                   8      526      2841        1440              597
# 9    9                   9      535      2734        1440              540
# 10  10                   0      922      2828        1440              395
# 11  11                   9      928      3127        1440              540
# 12  12                   8      950      3265        1440              597
# 13  13                   2     1001      3257        1440              568
# 14  14                   4     1127      3029        1440              393
# 15  15                   7     1142      3339        1440              539
# 16  16                   1     1254      3393        1440              510
# 17  17                   3     1285      3717        1440              655
# 18  18                   5     1397      3507        1440              496
# 19  19                   6     1398      3347        1440              416
#
#     Slack
# 0     120
# 1     319
# 2     399
# 3     563
# 4     455
# 5     638
# 6     573
# 7     724
# 8     804
# 9     754
# 10    993
# 11   1147
# 12   1228
# 13   1249
# 14   1196
# 15   1360
# 16   1443
# 17   1622
# 18   1571
# 19   1491

# %% [markdown]
# ### A) Scheduling für Tag 1

# %%
# Scheduling
df_schedule = cp_late_schedule.solve_jssp_sum(df_jssp, df_job_times, schedule_start = day_start,
                                         msg=False, timeLimit=max_time)
df_schedule
# Out:
# Solver-Status           : OPTIMAL
# Summe Absolute Lateness : 33.0
# Best Objective Bound    : 33.0
# Laufzeit                : 0.11 Sekunden
#     Job  Production_Plan_ID  Operation Machine  Arrival  Deadline  Start  \
# 0     0                   0          0     M00       49      1955   1440
# 1     2                   2          0     M01      151      2407   1440
# 2     4                   4          0     M02      386      2288   1440
# 3     5                   5          0     M02      464      2574   1454
# 4     1                   1          0     M00      130      2269   1469
# ..   ..                 ...        ...     ...      ...       ...    ...
# 195  17                   3          7     M03     1285      3717   3339
# 196  16                   1          9     M08     1254      3393   3363
# 197  17                   3          8     M09     1285      3717   3437
# 198  18                   5          9     M07     1397      3507   3482
# 199  17                   3          9     M05     1285      3717   3674
#
#      Processing Time   End  Lateness  Tardiness  Earliness
# 0                 29  1469      -486          0        486
# 1                 91  1531      -876          0        876
# 2                 14  1454      -834          0        834
# 3                 84  1538     -1036          0       1036
# 4                 43  1512      -757          0        757
# ..               ...   ...       ...        ...        ...
# 195               98  3437      -280          0        280
# 196               30  3393         0          0          0
# 197               22  3459      -258          0        258
# 198               25  3507         0          0          0
# 199               43  3717         0          0          0
#
# [200 rows x 12 columns]

# %%
last_ops = df_schedule.sort_values(['Job', 'Operation']).drop_duplicates('Job', keep='last')
print(show.count_column_grouped(last_ops, 'Lateness'))
# Out:
# label
# <-180           0
# -180 - -120     0
# -120 - -60      0
# -60 - 0         0
# 0              19
# 0 - 60          1
# 60 - 120        0
# 120 - 180       0
# >180            0
# Name: count, dtype: int64

# %%
show.plot_gantt(df_schedule, perspective="Machine")
check.is_machine_conflict_free(df_schedule)
check.is_operation_sequence_correct(df_schedule)
check.is_job_timing_correct(df_schedule)
check.is_start_correct(df_schedule)
# Out:
# + Keine Maschinenkonflikte gefunden
# + Alle Gruppen wurden in korrekter Operationsreihenfolge ausgeführt.
# + Alle technologischen Abhängigkeiten wurden eingehalten.
# + Alle Operation starten erst nach Arrival des Job
# True

# %% [markdown]
# ### B) Simulation

# %%
simulation = ProductionDaySimulation(df_schedule, vc=0.35)
df_execution = simulation.run(start_time = day_start, end_time=day_end)
# Out:
# [24:00:00] Job 0 started on M00
# [24:00:00] Job 2 started on M01
# [24:00:00] Job 4 started on M02
# [24:19:03] Job 4 finished on M02 (after 19 minutes 04 seconds)
# [24:19:03] Job 5 started on M02
# [24:33:10] Job 0 finished on M00 (after 33 minutes 11 seconds)
# [24:33:10] Job 1 started on M00
# [25:21:46] Job 1 finished on M00 (after 48 minutes 36 seconds)
# [25:21:46] Job 4 started on M00
# [25:27:15] Job 2 finished on M01 (after 87 minutes 15 seconds)
# [25:31:00] Job 0 started on M01
# [47:45:49] Job 10 finished on M08 (after 31 minutes 02 seconds)
# [47:45:49] Job 8 started on M08
# [47:53:33] Job 12 finished on M09 (after 11 minutes 16 seconds)
# [47:53:33] Job 16 started on M09
# [47:53:33] Job 12 started on M06
# [47:54:52] Job 9 finished on M07 (after 80 minutes 35 seconds)
# [47:54:52] Job 13 started on M07
# [47:55:58] Job 7 finished on M03 (after 97 minutes 52 seconds)
# [48:00:57] Job 16 finished on M09 (after 07 minutes 23 seconds)
# [48:04:48] Job 13 finished on M07 (after 09 minutes 56 seconds)
# [48:12:52] Job 17 finished on M04 (after 97 minutes 47 seconds)
# [48:28:16] Job 12 finished on M06 (after 34 minutes 43 seconds)
# [49:46:42] Job 8 finished on M08 (after 120 minutes 53 seconds)
#
# [49:46:42] Simulation ended! There are no more active Operations

# %%
df_plan_undone = process_filter.get_unexecuted_operations(df_schedule, df_execution)
df_plan_undone
# Out:
#    Job  Production_Plan_ID  Operation Machine  Arrival  Deadline  Start  \
# 0   11                   9          5     M09      928      3127   2614
# 1   16                   1          4     M03     1254      3393   2703
# 2   11                   9          6     M05      928      3127   2710
# 3   12                   8          7     M07      950      3265   2734
# 4   11                   9          7     M03      928      3127   2772
# ..  ..                 ...        ...     ...      ...       ...    ...
# 35  17                   3          7     M03     1285      3717   3339
# 36  16                   1          9     M08     1254      3393   3363
# 37  17                   3          8     M09     1285      3717   3437
# 38  18                   5          9     M07     1397      3507   3482
# 39  17                   3          9     M05     1285      3717   3674
#
#     Processing Time   End  Lateness  Tardiness  Earliness
# 0                76  2690      -437          0        437
# 1                69  2772      -621          0        621
# 2                47  2757      -370          0        370
# 3                89  2823      -442          0        442
# 4                52  2824      -303          0        303
# ..              ...   ...       ...        ...        ...
# 35               98  3437      -280          0        280
# 36               30  3393         0          0          0
# 37               22  3459      -258          0        258
# 38               25  3507         0          0          0
# 39               43  3717         0          0          0
#
# [40 rows x 12 columns]

# %%
if not df_execution.empty:
    show.plot_gantt(df_execution, perspective="Machine", title=f"Gantt-Diagramm ab Tag {day_numb}")
else:
    print(f"Nothing executed on day {day_numb}")

# %% [markdown]
# ## II) Tag 2
# > vereinfacht, ohne neu Aufträge (nur der Rest)

# %%
day_numb = 2

day_start = day_length*day_numb 
day_end = day_start + day_length
print(f"Tag {day_numb:02d}: [{day_start}, {day_end})")
# Out:
# Tag 02: [2880, 4320)

# %% [markdown]
# #### a) Filtern nach der aktuellen "Ready Time"

# %%
df_job_times_curr, df_jssp_curr = filter_ops_and_jobs_by_ready_time(df_job_times, df_jssp, ready_time = day_start)
df_job_times_curr
# Out:
# Empty DataFrame
# Columns: [Job, Production_Plan_ID, Arrival, Deadline, Ready Time, Processing Time, Slack]
# Index: []

# %% [markdown]
# #### b) Unerledigte Operationen

# %%
df_plan_undone
# Out:
#    Job  Production_Plan_ID  Operation Machine  Arrival  Deadline  Start  \
# 0   11                   9          5     M09      928      3127   2614
# 1   16                   1          4     M03     1254      3393   2703
# 2   11                   9          6     M05      928      3127   2710
# 3   12                   8          7     M07      950      3265   2734
# 4   11                   9          7     M03      928      3127   2772
# ..  ..                 ...        ...     ...      ...       ...    ...
# 35  17                   3          7     M03     1285      3717   3339
# 36  16                   1          9     M08     1254      3393   3363
# 37  17                   3          8     M09     1285      3717   3437
# 38  18                   5          9     M07     1397      3507   3482
# 39  17                   3          9     M05     1285      3717   3674
#
#     Processing Time   End  Lateness  Tardiness  Earliness
# 0                76  2690      -437          0        437
# 1                69  2772      -621          0        621
# 2                47  2757      -370          0        370
# 3                89  2823      -442          0        442
# 4                52  2824      -303          0        303
# ..              ...   ...       ...        ...        ...
# 35               98  3437      -280          0        280
# 36               30  3393         0          0          0
# 37               22  3459      -258          0        258
# 38               25  3507         0          0          0
# 39               43  3717         0          0          0
#
# [40 rows x 12 columns]

# %%
# Sicherstellen, dass beide DataFrames die Spalten 'Job' und 'Operation' haben
df_jssp_undone = df_jssp.merge(df_plan_undone[["Job", "Operation"]], on=["Job", "Operation"], how="inner")
df_jssp_undone
# Out:
#    Job  Production_Plan_ID  Operation Machine  Processing Time
# 0   10                   0          9     M09               21
# 1   11                   9          5     M09               76
# 2   11                   9          6     M05               47
# 3   11                   9          7     M03               52
# 4   11                   9          8     M04               90
# ..  ..                 ...        ...     ...              ...
# 35  18                   5          9     M07               25
# 36  19                   6          6     M09               32
# 37  19                   6          7     M08               89
# 38  19                   6          8     M07               30
# 39  19                   6          9     M04               55
#
# [40 rows x 5 columns]

# %%
df_job_times_undone = df_job_times[df_job_times["Job"].isin(df_jssp_undone["Job"].unique())]
df_job_times_undone
# Out:
#    Job  Production_Plan_ID  Arrival  Deadline  Ready Time  Processing Time  \
# 10  10                   0      922      2828        1440              395
# 11  11                   9      928      3127        1440              540
# 12  12                   8      950      3265        1440              597
# 13  13                   2     1001      3257        1440              568
# 14  14                   4     1127      3029        1440              393
# 15  15                   7     1142      3339        1440              539
# 16  16                   1     1254      3393        1440              510
# 17  17                   3     1285      3717        1440              655
# 18  18                   5     1397      3507        1440              496
# 19  19                   6     1398      3347        1440              416
#
#     Slack
# 10    993
# 11   1147
# 12   1228
# 13   1249
# 14   1196
# 15   1360
# 16   1443
# 17   1622
# 18   1571
# 19   1491

# %% [markdown]
# ### Zusammenführen

# %%
# Operationen
df_jssp_curr_all = pd.concat([df_jssp_curr, df_jssp_undone], ignore_index=True)
df_jssp_curr_all = df_jssp_curr_all.sort_values(by=["Job", "Operation"]).reset_index(drop=True)
df_jssp_curr_all
# Out:
#    Job  Production_Plan_ID  Operation Machine  Processing Time
# 0   10                   0          9     M09               21
# 1   11                   9          5     M09               76
# 2   11                   9          6     M05               47
# 3   11                   9          7     M03               52
# 4   11                   9          8     M04               90
# ..  ..                 ...        ...     ...              ...
# 35  18                   5          9     M07               25
# 36  19                   6          6     M09               32
# 37  19                   6          7     M08               89
# 38  19                   6          8     M07               30
# 39  19                   6          9     M04               55
#
# [40 rows x 5 columns]

# %%
df_job_times_curr_all = pd.concat([df_job_times_curr, df_job_times_undone], ignore_index=True)
df_job_times_curr_all = df_job_times_curr_all.drop_duplicates(subset="Job", keep="first").sort_values(by="Job").reset_index(drop=True)
df_job_times_curr_all
# Out:
#   Job  Production_Plan_ID  Arrival  Deadline  Ready Time  Processing Time  \
# 0  10                   0      922      2828        1440              395
# 1  11                   9      928      3127        1440              540
# 2  12                   8      950      3265        1440              597
# 3  13                   2     1001      3257        1440              568
# 4  14                   4     1127      3029        1440              393
# 5  15                   7     1142      3339        1440              539
# 6  16                   1     1254      3393        1440              510
# 7  17                   3     1285      3717        1440              655
# 8  18                   5     1397      3507        1440              496
# 9  19                   6     1398      3347        1440              416
#
#    Slack
# 0    993
# 1   1147
# 2   1228
# 3   1249
# 4   1196
# 5   1360
# 6   1443
# 7   1622
# 8   1571
# 9   1491

# %% [markdown]
# ### A) Rescheduling für Tag 2

# %%
# Reduktion der bereits ausgeführten Operationen, die im heutigen Plan hineinlaufen
df_execution_important = df_execution[df_execution["End"] >= day_start]
df_execution_important
# Out:
#     Job  Production_Plan_ID  Operation Machine  Arrival    Start  \
# 40   12                   8          6     M06      950  2873.56
# 47   13                   2          6     M07     1001  2874.87
# 66   16                   1          3     M09     1254  2873.56
# 70   17                   3          3     M04     1285  2795.09
# 149   8                   8          9     M08      526  2865.82
#
#      Processing Time      End
# 40             34.72  2908.28
# 47              9.94  2884.81
# 66              7.39  2880.95
# 70             97.79  2892.88
# 149           120.89  2986.71

# %%
df_reschedule = cp_late_reschedule.solve_jssp_by_tardiness_and_earliness_with_devpen(df_jssp_curr_all, df_job_times_curr_all,
                                                                                     df_execution_important,
                                                                                     df_original_plan = df_schedule, w_t = 5,
                                                                                     r = 0.5,
                                                                                     reschedule_start = day_start, msg=False, 
                                                                                     timeLimit=max_time, gapRel= 0)
df_reschedule
# Out:
# Solver-Status         : OPTIMAL
# Objective Value       : 297750.00
# Best Objective Bound  : 297750.00
# Laufzeit              : 0.70 Sekunden
# Deviation terms       : 40
#    Job  Production_Plan_ID  Operation Machine  Arrival  Deadline  Start  \
# 0   10                   0          9     M09      922      2828   2881
# 1   16                   1          4     M03     1254      3393   2881
# 2   11                   9          5     M09      928      3127   2902
# 3   12                   8          7     M07      950      3265   2909
# 4   17                   3          4     M06     1285      3717   2909
# ..  ..                 ...        ...     ...      ...       ...    ...
# 35  17                   3          7     M03     1285      3717   3347
# 36  16                   1          9     M08     1254      3393   3363
# 37  17                   3          8     M09     1285      3717   3445
# 38  18                   5          9     M07     1397      3507   3482
# 39  17                   3          9     M05     1285      3717   3674
#
#     Processing Time   End  Lateness  Tardiness  Earliness
# 0                21  2902        74         74          0
# 1                69  2950      -443          0        443
# 2                76  2978      -149          0        149
# 3                89  2998      -267          0        267
# 4                 9  2918      -799          0        799
# ..              ...   ...       ...        ...        ...
# 35               98  3445      -272          0        272
# 36               30  3393         0          0          0
# 37               22  3467      -250          0        250
# 38               25  3507         0          0          0
# 39               43  3717         0          0          0
#
# [40 rows x 12 columns]

# %%
df_reschedule
# Out:
#    Job  Production_Plan_ID  Operation Machine  Arrival  Deadline  Start  \
# 0   10                   0          9     M09      922      2828   2881
# 1   16                   1          4     M03     1254      3393   2881
# 2   11                   9          5     M09      928      3127   2902
# 3   12                   8          7     M07      950      3265   2909
# 4   17                   3          4     M06     1285      3717   2909
# ..  ..                 ...        ...     ...      ...       ...    ...
# 35  17                   3          7     M03     1285      3717   3347
# 36  16                   1          9     M08     1254      3393   3363
# 37  17                   3          8     M09     1285      3717   3445
# 38  18                   5          9     M07     1397      3507   3482
# 39  17                   3          9     M05     1285      3717   3674
#
#     Processing Time   End  Lateness  Tardiness  Earliness
# 0                21  2902        74         74          0
# 1                69  2950      -443          0        443
# 2                76  2978      -149          0        149
# 3                89  2998      -267          0        267
# 4                 9  2918      -799          0        799
# ..              ...   ...       ...        ...        ...
# 35               98  3445      -272          0        272
# 36               30  3393         0          0          0
# 37               22  3467      -250          0        250
# 38               25  3507         0          0          0
# 39               43  3717         0          0          0
#
# [40 rows x 12 columns]

# %%
last_ops = df_reschedule.sort_values(['Job', 'Operation']).drop_duplicates('Job', keep='last')
print(show.count_column_grouped(last_ops, 'Lateness'))
# Out:
# label
# <-180          0
# -180 - -120    0
# -120 - -60     0
# -60 - 0        1
# 0              5
# 0 - 60         2
# 60 - 120       2
# 120 - 180      0
# >180           0
# Name: count, dtype: int64

# %%
show.plot_gantt(df_reschedule, perspective="Machine")
check.is_machine_conflict_free(df_reschedule)
check.is_operation_sequence_correct(df_reschedule)
check.is_job_timing_correct(df_reschedule)
check.is_start_correct(df_reschedule)
# Out:
# + Keine Maschinenkonflikte gefunden
# + Alle Gruppen wurden in korrekter Operationsreihenfolge ausgeführt.
# + Alle technologischen Abhängigkeiten wurden eingehalten.
# + Alle Operation starten erst nach Arrival des Job
# True

# %% [markdown]
# ### Combi aus Simulation und Neuplannung

# %%
df_combined = pd.concat([df_execution, df_reschedule], ignore_index=True)
df_combined
# Out:
#     Job  Production_Plan_ID  Operation Machine  Arrival    Start  \
# 0     0                   0          0     M00       49  1440.00
# 1     0                   0          1     M01       49  1531.00
# 2     0                   0          2     M02       49  1675.38
# 3     0                   0          3     M03       49  1744.28
# 4     0                   0          4     M04       49  1825.33
# ..   ..                 ...        ...     ...      ...      ...
# 195  17                   3          7     M03     1285  3347.00
# 196  16                   1          9     M08     1254  3363.00
# 197  17                   3          8     M09     1285  3445.00
# 198  18                   5          9     M07     1397  3482.00
# 199  17                   3          9     M05     1285  3674.00
#
#      Processing Time      End  Deadline  Lateness  Tardiness  Earliness
# 0              33.18  1473.18       NaN       NaN        NaN        NaN
# 1             108.04  1639.04       NaN       NaN        NaN        NaN
# 2              11.92  1687.30       NaN       NaN        NaN        NaN
# 3              39.62  1783.90       NaN       NaN        NaN        NaN
# 4              49.05  1874.38       NaN       NaN        NaN        NaN
# ..               ...      ...       ...       ...        ...        ...
# 195            98.00  3445.00    3717.0    -272.0        0.0      272.0
# 196            30.00  3393.00    3393.0       0.0        0.0        0.0
# 197            22.00  3467.00    3717.0    -250.0        0.0      250.0
# 198            25.00  3507.00    3507.0       0.0        0.0        0.0
# 199            43.00  3717.00    3717.0       0.0        0.0        0.0
#
# [200 rows x 12 columns]

# %%
df = df_combined
show.plot_gantt_machines(df)
check.is_machine_conflict_free(df)
check.is_operation_sequence_correct(df)
check.is_job_timing_correct(df)
check.is_start_correct(df)
# Out:
# + Keine Maschinenkonflikte gefunden
# + Alle Gruppen wurden in korrekter Operationsreihenfolge ausgeführt.
# + Alle technologischen Abhängigkeiten wurden eingehalten.
# + Alle Operation starten erst nach Arrival des Job
# True
