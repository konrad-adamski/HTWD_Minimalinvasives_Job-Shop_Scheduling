# %%
import sys
import os

# Projektverzeichnis
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))

# Füge dem sys.path hinzu, falls noch nicht vorhanden
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
# Datenzugriff
from models import *


# Utils
import src.utils.presenter as show
from src.utils.analize import check_constrains as check

from src.utils.production_process import time_determination as term
from src.utils.production_process import filter as process_filter

# Solver Model
from src.models.cp import lateness_scheduling as cp_late_schedule
from src.models.cp import lateness_rescheduling as cp_late_reschedule
import src.models.heuristics.fcfs as fcfs


# Simulation
from src.simulation.ProductionSimulation import ProductionSimulation

# Extern
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 21)

# %%
max_time = 60 * 30 # 30 min

# %% [markdown]
# ## Laden der Produktionsaufträge

# %%
df_jobs_times = Job.get_dataframe(version="lateness")
df_jobs_times
# Out:
#            Job Routing_ID  Arrival  Ready Time  Deadline  Status   Version
# 0     J25-0000          8       79        1440      3660    open  lateness
# 1     J25-0001          6      129        1440      2338  closed  lateness
# 2     J25-0002          0      198        1440      3744    open  lateness
# 3     J25-0003          2      243        1440      3379    open  lateness
# 4     J25-0004          3      287        1440      4856    open  lateness
# ...        ...        ...      ...         ...       ...     ...       ...
# 7245  J25-7245          9   518089      518400    519640    open  lateness
# 7246  J25-7246          6   518116      518400    520157    open  lateness
# 7247  J25-7247          1   518184      518400    520172    open  lateness
# 7248  J25-7248          0   518188      518400    520490    open  lateness
# 7249  J25-7249          4   518302      518400    522163    open  lateness
#
# [7250 rows x 7 columns]

# %%
def get_jssp_for_jobs(df_jobs_times, df_routings):
    """
    Erstellt ein JSSP-kompatibles DataFrame durch Verknüpfung von Job-Zeitdaten mit Routings.

    Parameter:
    - df_jobs_times: DataFrame mit mindestens den Spalten 'Job' und 'Routing_ID'.
    - df_routings: DataFrame mit Spalte 'Routing_ID' und den zugehörigen Operationsdaten.

    Rückgabe:
    - df_jssp: DataFrame mit allen für das JSSP notwendigen Informationen, inklusive 'Job' und den Operationen.
    """
    # 1. Relevante Spalten extrahieren
    df_job_ids = df_jobs_times[['Job', 'Routing_ID']].copy()

    # 2. Merge mit df_routings über Routing_ID
    df_jssp = df_job_ids.merge(df_routings, on='Routing_ID')

    return df_jssp

# Routings
df_routings = RoutingOperation.get_dataframe()
df_jssp = get_jssp_for_jobs(df_jobs_times, df_routings)
df_jssp
# Out:
#             Job Routing_ID  Operation Machine  Processing Time
# 0      J25-0000          8          0     M00               76
# 1      J25-0000          8          1     M01               69
# 2      J25-0000          8          2     M03               76
# 3      J25-0000          8          3     M05               51
# 4      J25-0000          8          4     M02               85
# ...         ...        ...        ...     ...              ...
# 72495  J25-7249          4          5     M04               69
# 72496  J25-7249          4          6     M08               21
# 72497  J25-7249          4          7     M07               49
# 72498  J25-7249          4          8     M09               72
# 72499  J25-7249          4          9     M06               53
#
# [72500 rows x 5 columns]

# %% [markdown]
# ## Laden der Initialisierungsdaten vom Tag 1

# %%
day_numb = 1

# %%
df_schedule = Schedule.get_schedule_as_dataframe(date = 1, version="lateness")
df_schedule
# Out:
# ℹ️ Achtung: 2 Schedules gefunden – letzter Eintrag (ID 2) wird verwendet.
#           Job Routing_ID  Operation Machine  Arrival  Deadline  Start  \
# 0    J25-0005          1          0     M00      498      3106   1440
# 1    J25-0007          5          0     M02      925      2929   1440
# 2    J25-0013          3          0     M01     1192      2567   1440
# 3    J25-0011          1          0     M00     1030      3210   1483
# 4    J25-0001          6          0     M01      129      2338   1521
# ..        ...        ...        ...     ...      ...       ...    ...
# 155  J25-0009          7          9     M03     1004      3578   3499
# 156  J25-0000          8          9     M08       79      3660   3586
# 157  J25-0002          0          9     M09      198      3744   3723
# 158  J25-0012          2          9     M04     1103      4385   4352
# 159  J25-0004          3          9     M05      287      4856   4813
#
#      Processing Time   End  Lateness  Tardiness  Earliness
# 0                 43  1483     -1623          0       1623
# 1                 84  1524     -1405          0       1405
# 2                 81  1521     -1046          0       1046
# 3                 43  1526     -1684          0       1684
# 4                 46  1567      -771          0        771
# ..               ...   ...       ...        ...        ...
# 155               79  3578         0          0          0
# 156               74  3660         0          0          0
# 157               21  3744         0          0          0
# 158               33  4385         0          0          0
# 159               43  4856         0          0          0
#
# [160 rows x 12 columns]

# %%
df_ops_in_progress = JSSP_LIVE.get_dataframe(version="lateness", status="in progress")
df_ops_in_progress
# Out:
#         Job Routing_ID Machine  Operation    Start      End  Processing Time  \
# 0  J25-0000          8     M04          8  2863.78  2907.24            43.46
# 1  J25-0004          3     M08          5  2847.11  2884.69            37.58
# 2  J25-0009          7     M07          8  2863.78  2895.81            32.03
# 3  J25-0012          2     M09          8  2833.22  2883.50            50.28
#
#     Version Operation Status
# 0  lateness      in progress
# 1  lateness      in progress
# 2  lateness      in progress
# 3  lateness      in progress

# %%
#  JSSP zu allen "offenen" Jobs, mit "offenen" Operationen
unique_jobs = df_schedule.Job.unique().tolist()
df_plan_undone  = JSSP_LIVE.get_dataframe(version="lateness", jobs=unique_jobs, status="open")
df_plan_undone
# Out:
#          Job Routing_ID Machine  Operation Start   End  Processing Time  \
# 0   J25-0000          8     M08          9  None  None             74.0
# 1   J25-0002          0     M09          9  None  None             21.0
# 2   J25-0003          2     M04          9  None  None             33.0
# 3   J25-0004          3     M07          6  None  None             85.0
# 4   J25-0004          3     M03          7  None  None             98.0
# 5   J25-0004          3     M09          8  None  None             22.0
# 6   J25-0004          3     M05          9  None  None             43.0
# 7   J25-0005          1     M08          9  None  None             30.0
# 8   J25-0006          9     M07          9  None  None             45.0
# 9   J25-0007          5     M07          9  None  None             25.0
# 10  J25-0008          4     M06          9  None  None             53.0
# 11  J25-0009          7     M03          9  None  None             79.0
# 12  J25-0010          0     M09          9  None  None             21.0
# 13  J25-0011          1     M08          9  None  None             30.0
# 14  J25-0012          2     M04          9  None  None             33.0
# 15  J25-0014          4     M06          9  None  None             53.0
# 16  J25-0015          5     M07          9  None  None             25.0
#
#      Version Operation Status
# 0   lateness             open
# 1   lateness             open
# 2   lateness             open
# 3   lateness             open
# 4   lateness             open
# 5   lateness             open
# 6   lateness             open
# 7   lateness             open
# 8   lateness             open
# 9   lateness             open
# 10  lateness             open
# 11  lateness             open
# 12  lateness             open
# 13  lateness             open
# 14  lateness             open
# 15  lateness             open
# 16  lateness             open

# %% [markdown]
# ## Version simple

# %%
this_version = "lateness_simple"

# %%
# Jobs
Job.clone_jobs(referenced_version="lateness", new_version=this_version)
# Out:
# ✅ 7250 Jobs von Version 'lateness' nach Version 'lateness_simple' kopiert.

# %%
JSSP_LIVE.clone_operations(referenced_version="lateness", new_version=this_version)
# Out:
# ✅ 11930 JSSP_LIVE-Einträge von Version 'lateness' nach Version 'lateness_simple' kopiert.

# %%
Schedule.clone_schedules(referenced_version="lateness", new_version=this_version)
# Out:
# ✅ 2 Schedule-Einträge von Version 'lateness' nach 'lateness_simple' kopiert.

# %%
def get_jssp_for_jobs(df_jobs_times, df_routings):
    """
    Erstellt ein JSSP-kompatibles DataFrame durch Verknüpfung von Job-Zeitdaten mit Routings.

    Parameter:
    - df_jobs_times: DataFrame mit mindestens den Spalten 'Job' und 'Routing_ID'.
    - df_routings: DataFrame mit Spalte 'Routing_ID' und den zugehörigen Operationsdaten.

    Rückgabe:
    - df_jssp: DataFrame mit allen für das JSSP notwendigen Informationen, inklusive 'Job' und den Operationen.
    """
    # 1. Relevante Spalten extrahieren
    df_job_ids = df_jobs_times[['Job', 'Routing_ID']].copy()

    # 2. Merge mit df_routings über Routing_ID
    df_jssp = df_job_ids.merge(df_routings, on='Routing_ID')

    return df_jssp

# %% [markdown]
# ## Rolling Planning ab Tag 2

# %%
day_length = 1440

# %%
day_numb = 2

day_start = day_length*day_numb 
day_end = day_start + day_length
print(f"Day {day_numb:02d}: [{day_start}, {day_end})")


# alle aktuelle "offenen" Jobs
df_jobs_times_curr = Job.get_dataframe(version=this_version, arrival_time_max=day_start, status="open")
df_jobs_times_curr
# Out:
# Day 02: [2880, 4320)
#          Job Routing_ID  Arrival  Ready Time  Deadline Status          Version
# 0   J25-0000          8       79        1440      3660   open  lateness_simple
# 1   J25-0002          0      198        1440      3744   open  lateness_simple
# 2   J25-0003          2      243        1440      3379   open  lateness_simple
# 3   J25-0004          3      287        1440      4856   open  lateness_simple
# 4   J25-0005          1      498        1440      3106   open  lateness_simple
# ..       ...        ...      ...         ...       ...    ...              ...
# 31  J25-0033          2     2660        2880      6738   open  lateness_simple
# 32  J25-0034          8     2715        2880      6387   open  lateness_simple
# 33  J25-0035          5     2726        2880      4126   open  lateness_simple
# 34  J25-0036          4     2734        2880      5231   open  lateness_simple
# 35  J25-0037          7     2801        2880      5173   open  lateness_simple
#
# [36 rows x 7 columns]

# %%
#  JSSP zu allen "offenen" Jobs (auch fertige Operationen)
df_jssp_temp = get_jssp_for_jobs(df_jobs_times_curr, df_routings)


#  JSSP zu allen "offenen" Jobs, mit "offenen" Operationen
df_jobs_ops = JSSP_LIVE.get_dataframe(version=this_version, jobs=df_jssp_temp.Job.tolist(), status="open")
df_jssp_curr = df_jssp_temp.merge(df_jobs_ops[['Job', 'Operation']], on=['Job', 'Operation'], how='inner')
df_jssp_curr
# Out:
#           Job Routing_ID  Operation Machine  Processing Time
# 0    J25-0000          8          9     M08               74
# 1    J25-0002          0          9     M09               21
# 2    J25-0003          2          9     M04               33
# 3    J25-0004          3          6     M07               85
# 4    J25-0004          3          7     M03               98
# ..        ...        ...        ...     ...              ...
# 232  J25-0037          7          5     M06               88
# 233  J25-0037          7          6     M08               19
# 234  J25-0037          7          7     M09               48
# 235  J25-0037          7          8     M07               36
# 236  J25-0037          7          9     M03               79
#
# [237 rows x 5 columns]

# %%
# Relevante 
df_ops_in_progess = JSSP_LIVE.get_dataframe(version=this_version, status="in progress")
df_ops_in_progess
# Out:
#         Job Routing_ID Machine  Operation    Start      End  Processing Time  \
# 0  J25-0000          8     M04          8  2863.78  2907.24            43.46
# 1  J25-0004          3     M08          5  2847.11  2884.69            37.58
# 2  J25-0009          7     M07          8  2863.78  2895.81            32.03
# 3  J25-0012          2     M09          8  2833.22  2883.50            50.28
#
#            Version Operation Status
# 0  lateness_simple      in progress
# 1  lateness_simple      in progress
# 2  lateness_simple      in progress
# 3  lateness_simple      in progress

# %%
df_schedule = cp_late_reschedule.solve_jssp_by_tardiness_and_earliness_with_fixed_ops(df_jssp_curr, df_jobs_times_curr, 
                                                                                      df_ops_in_progess, w_t = 5,
                                                                                      reschedule_start = day_start, 
                                                                                      msg=False, timeLimit=max_time, gapRel= 0.001)

show.plot_gantt(df_schedule, perspective="Machine", title=f"Gantt-Diagramm für Schedule ab Tag {day_numb}")
# Out:
# Solver-Status         : OPTIMAL
# Objective Value       : 25.00
# Best Objective Bound  : 25.00
# Laufzeit              : 0.22 Sekunden

# %%
schedule_dict = df_schedule.to_dict(orient='records') 
Schedule.add_schedule(data=schedule_dict, date=day_numb,version=this_version)
# Out:
# ✅ Schedule hinzugefügt (Version=lateness_simple, Date=2)

# %%
check.all_in_one(df_schedule)
# Out:
# + Keine Maschinenkonflikte gefunden
# + Alle Gruppen wurden in korrekter Operationsreihenfolge ausgeführt.
# + Alle technologischen Abhängigkeiten wurden eingehalten.
# + Alle Operation starten erst nach Arrival des Job
#
# +++ Alle Constraints wurden erfüllt.
# True

# %%
last_ops = df_schedule.sort_values(['Job', 'Operation']).drop_duplicates('Job', keep='last')
print(show.count_column_grouped(last_ops, "Lateness", max_val = 240, steps= 60))
# Out:
# label
# <-240           0
# -240 - -180     0
# -180 - -120     0
# -120 - -60      0
# -60 - 0         1
# 0              35
# 0 - 60          0
# 60 - 120        0
# 120 - 180       0
# 180 - 240       0
# >240            0
# Name: count, dtype: int64

# %%
simulation = ProductionSimulation(df_schedule, sigma=0.2)
df_execution = simulation.run(start_time = day_start, end_time=day_end)
# Out:
# [Day 2 00:00:00] Job J25-0024 started on M01
# [Day 2 00:00:00] Job J25-0030 started on M00
# [Day 2 00:00:00] Job J25-0037 started on M02
# [Day 2 00:24:00] Job J25-0007 started on M07
# [Day 2 00:25:39] Job J25-0030 finished on M00 (after 25 minutes 40 seconds)
# [Day 2 00:34:14] Job J25-0037 finished on M02 (after 34 minutes 14 seconds)
# [Day 2 00:34:14] Job J25-0029 started on M02
# [Day 2 00:34:14] Job J25-0037 started on M00
# [Day 2 00:45:49] Job J25-0029 finished on M02 (after 11 minutes 35 seconds)
# [Day 2 00:45:49] Job J25-0017 started on M02
# [Day 2 00:47:21] Job J25-0007 finished on M07 (after 23 minutes 22 seconds)
# [Day 2 01:13:22] Job J25-0017 finished on M02 (after 27 minutes 33 seconds)
# [Day 2 01:16:00] Job J25-0015 started on M07
# [Day 2 01:16:07] Job J25-0024 finished on M01 (after 76 minutes 07 seconds)
# [Day 2 01:21:00] Job J25-0024 started on M02
# [Day 2 01:43:29] Job J25-0015 finished on M07 (after 27 minutes 29 seconds)
# [Day 2 01:43:29] Job J25-0004 started on M07
# [Day 2 01:58:03] Job J25-0037 finished on M00 (after 83 minutes 49 seconds)
# [Day 2 23:56:38] Job J25-0033 finished on M02 (after 75 minutes 28 seconds)
# [Day 2 23:59:47] Job J25-0031 finished on M06 (after 44 minutes 08 seconds)
# [Day 3 00:25:10] Job J25-0028 finished on M08 (after 47 minutes 56 seconds)
# [Day 3 00:45:43] Job J25-0017 finished on M05 (after 90 minutes 43 seconds)
# [Day 3 00:48:01] Job J25-0019 finished on M04 (after 75 minutes 19 seconds)
# [Day 3 01:02:28] Job J25-0036 finished on M09 (after 97 minutes 52 seconds)
# [Day 3 01:42:22] Job J25-0024 finished on M03 (after 129 minutes 40 seconds)
#
# [Day 3 01:42:22] Simulation ended! There are no more active Operations

# %%
show.plot_gantt(df_execution, perspective="Machine", title=f"Gantt-Diagramm für Simulationstag {day_numb}")

# %%
df_ops_finished = df_execution[df_execution.End < day_end]
JSSP_LIVE.add_from_dataframe(df_ops_finished, version=this_version, status="finished")
df_ops_finished
# Out:
# ✅ 170 JSSP_LIVE-Einträge (Version 'lateness_simple', Status 'finished') wurden hinzugefügt oder aktualisiert.
#           Job Routing_ID  Operation Machine  Arrival    Start  \
# 0    J25-0000          8          9     M08       79  3586.00
# 1    J25-0002          0          9     M09      198  3724.21
# 2    J25-0003          2          9     M04      243  3346.00
# 3    J25-0004          3          6     M07      287  2983.49
# 4    J25-0005          1          9     M08      498  3076.00
# ..        ...        ...        ...     ...      ...      ...
# 170  J25-0037          7          4     M04     2801  3118.67
# 171  J25-0037          7          5     M06     2801  3149.00
# 172  J25-0037          7          6     M08     2801  3237.00
# 173  J25-0037          7          7     M09     2801  3257.65
# 174  J25-0037          7          8     M07     2801  3304.00
#
#      Processing Time      End
# 0              80.51  3666.51
# 1              22.62  3746.83
# 2              27.35  3373.35
# 3              83.23  3066.72
# 4              25.81  3101.81
# ..               ...      ...
# 170            29.93  3148.60
# 171            82.10  3231.10
# 172            20.65  3257.65
# 173            38.10  3295.75
# 174            32.05  3336.05
#
# [170 rows x 8 columns]

# %%
JSSP_LIVE.update_closed_jobs_from_operations(version=this_version)
# Out:
# ✅ 14 Job(s) wurden auf 'closed' gesetzt (Version 'lateness_simple').
# ['J25-0001',
#  'J25-0002',
#  'J25-0003',
#  'J25-0005',
#  'J25-0006',
#  'J25-0007',
#  'J25-0008',
#  'J25-0010',
#  'J25-0011',
#  'J25-0013',
#  'J25-0014',
#  'J25-0015',
#  'J25-0032',
#  'J25-0035']

# %%
df_ops_in_progess = df_execution[df_execution.End >= day_end]
JSSP_LIVE.add_from_dataframe(df_ops_in_progess, version=this_version, status="in progress")
df_ops_in_progess
# Out:
# ✅ 5 JSSP_LIVE-Einträge (Version 'lateness_simple', Status 'in progress') wurden hinzugefügt oder aktualisiert.
#           Job Routing_ID  Operation Machine  Arrival    Start  \
# 20   J25-0017          7          3     M05     1864  4275.00
# 38   J25-0019          9          8     M04     1925  4292.71
# 70   J25-0024          3          7     M03     2108  4292.71
# 98   J25-0028          0          8     M08     2282  4297.24
# 165  J25-0036          4          8     M09     2734  4284.62
#
#      Processing Time      End
# 20             90.72  4365.72
# 38             75.32  4368.03
# 70            129.66  4422.37
# 98             47.94  4345.18
# 165            97.86  4382.48
