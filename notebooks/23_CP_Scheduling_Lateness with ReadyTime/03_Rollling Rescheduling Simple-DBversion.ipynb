# %%
import sys
import os

# Projektverzeichnis
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))

# Füge dem sys.path hinzu, falls noch nicht vorhanden
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
# Datenzugriff
from models import db, Routing, Job, Schedule, JobOperation


# Utils
import src.utils.presenter as show
from src.utils.analize import check_constrains as check

from src.utils.production_process import time_determination as term
from src.utils.production_process import filter as process_filter

# Solver Model
from src.models.cp import lateness_scheduling as cp_late_schedule
from src.models.cp import lateness_rescheduling as cp_late_reschedule
import src.models.heuristics.fcfs as fcfs


# Simulation
from src.simulation.ProductionSimulation import ProductionSimulation

# Extern
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 21)

# %%
max_time = 60 * 30 # 30 min

# %% [markdown]
# ## Laden der Produktionsaufträge

# %%
df_jobs_times = Job.get_dataframe(version="lateness")
df_jobs_times
# Out:
#            Job Routing_ID  Arrival  Ready Time  Deadline  Status   Version
# 0     J25-0000          8       79        1440      3660    open  lateness
# 1     J25-0001          6      129        1440      2338  closed  lateness
# 2     J25-0002          0      198        1440      3744    open  lateness
# 3     J25-0003          2      243        1440      3379    open  lateness
# 4     J25-0004          3      287        1440      4856    open  lateness
# ...        ...        ...      ...         ...       ...     ...       ...
# 1188  J25-1188          8    85975       86400     88866    open  lateness
# 1189  J25-1189          1    86001       86400     88375    open  lateness
# 1190  J25-1190          5    86033       86400     87868    open  lateness
# 1191  J25-1191          1    86084       86400     88251    open  lateness
# 1192  J25-1192          3    86247       86400     87822    open  lateness
#
# [1193 rows x 7 columns]

# %%
def get_jssp_for_jobs(df_jobs_times, df_routings):
    """
    Erstellt ein JSSP-kompatibles DataFrame durch Verknüpfung von Job-Zeitdaten mit Routings.

    Parameter:
    - df_jobs_times: DataFrame mit mindestens den Spalten 'Job' und 'Routing_ID'.
    - df_routings: DataFrame mit Spalte 'Routing_ID' und den zugehörigen Operationsdaten.

    Rückgabe:
    - df_jssp: DataFrame mit allen für das JSSP notwendigen Informationen, inklusive 'Job' und den Operationen.
    """
    # 1. Relevante Spalten extrahieren
    df_job_ids = df_jobs_times[['Job', 'Routing_ID']].copy()

    # 2. Merge mit df_routings über Routing_ID
    df_jssp = df_job_ids.merge(df_routings, on='Routing_ID')

    return df_jssp

# Routings
df_routings = Routing.get_dataframe()
df_jssp = get_jssp_for_jobs(df_jobs_times, df_routings)
df_jssp
# Out:
#             Job Routing_ID  Operation Machine  Processing Time
# 0      J25-0000          8          0     M00               76
# 1      J25-0000          8          1     M01               69
# 2      J25-0000          8          2     M03               76
# 3      J25-0000          8          3     M05               51
# 4      J25-0000          8          4     M02               85
# ...         ...        ...        ...     ...              ...
# 11925  J25-1192          3          5     M08               52
# 11926  J25-1192          3          6     M07               85
# 11927  J25-1192          3          7     M03               98
# 11928  J25-1192          3          8     M09               22
# 11929  J25-1192          3          9     M05               43
#
# [11930 rows x 5 columns]

# %% [markdown]
# ## Laden der Initialisierungsdaten vom Tag 1

# %%
day_numb = 1

# %%
df_schedule = Schedule.get_schedule_as_dataframe(date = 1, version="lateness")
df_schedule
# Out:
#           Job Routing_ID  Operation Machine  Arrival  Deadline  Start  \
# 0    J25-0005          1          0     M00      498      3106   1440
# 1    J25-0007          5          0     M02      925      2929   1440
# 2    J25-0013          3          0     M01     1192      2567   1440
# 3    J25-0011          1          0     M00     1030      3210   1483
# 4    J25-0001          6          0     M01      129      2338   1521
# ..        ...        ...        ...     ...      ...       ...    ...
# 155  J25-0009          7          9     M03     1004      3578   3499
# 156  J25-0000          8          9     M08       79      3660   3586
# 157  J25-0002          0          9     M09      198      3744   3723
# 158  J25-0012          2          9     M04     1103      4385   4352
# 159  J25-0004          3          9     M05      287      4856   4813
#
#      Processing Time   End  Lateness  Tardiness  Earliness
# 0                 43  1483     -1623          0       1623
# 1                 84  1524     -1405          0       1405
# 2                 81  1521     -1046          0       1046
# 3                 43  1526     -1684          0       1684
# 4                 46  1567      -771          0        771
# ..               ...   ...       ...        ...        ...
# 155               79  3578         0          0          0
# 156               74  3660         0          0          0
# 157               21  3744         0          0          0
# 158               33  4385         0          0          0
# 159               43  4856         0          0          0
#
# [160 rows x 12 columns]

# %%
df_ops_in_progress = JobOperation.get_dataframe(version="lateness", status="in progress")
df_ops_in_progress
# Out:
#         Job Machine  Operation    Start      End  Processing Time   Version  \
# 0  J25-0000     M07          7  2793.04  2886.95            93.91  lateness
# 1  J25-0004     M08          5  2847.61  2907.80            60.19  lateness
# 2  J25-0006     M04          8  2756.44  2891.60           135.16  lateness
#
#   Operation Status
# 0      in progress
# 1      in progress
# 2      in progress

# %%
#  JSSP zu allen "offenen" Jobs, mit "offenen" Operationen
unique_jobs = df_schedule.Job.unique().tolist()
df_plan_undone  = JobOperation.get_dataframe(version="lateness", jobs=unique_jobs, status="open")
df_plan_undone
# Out:
#          Job Machine  Operation Start   End  Processing Time   Version  \
# 0   J25-0000     M04          8  None  None             26.0  lateness
# 1   J25-0000     M08          9  None  None             74.0  lateness
# 2   J25-0002     M09          9  None  None             21.0  lateness
# 3   J25-0003     M04          9  None  None             33.0  lateness
# 4   J25-0004     M07          6  None  None             85.0  lateness
# 5   J25-0004     M03          7  None  None             98.0  lateness
# 6   J25-0004     M09          8  None  None             22.0  lateness
# 7   J25-0004     M05          9  None  None             43.0  lateness
# 8   J25-0005     M08          9  None  None             30.0  lateness
# 9   J25-0006     M07          9  None  None             45.0  lateness
# 10  J25-0007     M07          9  None  None             25.0  lateness
# 11  J25-0008     M06          9  None  None             53.0  lateness
# 12  J25-0009     M07          8  None  None             36.0  lateness
# 13  J25-0009     M03          9  None  None             79.0  lateness
# 14  J25-0010     M09          9  None  None             21.0  lateness
# 15  J25-0011     M08          9  None  None             30.0  lateness
# 16  J25-0012     M04          9  None  None             33.0  lateness
# 17  J25-0014     M06          9  None  None             53.0  lateness
# 18  J25-0015     M07          9  None  None             25.0  lateness
#
#    Operation Status
# 0              open
# 1              open
# 2              open
# 3              open
# 4              open
# 5              open
# 6              open
# 7              open
# 8              open
# 9              open
# 10             open
# 11             open
# 12             open
# 13             open
# 14             open
# 15             open
# 16             open
# 17             open
# 18             open

# %% [markdown]
# ## Version simple

# %%
this_version = "lateness_simple"

# %%
# Jobs
Job.clone_jobs(referenced_version="lateness", new_version=this_version)
# Out:
# ✅ 1193 Jobs von Version 'lateness' nach Version 'lateness_simple' kopiert.

# %%
JobOperation.clone_operations(referenced_version="lateness", new_version=this_version)
# Out:
# ✅ 11930 JobOperation-Einträge von Version 'lateness' nach Version 'lateness_simple' kopiert.

# %%
Schedule.clone_schedules(referenced_version="lateness", new_version=this_version)
# Out:
# ✅ 1 Schedule-Einträge von Version 'lateness' nach 'lateness_simple' kopiert.

# %%
def get_jssp_for_jobs(df_jobs_times, df_routings):
    """
    Erstellt ein JSSP-kompatibles DataFrame durch Verknüpfung von Job-Zeitdaten mit Routings.

    Parameter:
    - df_jobs_times: DataFrame mit mindestens den Spalten 'Job' und 'Routing_ID'.
    - df_routings: DataFrame mit Spalte 'Routing_ID' und den zugehörigen Operationsdaten.

    Rückgabe:
    - df_jssp: DataFrame mit allen für das JSSP notwendigen Informationen, inklusive 'Job' und den Operationen.
    """
    # 1. Relevante Spalten extrahieren
    df_job_ids = df_jobs_times[['Job', 'Routing_ID']].copy()

    # 2. Merge mit df_routings über Routing_ID
    df_jssp = df_job_ids.merge(df_routings, on='Routing_ID')

    return df_jssp

# %% [markdown]
# ## Rolling Planning ab Tag 2

# %%
day_length = 1440

# %%
day_numb = 2

day_start = day_length*day_numb 
day_end = day_start + day_length
print(f"Day {day_numb:02d}: [{day_start}, {day_end})")


# alle aktuelle "offenen" Jobs
df_jobs_times_curr = Job.get_dataframe(version=this_version, arrival_time_max=day_start, status="open")
df_jobs_times_curr
# Out:
# Day 02: [2880, 4320)
#          Job Routing_ID  Arrival  Ready Time  Deadline Status          Version
# 0   J25-0000          8       79        1440      3660   open  lateness_simple
# 1   J25-0002          0      198        1440      3744   open  lateness_simple
# 2   J25-0003          2      243        1440      3379   open  lateness_simple
# 3   J25-0004          3      287        1440      4856   open  lateness_simple
# 4   J25-0005          1      498        1440      3106   open  lateness_simple
# ..       ...        ...      ...         ...       ...    ...              ...
# 31  J25-0033          2     2660        2880      6738   open  lateness_simple
# 32  J25-0034          8     2715        2880      6387   open  lateness_simple
# 33  J25-0035          5     2726        2880      4126   open  lateness_simple
# 34  J25-0036          4     2734        2880      5231   open  lateness_simple
# 35  J25-0037          7     2801        2880      5173   open  lateness_simple
#
# [36 rows x 7 columns]

# %%
#  JSSP zu allen "offenen" Jobs (auch fertige Operationen)
df_jssp_temp = get_jssp_for_jobs(df_jobs_times_curr, df_routings)


#  JSSP zu allen "offenen" Jobs, mit "offenen" Operationen
df_jobs_ops = JobOperation.get_dataframe(version=this_version, jobs=df_jssp_temp.Job.tolist(), status="open")
df_jssp_curr = df_jssp_temp.merge(df_jobs_ops[['Job', 'Operation']], on=['Job', 'Operation'], how='inner')
df_jssp_curr
# Out:
#           Job Routing_ID  Operation Machine  Processing Time
# 0    J25-0000          8          8     M04               26
# 1    J25-0000          8          9     M08               74
# 2    J25-0002          0          9     M09               21
# 3    J25-0003          2          9     M04               33
# 4    J25-0004          3          6     M07               85
# ..        ...        ...        ...     ...              ...
# 234  J25-0037          7          5     M06               88
# 235  J25-0037          7          6     M08               19
# 236  J25-0037          7          7     M09               48
# 237  J25-0037          7          8     M07               36
# 238  J25-0037          7          9     M03               79
#
# [239 rows x 5 columns]

# %%
# Relevante 
df_ops_in_progess = JobOperation.get_dataframe(version=this_version, status="in progress")
df_ops_in_progess
# Out:
#         Job Machine  Operation    Start      End  Processing Time  \
# 0  J25-0000     M07          7  2793.04  2886.95            93.91
# 1  J25-0004     M08          5  2847.61  2907.80            60.19
# 2  J25-0006     M04          8  2756.44  2891.60           135.16
#
#            Version Operation Status
# 0  lateness_simple      in progress
# 1  lateness_simple      in progress
# 2  lateness_simple      in progress

# %%
df_schedule = cp_late_reschedule.solve_jssp_by_tardiness_and_earliness_with_fixed_ops(df_jssp_curr, df_jobs_times_curr, 
                                                                                      df_ops_in_progess, w_t = 5,
                                                                                      reschedule_start = day_start, 
                                                                                      msg=False, timeLimit=max_time, gapRel= 0.001)

show.plot_gantt(df_schedule, perspective="Machine", title=f"Gantt-Diagramm für Schedule ab Tag {day_numb}")
# Out:
# Solver-Status         : OPTIMAL
# Objective Value       : 25.00
# Best Objective Bound  : 25.00
# Laufzeit              : 0.16 Sekunden

# %%
schedule_dict = df_schedule.to_dict(orient='records') 
Schedule.add_schedule(data=schedule_dict, date=day_numb,version=this_version)
# Out:
# ✅ Schedule hinzugefügt (Version=lateness_simple, Date=2)

# %%
check.all_in_one(df_schedule)
# Out:
# + Keine Maschinenkonflikte gefunden
# + Alle Gruppen wurden in korrekter Operationsreihenfolge ausgeführt.
# + Alle technologischen Abhängigkeiten wurden eingehalten.
# + Alle Operation starten erst nach Arrival des Job
#
# +++ Alle Constraints wurden erfüllt.
# True

# %%
last_ops = df_schedule.sort_values(['Job', 'Operation']).drop_duplicates('Job', keep='last')
print(show.count_column_grouped(last_ops, "Lateness", max_val = 240, steps= 60))
# Out:
# label
# <-240           0
# -240 - -180     0
# -180 - -120     0
# -120 - -60      0
# -60 - 0         1
# 0              35
# 0 - 60          0
# 60 - 120        0
# 120 - 180       0
# 180 - 240       0
# >240            0
# Name: count, dtype: int64

# %%
simulation = ProductionSimulation(df_schedule, sigma=0.2)
df_execution = simulation.run(start_time = day_start, end_time=day_end)
# Out:
# [Day 2 00:00:00] Job J25-0031 started on M00
# [Day 2 00:00:00] Job J25-0032 started on M01
# [Day 2 00:00:00] Job J25-0035 started on M02
# [Day 2 00:12:00] Job J25-0000 started on M04
# [Day 2 00:24:00] Job J25-0007 started on M07
# [Day 2 00:40:41] Job J25-0031 finished on M00 (after 40 minutes 41 seconds)
# [Day 2 00:41:06] Job J25-0000 finished on M04 (after 29 minutes 07 seconds)
# [Day 2 00:41:54] Job J25-0007 finished on M07 (after 17 minutes 55 seconds)
# [Day 2 00:43:00] Job J25-0023 started on M00
# [Day 2 00:48:23] Job J25-0032 finished on M01 (after 48 minutes 23 seconds)
# [Day 2 00:48:23] Job J25-0019 started on M01
# [Day 2 01:16:00] Job J25-0015 started on M07
# [Day 2 01:34:06] Job J25-0035 finished on M02 (after 94 minutes 07 seconds)
# [Day 2 01:34:06] Job J25-0031 started on M02
# [Day 2 01:36:58] Job J25-0015 finished on M07 (after 20 minutes 59 seconds)
# [Day 2 01:41:00] Job J25-0009 started on M07
# [Day 2 01:42:59] Job J25-0023 finished on M00 (after 59 minutes 59 seconds)
# [Day 2 01:48:44] Job J25-0019 finished on M01 (after 60 minutes 21 seconds)
# [Day 2 01:59:00] Job J25-0032 started on M00
# [Day 2 02:11:00] Job J25-0035 started on M01
# [Day 2 02:11:24] Job J25-0009 finished on M07 (after 30 minutes 25 seconds)
# [Day 2 02:12:33] Job J25-0035 finished on M01 (after 01 minute 33 seconds)
# [Day 2 02:13:00] Job J25-0024 started on M01
# [Day 2 02:13:00] Job J25-0035 started on M05
# [Day 2 02:17:00] Job J25-0004 started on M07
# [Day 2 02:48:10] Job J25-0032 finished on M00 (after 49 minutes 10 seconds)
# [Day 2 02:48:10] Job J25-0019 started on M00
# [Day 2 02:48:10] Job J25-0032 started on M03
# [Day 2 02:56:54] Job J25-0019 finished on M00 (after 08 minutes 44 seconds)
# [Day 2 02:56:54] Job J25-0018 started on M00
# [Day 2 03:01:07] Job J25-0031 finished on M02 (after 87 minutes 01 second)
# [Day 2 03:01:07] Job J25-0019 started on M02
# [Day 2 03:01:07] Job J25-0031 started on M04
# [Day 2 03:16:00] Job J25-0005 started on M08
# [Day 2 03:22:01] Job J25-0035 finished on M05 (after 69 minutes 02 seconds)
# [Day 2 03:39:01] Job J25-0019 finished on M02 (after 37 minutes 55 seconds)
# [Day 2 03:41:21] Job J25-0005 finished on M08 (after 25 minutes 22 seconds)
# [Day 2 03:55:00] Job J25-0019 started on M06
# [Day 2 03:59:22] Job J25-0019 finished on M06 (after 04 minutes 22 seconds)
# [Day 2 03:59:40] Job J25-0032 finished on M03 (after 71 minutes 30 seconds)
# [Day 2 03:59:40] Job J25-0035 started on M03
# [Day 2 03:59:40] Job J25-0032 started on M02
# [Day 2 04:01:45] Job J25-0031 finished on M04 (after 60 minutes 38 seconds)
# [Day 2 04:02:50] Job J25-0024 finished on M01 (after 109 minutes 51 seconds)
# [Day 2 04:02:50] Job J25-0026 started on M01
# [Day 2 04:08:34] Job J25-0004 finished on M07 (after 111 minutes 34 seconds)
# [Day 2 04:09:00] Job J25-0031 started on M09
# [Day 2 04:15:31] Job J25-0031 finished on M09 (after 06 minutes 32 seconds)
# [Day 2 04:18:19] Job J25-0032 finished on M02 (after 18 minutes 39 seconds)
# [Day 2 04:18:19] Job J25-0024 started on M02
# [Day 2 04:18:19] Job J25-0032 started on M06
# [Day 2 04:20:34] Job J25-0018 finished on M00 (after 83 minutes 40 seconds)
# [Day 2 04:20:34] Job J25-0020 started on M00
# [Day 2 04:51:39] Job J25-0032 finished on M06 (after 33 minutes 20 seconds)
# [Day 2 04:51:39] Job J25-0032 started on M05
# [Day 2 04:51:50] Job J25-0026 finished on M01 (after 49 minutes)
# [Day 2 04:51:50] Job J25-0025 started on M01
# [Day 2 05:00:00] Job J25-0011 started on M08
# [Day 2 05:03:48] Job J25-0020 finished on M00 (after 43 minutes 14 seconds)
# [Day 2 05:03:48] Job J25-0026 started on M00
# [Day 2 05:16:39] Job J25-0032 finished on M05 (after 25 minutes)
# [Day 2 05:16:39] Job J25-0032 started on M09
# [Day 2 05:21:26] Job J25-0011 finished on M08 (after 21 minutes 27 seconds)
# [Day 2 05:37:05] Job J25-0026 finished on M00 (after 33 minutes 17 seconds)
# [Day 2 05:37:05] Job J25-0028 started on M00
# [Day 2 05:41:21] Job J25-0024 finished on M02 (after 83 minutes 02 seconds)
# [Day 2 05:43:00] Job J25-0029 started on M02
# [Day 2 05:44:52] Job J25-0032 finished on M09 (after 28 minutes 13 seconds)
# [Day 2 05:59:04] Job J25-0029 finished on M02 (after 16 minutes 05 seconds)
# [Day 2 05:59:04] Job J25-0020 started on M02
# [Day 2 06:08:51] Job J25-0028 finished on M00 (after 31 minutes 46 seconds)
# [Day 2 06:08:51] Job J25-0024 started on M00
# [Day 2 06:11:53] Job J25-0035 finished on M03 (after 132 minutes 13 seconds)
# [Day 2 06:11:53] Job J25-0031 started on M03
# [Day 2 06:11:53] Job J25-0035 started on M08
# [Day 2 06:22:00] Job J25-0014 started on M06
# [Day 2 06:28:56] Job J25-0025 finished on M01 (after 97 minutes 05 seconds)
# [Day 2 06:28:56] Job J25-0016 started on M01
# [Day 2 07:00:55] Job J25-0035 finished on M08 (after 49 minutes 02 seconds)
# [Day 2 07:00:55] Job J25-0032 started on M08
# [Day 2 07:02:48] Job J25-0014 finished on M06 (after 40 minutes 48 seconds)
# [Day 2 07:20:44] Job J25-0031 finished on M03 (after 68 minutes 51 seconds)
# [Day 2 07:20:44] Job J25-0026 started on M03
# [Day 2 07:24:00] Job J25-0010 started on M09
# [Day 2 07:31:53] Job J25-0016 finished on M01 (after 62 minutes 57 seconds)
# [Day 2 07:31:53] Job J25-0018 started on M01
# [Day 2 07:36:05] Job J25-0024 finished on M00 (after 87 minutes 14 seconds)
# [Day 2 07:36:05] Job J25-0029 started on M00
# [Day 2 07:42:43] Job J25-0029 finished on M00 (after 06 minutes 38 seconds)
# [Day 2 07:42:43] Job J25-0016 started on M00
# [Day 2 07:46:00] Job J25-0003 started on M04
# [Day 2 07:53:55] Job J25-0010 finished on M09 (after 29 minutes 55 seconds)
# [Day 2 07:53:55] Job J25-0035 started on M09
# [Day 2 08:06:52] Job J25-0020 finished on M02 (after 127 minutes 47 seconds)
# [Day 2 08:06:52] Job J25-0017 started on M02
# [Day 2 08:15:30] Job J25-0026 finished on M03 (after 54 minutes 46 seconds)
# [Day 2 08:15:30] Job J25-0004 started on M03
# [Day 2 08:18:15] Job J25-0032 finished on M08 (after 77 minutes 19 seconds)
# [Day 2 08:18:15] Job J25-0019 started on M08
# [Day 2 08:18:15] Job J25-0032 started on M07
# [Day 2 08:19:51] Job J25-0003 finished on M04 (after 33 minutes 52 seconds)
# [Day 2 08:19:51] Job J25-0024 started on M04
# [Day 2 08:21:52] Job J25-0016 finished on M00 (after 39 minutes 08 seconds)
# [Day 2 08:21:52] Job J25-0025 started on M00
# [Day 2 08:31:45] Job J25-0018 finished on M01 (after 59 minutes 52 seconds)
# [Day 2 08:31:45] Job J25-0031 started on M01
# [Day 2 08:39:09] Job J25-0035 finished on M09 (after 45 minutes 14 seconds)
# [Day 2 08:44:27] Job J25-0032 finished on M07 (after 26 minutes 13 seconds)
# [Day 2 08:44:34] Job J25-0017 finished on M02 (after 37 minutes 43 seconds)
# [Day 2 08:44:34] Job J25-0037 started on M02
# [Day 2 08:59:40] Job J25-0031 finished on M01 (after 27 minutes 55 seconds)
# [Day 2 08:59:40] Job J25-0029 started on M01
# [Day 2 08:59:40] Job J25-0031 started on M06
# [Day 2 09:17:07] Job J25-0019 finished on M08 (after 58 minutes 52 seconds)
# [Day 2 09:17:07] Job J25-0019 started on M09
# [Day 2 09:23:39] Job J25-0037 finished on M02 (after 39 minutes 05 seconds)
# [Day 2 09:23:39] Job J25-0026 started on M02
# [Day 2 09:27:25] Job J25-0029 finished on M01 (after 27 minutes 45 seconds)
# [Day 2 09:27:25] Job J25-0023 started on M01
# [Day 2 09:27:25] Job J25-0029 started on M05
# [Day 2 09:37:20] Job J25-0025 finished on M00 (after 75 minutes 28 seconds)
# [Day 2 09:37:20] Job J25-0035 started on M00
# [Day 2 09:38:23] Job J25-0026 finished on M02 (after 14 minutes 44 seconds)
# [Day 2 09:38:23] Job J25-0036 started on M02
# [Day 2 09:47:30] Job J25-0031 finished on M06 (after 47 minutes 50 seconds)
# [Day 2 09:47:30] Job J25-0026 started on M06
# [Day 2 09:54:20] Job J25-0036 finished on M02 (after 15 minutes 57 seconds)
# [Day 2 09:54:20] Job J25-0021 started on M02
# [Day 2 10:07:57] Job J25-0004 finished on M03 (after 112 minutes 27 seconds)
# [Day 2 10:07:57] Job J25-0018 started on M03
# [Day 2 10:14:00] Job J25-0006 started on M07
# [Day 2 10:15:28] Job J25-0035 finished on M00 (after 38 minutes 08 seconds)
# [Day 2 10:15:28] Job J25-0017 started on M00
# [Day 2 10:28:33] Job J25-0026 finished on M06 (after 41 minutes 04 seconds)
# [Day 2 10:28:33] Job J25-0008 started on M06
# [Day 2 10:29:56] Job J25-0019 finished on M09 (after 72 minutes 49 seconds)
# [Day 2 10:34:48] Job J25-0029 finished on M05 (after 67 minutes 23 seconds)
# [Day 2 10:34:48] Job J25-0031 started on M05
# [Day 2 10:37:24] Job J25-0024 finished on M04 (after 137 minutes 32 seconds)
# [Day 2 10:37:24] Job J25-0020 started on M04
# [Day 2 10:41:37] Job J25-0023 finished on M01 (after 74 minutes 12 seconds)
# [Day 2 10:41:37] Job J25-0022 started on M01
# [Day 2 10:45:00] Job J25-0004 started on M09
# [Day 2 11:00:40] Job J25-0018 finished on M03 (after 52 minutes 43 seconds)
# [Day 2 11:00:40] Job J25-0009 started on M03
# [Day 2 11:07:04] Job J25-0006 finished on M07 (after 53 minutes 04 seconds)
# [Day 2 11:07:30] Job J25-0004 finished on M09 (after 22 minutes 30 seconds)
# [Day 2 11:09:14] Job J25-0021 finished on M02 (after 74 minutes 54 seconds)
# [Day 2 11:09:14] Job J25-0027 started on M02
# [Day 2 11:15:41] Job J25-0031 finished on M05 (after 40 minutes 53 seconds)
# [Day 2 11:15:41] Job J25-0026 started on M05
# [Day 2 11:15:41] Job J25-0031 started on M07
# [Day 2 11:29:24] Job J25-0026 finished on M05 (after 13 minutes 43 seconds)
# [Day 2 11:29:24] Job J25-0019 started on M05
# [Day 2 11:29:24] Job J25-0026 started on M09
# [Day 2 11:31:07] Job J25-0017 finished on M00 (after 75 minutes 40 seconds)
# [Day 2 11:34:13] Job J25-0008 finished on M06 (after 65 minutes 40 seconds)
# [Day 2 11:34:13] Job J25-0024 started on M06
# [Day 2 11:35:23] Job J25-0027 finished on M02 (after 26 minutes 09 seconds)
# [Day 2 11:39:00] Job J25-0037 started on M00
# [Day 2 11:43:38] Job J25-0024 finished on M06 (after 09 minutes 26 seconds)
# [Day 2 11:43:38] Job J25-0035 started on M06
# [Day 2 11:43:38] Job J25-0024 started on M08
# [Day 2 11:54:48] Job J25-0026 finished on M09 (after 25 minutes 25 seconds)
# [Day 2 11:57:20] Job J25-0020 finished on M04 (after 79 minutes 57 seconds)
# [Day 2 11:57:20] Job J25-0020 started on M09
# [Day 2 12:02:05] Job J25-0019 finished on M05 (after 32 minutes 41 seconds)
# [Day 2 12:02:05] Job J25-0018 started on M05
# [Day 2 12:04:40] Job J25-0020 finished on M09 (after 07 minutes 20 seconds)
# [Day 2 12:07:28] Job J25-0022 finished on M01 (after 85 minutes 51 seconds)
# [Day 2 12:07:28] Job J25-0028 started on M01
# [Day 2 12:10:34] Job J25-0009 finished on M03 (after 69 minutes 54 seconds)
# [Day 2 12:10:34] Job J25-0019 started on M03
# [Day 2 12:13:04] Job J25-0031 finished on M07 (after 57 minutes 23 seconds)
# [Day 2 12:34:10] Job J25-0024 finished on M08 (after 50 minutes 32 seconds)
# [Day 2 12:34:10] Job J25-0000 started on M08
# [Day 2 12:34:10] Job J25-0024 started on M07
# [Day 2 12:47:20] Job J25-0037 finished on M00 (after 68 minutes 20 seconds)
# [Day 2 12:47:20] Job J25-0022 started on M00
# [Day 2 12:51:00] Job J25-0018 finished on M05 (after 48 minutes 55 seconds)
# [Day 2 12:51:00] Job J25-0018 started on M02
# [Day 2 12:57:42] Job J25-0022 finished on M00 (after 10 minutes 22 seconds)
# [Day 2 13:05:00] Job J25-0036 started on M00
# [Day 2 13:11:11] Job J25-0036 finished on M00 (after 06 minutes 11 seconds)
# [Day 2 13:11:11] Job J25-0027 started on M00
# [Day 2 13:13:05] Job J25-0035 finished on M06 (after 89 minutes 26 seconds)
# [Day 2 13:13:05] Job J25-0035 started on M04
# [Day 2 13:21:16] Job J25-0035 finished on M04 (after 08 minutes 11 seconds)
# [Day 2 13:30:00] Job J25-0000 finished on M08 (after 55 minutes 50 seconds)
# [Day 2 13:30:00] Job J25-0026 started on M08
# [Day 2 13:31:10] Job J25-0019 finished on M03 (after 80 minutes 35 seconds)
# [Day 2 13:31:10] Job J25-0023 started on M03
# [Day 2 13:31:10] Job J25-0019 started on M04
# [Day 2 13:43:45] Job J25-0028 finished on M01 (after 96 minutes 17 seconds)
# [Day 2 13:43:45] Job J25-0017 started on M01
# [Day 2 14:03:00] Job J25-0002 started on M09
# [Day 2 14:07:16] Job J25-0024 finished on M07 (after 93 minutes 06 seconds)
# [Day 2 14:10:46] Job J25-0018 finished on M02 (after 79 minutes 46 seconds)
# [Day 2 14:10:46] Job J25-0022 started on M02
# [Day 2 14:21:49] Job J25-0002 finished on M09 (after 18 minutes 49 seconds)
# [Day 2 14:24:00] Job J25-0018 started on M09
# [Day 2 14:25:49] Job J25-0017 finished on M01 (after 42 minutes 04 seconds)
# [Day 2 14:25:49] Job J25-0037 started on M01
# [Day 2 14:25:49] Job J25-0017 started on M05
# [Day 2 14:31:07] Job J25-0019 finished on M04 (after 59 minutes 57 seconds)
# [Day 2 14:36:08] Job J25-0018 finished on M09 (after 12 minutes 08 seconds)
# [Day 2 14:36:08] Job J25-0018 started on M06
# [Day 2 14:40:51] Job J25-0027 finished on M00 (after 89 minutes 40 seconds)
# [Day 2 14:40:51] Job J25-0030 started on M00
# [Day 2 14:55:49] Job J25-0023 finished on M03 (after 84 minutes 39 seconds)
# [Day 2 14:55:49] Job J25-0016 started on M03
# [Day 2 15:01:58] Job J25-0030 finished on M00 (after 21 minutes 07 seconds)
# [Day 2 15:04:58] Job J25-0022 finished on M02 (after 54 minutes 11 seconds)
# [Day 2 15:04:58] Job J25-0028 started on M02
# [Day 2 15:06:00] Job J25-0034 started on M00
# [Day 2 15:06:41] Job J25-0037 finished on M01 (after 40 minutes 52 seconds)
# [Day 2 15:06:41] Job J25-0036 started on M01
# [Day 2 15:10:36] Job J25-0018 finished on M06 (after 34 minutes 28 seconds)
# [Day 2 15:10:36] Job J25-0022 started on M06
# [Day 2 15:15:00] Job J25-0018 started on M07
# [Day 2 15:15:48] Job J25-0026 finished on M08 (after 105 minutes 48 seconds)
# [Day 2 15:17:41] Job J25-0022 finished on M06 (after 07 minutes 05 seconds)
# [Day 2 15:17:41] Job J25-0022 started on M08
# [Day 2 15:18:06] Job J25-0028 finished on M02 (after 13 minutes 08 seconds)
# [Day 2 15:18:40] Job J25-0017 finished on M05 (after 52 minutes 51 seconds)
# [Day 2 15:18:40] Job J25-0023 started on M05
# [Day 2 15:18:40] Job J25-0017 started on M04
# [Day 2 15:22:50] Job J25-0036 finished on M01 (after 16 minutes 10 seconds)
# [Day 2 15:22:50] Job J25-0021 started on M01
# [Day 2 15:24:02] Job J25-0021 finished on M01 (after 01 minute 12 seconds)
# [Day 2 15:24:02] Job J25-0033 started on M01
# [Day 2 15:52:32] Job J25-0016 finished on M03 (after 56 minutes 43 seconds)
# [Day 2 15:52:32] Job J25-0029 started on M03
# [Day 2 15:52:32] Job J25-0016 started on M02
# [Day 2 15:55:37] Job J25-0017 finished on M04 (after 36 minutes 56 seconds)
# [Day 2 15:55:37] Job J25-0032 started on M04
# [Day 2 15:55:37] Job J25-0017 started on M06
# [Day 2 16:02:28] Job J25-0023 finished on M05 (after 43 minutes 47 seconds)
# [Day 2 16:02:28] Job J25-0037 started on M05
# [Day 2 16:03:39] Job J25-0016 finished on M02 (after 11 minutes 07 seconds)
# [Day 2 16:03:39] Job J25-0023 started on M02
# [Day 2 16:04:08] Job J25-0022 finished on M08 (after 46 minutes 27 seconds)
# [Day 2 16:04:08] Job J25-0022 started on M09
# [Day 2 16:22:07] Job J25-0029 finished on M03 (after 29 minutes 35 seconds)
# [Day 2 16:22:07] Job J25-0025 started on M03
# [Day 2 16:25:00] Job J25-0034 finished on M00 (after 79 minutes 01 second)
# [Day 2 16:29:53] Job J25-0018 finished on M07 (after 74 minutes 53 seconds)
# [Day 2 16:29:53] Job J25-0026 started on M07
# [Day 2 16:40:54] Job J25-0032 finished on M04 (after 45 minutes 17 seconds)
# [Day 2 16:41:00] Job J25-0029 started on M04
# [Day 2 16:49:34] Job J25-0025 finished on M03 (after 27 minutes 28 seconds)
# [Day 2 16:49:34] Job J25-0020 started on M03
# [Day 2 16:59:59] Job J25-0026 finished on M07 (after 30 minutes 06 seconds)
# [Day 2 17:06:13] Job J25-0017 finished on M06 (after 70 minutes 36 seconds)
# [Day 2 17:06:13] Job J25-0016 started on M06
# [Day 2 17:15:00] Job J25-0017 started on M08
# [Day 2 17:18:52] Job J25-0033 finished on M01 (after 114 minutes 50 seconds)
# [Day 2 17:18:52] Job J25-0027 started on M01
# [Day 2 17:18:52] Job J25-0033 started on M00
# [Day 2 17:21:45] Job J25-0037 finished on M05 (after 79 minutes 17 seconds)
# [Day 2 17:30:22] Job J25-0016 finished on M06 (after 24 minutes 10 seconds)
# [Day 2 17:30:22] Job J25-0016 started on M05
# [Day 2 17:34:12] Job J25-0017 finished on M08 (after 19 minutes 13 seconds)
# [Day 2 17:39:04] Job J25-0022 finished on M09 (after 94 minutes 55 seconds)
# [Day 2 17:39:04] Job J25-0017 started on M09
# [Day 2 17:42:38] Job J25-0020 finished on M03 (after 53 minutes 04 seconds)
# [Day 2 17:42:38] Job J25-0024 started on M03
# [Day 2 17:48:15] Job J25-0029 finished on M04 (after 67 minutes 16 seconds)
# [Day 2 17:49:54] Job J25-0016 finished on M05 (after 19 minutes 32 seconds)
# [Day 2 17:49:54] Job J25-0022 started on M05
# [Day 2 17:50:00] Job J25-0018 started on M04
# [Day 2 17:52:14] Job J25-0023 finished on M02 (after 108 minutes 35 seconds)
# [Day 2 17:52:14] Job J25-0025 started on M02
# [Day 2 17:52:52] Job J25-0027 finished on M01 (after 33 minutes 59 seconds)
# [Day 2 17:52:52] Job J25-0030 started on M01
# [Day 2 18:11:34] Job J25-0018 finished on M04 (after 21 minutes 34 seconds)
# [Day 2 18:16:00] Job J25-0037 started on M04
# [Day 2 18:32:00] Job J25-0022 finished on M05 (after 42 minutes 05 seconds)
# [Day 2 18:32:00] Job J25-0036 started on M05
# [Day 2 18:40:25] Job J25-0017 finished on M09 (after 61 minutes 22 seconds)
# [Day 2 18:40:25] Job J25-0016 started on M09
# [Day 2 18:43:56] Job J25-0033 finished on M00 (after 85 minutes 04 seconds)
# [Day 2 18:46:46] Job J25-0037 finished on M04 (after 30 minutes 47 seconds)
# [Day 2 18:52:46] Job J25-0025 finished on M02 (after 60 minutes 32 seconds)
# [Day 2 18:56:34] Job J25-0030 finished on M01 (after 63 minutes 42 seconds)
# [Day 2 18:56:34] Job J25-0020 started on M01
# [Day 2 18:56:34] Job J25-0030 started on M02
# [Day 2 19:01:58] Job J25-0024 finished on M03 (after 79 minutes 20 seconds)
# [Day 2 19:01:58] Job J25-0022 started on M03
# [Day 2 19:03:00] Job J25-0025 started on M08
# [Day 2 19:05:56] Job J25-0030 finished on M02 (after 09 minutes 22 seconds)
# [Day 2 19:13:00] Job J25-0037 started on M06
# [Day 2 19:13:36] Job J25-0016 finished on M09 (after 33 minutes 11 seconds)
# [Day 2 19:13:36] Job J25-0023 started on M09
# [Day 2 19:18:26] Job J25-0036 finished on M05 (after 46 minutes 27 seconds)
# [Day 2 19:18:26] Job J25-0021 started on M05
# [Day 2 19:23:02] Job J25-0020 finished on M01 (after 26 minutes 28 seconds)
# [Day 2 19:23:02] Job J25-0034 started on M01
# [Day 2 19:27:31] Job J25-0023 finished on M09 (after 13 minutes 55 seconds)
# [Day 2 19:27:31] Job J25-0024 started on M09
# [Day 2 19:43:09] Job J25-0022 finished on M03 (after 41 minutes 11 seconds)
# [Day 2 19:43:09] Job J25-0036 started on M03
# [Day 2 19:45:38] Job J25-0024 finished on M09 (after 18 minutes 08 seconds)
# [Day 2 19:50:00] Job J25-0022 started on M04
# [Day 2 20:16:04] Job J25-0021 finished on M05 (after 57 minutes 37 seconds)
# [Day 2 20:17:23] Job J25-0036 finished on M03 (after 34 minutes 14 seconds)
# [Day 2 20:17:23] Job J25-0021 started on M03
# [Day 2 20:20:00] Job J25-0027 started on M05
# [Day 2 20:21:00] Job J25-0035 started on M07
# [Day 2 20:29:12] Job J25-0034 finished on M01 (after 66 minutes 10 seconds)
# [Day 2 20:38:26] Job J25-0025 finished on M08 (after 95 minutes 27 seconds)
# [Day 2 20:38:26] Job J25-0016 started on M08
# [Day 2 20:49:03] Job J25-0035 finished on M07 (after 28 minutes 03 seconds)
# [Day 2 20:51:16] Job J25-0022 finished on M04 (after 61 minutes 16 seconds)
# [Day 2 21:04:25] Job J25-0037 finished on M06 (after 111 minutes 26 seconds)
# [Day 2 21:04:25] Job J25-0020 started on M06
# [Day 2 21:20:00] Job J25-0036 started on M04
# [Day 2 21:25:13] Job J25-0027 finished on M05 (after 65 minutes 14 seconds)
# [Day 2 21:34:00] Job J25-0025 started on M05
# [Day 2 21:45:34] Job J25-0025 finished on M05 (after 11 minutes 34 seconds)
# [Day 2 21:52:44] Job J25-0020 finished on M06 (after 48 minutes 19 seconds)
# [Day 2 21:52:44] Job J25-0023 started on M06
# [Day 2 21:52:44] Job J25-0020 started on M05
# [Day 2 21:56:28] Job J25-0016 finished on M08 (after 78 minutes 02 seconds)
# [Day 2 21:56:28] Job J25-0029 started on M08
# [Day 2 21:56:28] Job J25-0016 started on M07
# [Day 2 22:02:34] Job J25-0021 finished on M03 (after 105 minutes 11 seconds)
# [Day 2 22:02:34] Job J25-0028 started on M03
# [Day 2 22:06:13] Job J25-0036 finished on M04 (after 46 minutes 13 seconds)
# [Day 2 22:15:22] Job J25-0029 finished on M08 (after 18 minutes 54 seconds)
# [Day 2 22:15:22] Job J25-0037 started on M08
# [Day 2 22:18:28] Job J25-0016 finished on M07 (after 22 minutes)
# [Day 2 22:18:28] Job J25-0029 started on M07
# [Day 2 22:24:19] Job J25-0023 finished on M06 (after 31 minutes 35 seconds)
# [Day 2 22:30:52] Job J25-0037 finished on M08 (after 15 minutes 29 seconds)
# [Day 2 22:30:52] Job J25-0021 started on M08
# [Day 2 22:30:52] Job J25-0037 started on M09
# [Day 2 22:31:59] Job J25-0028 finished on M03 (after 29 minutes 25 seconds)
# [Day 2 22:31:59] Job J25-0030 started on M03
# [Day 2 22:31:59] Job J25-0028 started on M04
# [Day 2 22:48:37] Job J25-0020 finished on M05 (after 55 minutes 53 seconds)
# [Day 2 22:55:36] Job J25-0029 finished on M07 (after 37 minutes 08 seconds)
# [Day 2 22:55:36] Job J25-0023 started on M07
# [Day 2 23:13:19] Job J25-0030 finished on M03 (after 41 minutes 20 seconds)
# [Day 2 23:13:19] Job J25-0034 started on M03
# [Day 2 23:22:05] Job J25-0028 finished on M04 (after 50 minutes 07 seconds)
# [Day 2 23:22:05] Job J25-0027 started on M04
# [Day 2 23:22:05] Job J25-0028 started on M05
# [Day 2 23:23:01] Job J25-0021 finished on M08 (after 52 minutes 10 seconds)
# [Day 2 23:23:01] Job J25-0036 started on M08
# [Day 2 23:23:39] Job J25-0037 finished on M09 (after 52 minutes 47 seconds)
# [Day 2 23:23:39] Job J25-0021 started on M09
# [Day 2 23:31:55] Job J25-0028 finished on M05 (after 09 minutes 50 seconds)
# [Day 2 23:46:16] Job J25-0036 finished on M08 (after 23 minutes 14 seconds)
# [Day 2 23:51:34] Job J25-0027 finished on M04 (after 29 minutes 28 seconds)
# [Day 3 00:05:56] Job J25-0023 finished on M07 (after 70 minutes 20 seconds)
# [Day 3 00:21:04] Job J25-0021 finished on M09 (after 57 minutes 25 seconds)
# [Day 3 00:59:33] Job J25-0034 finished on M03 (after 106 minutes 14 seconds)
#
# [Day 3 00:59:33] Simulation ended! There are no more active Operations

# %%
show.plot_gantt(df_execution, perspective="Machine", title=f"Gantt-Diagramm für Simulationstag {day_numb}")

# %%
df_ops_finished = df_execution[df_execution.End < day_end]
JobOperation.add_from_dataframe(df_ops_finished, version=this_version, status="finished")
df_ops_finished
# Out:
# ✅ 176 JobOperation-Einträge (Version 'lateness_simple', Status 'finished') wurden hinzugefügt oder aktualisiert.
#           Job Routing_ID  Operation Machine  Arrival    Start  \
# 0    J25-0000          8          8     M04       79  2892.00
# 1    J25-0000          8          9     M08       79  3634.18
# 2    J25-0002          0          9     M09      198  3723.00
# 3    J25-0003          2          9     M04      243  3346.00
# 4    J25-0004          3          6     M07      287  3017.00
# ..        ...        ...        ...     ...      ...      ...
# 174  J25-0037          7          3     M05     2801  3842.47
# 175  J25-0037          7          4     M04     2801  3976.00
# 176  J25-0037          7          5     M06     2801  4033.00
# 177  J25-0037          7          6     M08     2801  4215.38
# 178  J25-0037          7          7     M09     2801  4230.87
#
#      Processing Time      End
# 0              29.11  2921.11
# 1              55.83  3690.01
# 2              18.82  3741.82
# 3              33.86  3379.86
# 4             111.57  3128.57
# ..               ...      ...
# 174            79.28  3921.75
# 175            30.78  4006.78
# 176           111.43  4144.43
# 177            15.49  4230.87
# 178            52.79  4283.66
#
# [176 rows x 8 columns]

# %%
JobOperation.update_closed_jobs_from_operations(version=this_version)
# Out:
# ✅ 14 Job(s) wurden auf 'closed' gesetzt (Version 'lateness_simple').
# ['J25-0001',
#  'J25-0002',
#  'J25-0003',
#  'J25-0005',
#  'J25-0007',
#  'J25-0008',
#  'J25-0009',
#  'J25-0010',
#  'J25-0011',
#  'J25-0013',
#  'J25-0014',
#  'J25-0015',
#  'J25-0032',
#  'J25-0035']

# %%
df_ops_in_progess = df_execution[df_execution.End >= day_end]
JobOperation.add_from_dataframe(df_ops_in_progess, version=this_version, status="in progress")
df_ops_in_progess
# Out:
# ✅ 3 JobOperation-Einträge (Version 'lateness_simple', Status 'in progress') wurden hinzugefügt oder aktualisiert.
#           Job Routing_ID  Operation Machine  Arrival    Start  \
# 65   J25-0021          5          5     M09     1952  4283.66
# 82   J25-0023          8          7     M07     2055  4255.61
# 153  J25-0034          8          2     M03     2715  4273.33
#
#      Processing Time      End
# 65             57.41  4341.07
# 82             70.33  4325.94
# 153           106.23  4379.56
