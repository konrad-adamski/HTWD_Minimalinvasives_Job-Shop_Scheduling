# %% [markdown]
# # Deadlines aus Simulation (FIFO)

# %%
# Datenzugriff
from configs.config import get_path

# Utils
import src.utils.presenter as show
from src.utils.analize import check_constrains as check

from src.utils.production_process import initialize as init

# Extern
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.min_rows', 16)
pd.set_option('display.max_rows', 24)

# %%
# Simulation
from src.simulation.ProductionSimulation import ProductionSimulation

# %%
day_count = 4
basic_data_path = get_path("data", "basic")

df_instance = pd.read_csv(basic_data_path / "instance.csv")
df_jssp, df_jobs_arrivals = init.create_production_orders_for_shifts(df_template=df_instance, shift_count=day_count,
                                                                 shift_length=1440, shuffle=True, 
                                                                 job_seed=40, arrival_seed=80)
df_jobs_arrivals
# Out:
#     Job  Production_Plan_ID  Arrival
# 0     0                   0       51
# 1     1                   1      136
# 2     2                   2      158
# 3     3                   3      236
# 4     4                   4      404
# 5     5                   5      485
# 6     6                   6      501
# 7     7                   7      528
# ..  ...                 ...      ...
# 63   63                   5     5239
# 64   64                   9     5413
# 65   65                   8     5586
# 66   66                   4     5587
# 67   67                   0     5649
# 68   68                   6     5651
# 69   69                   1     5667
# 70   70                   0     5757
#
# [71 rows x 3 columns]

# %%
shift_length=1440

df_jobs_arrivals['Ready Time'] = df_jobs_arrivals['Arrival'].apply(lambda arrival: math.ceil((arrival + 1) / shift_length) * shift_length)
df_jobs_arrivals
# Out:
#     Job  Production_Plan_ID  Arrival  Ready Time
# 0     0                   0       51        1440
# 1     1                   1      136        1440
# 2     2                   2      158        1440
# 3     3                   3      236        1440
# 4     4                   4      404        1440
# 5     5                   5      485        1440
# 6     6                   6      501        1440
# 7     7                   7      528        1440
# ..  ...                 ...      ...         ...
# 63   63                   5     5239        5760
# 64   64                   9     5413        5760
# 65   65                   8     5586        5760
# 66   66                   4     5587        5760
# 67   67                   0     5649        5760
# 68   68                   6     5651        5760
# 69   69                   1     5667        5760
# 70   70                   0     5757        5760
#
# [71 rows x 4 columns]

# %%
df_jssp = df_jssp.merge(
    df_jobs_arrivals[['Job', 'Production_Plan_ID','Arrival', 'Ready Time']],
    on=['Job', 'Production_Plan_ID'],
    how='left'
)
df_jssp
# Out:
#      Job  Production_Plan_ID  Operation Machine  Processing Time  Arrival  \
# 0      0                   0          0     M00               29       51
# 1      0                   0          1     M01               78       51
# 2      0                   0          2     M02                9       51
# 3      0                   0          3     M03               36       51
# 4      0                   0          4     M04               49       51
# 5      0                   0          5     M05               11       51
# 6      0                   0          6     M06               62       51
# 7      0                   0          7     M07               56       51
# ..   ...                 ...        ...     ...              ...      ...
# 702   70                   0          2     M02                9     5757
# 703   70                   0          3     M03               36     5757
# 704   70                   0          4     M04               49     5757
# 705   70                   0          5     M05               11     5757
# 706   70                   0          6     M06               62     5757
# 707   70                   0          7     M07               56     5757
# 708   70                   0          8     M08               44     5757
# 709   70                   0          9     M09               21     5757
#
#      Ready Time
# 0          1440
# 1          1440
# 2          1440
# 3          1440
# 4          1440
# 5          1440
# 6          1440
# 7          1440
# ..          ...
# 702        5760
# 703        5760
# 704        5760
# 705        5760
# 706        5760
# 707        5760
# 708        5760
# 709        5760
#
# [710 rows x 7 columns]

# %% [markdown]
# ## I) Simulation

# %%
simulation = ProductionSimulation(df_jssp, earliest_start_column = "Ready Time", sigma=0)
df_fcfs_execution = simulation.run(start_time = 0, end_time=None)
# Out:
# [Day 1 00:00:00] Job 0 started on M00
# [Day 1 00:00:00] Job 2 started on M01
# [Day 1 00:00:00] Job 4 started on M02
# [Day 1 00:14:00] Job 4 finished on M02 (after 14 minutes)
# [Day 1 00:14:00] Job 5 started on M02
# [Day 1 00:29:00] Job 0 finished on M00 (after 29 minutes)
# [Day 1 00:29:00] Job 1 started on M00
# [Day 1 01:12:00] Job 1 finished on M00 (after 43 minutes)
# [Day 1 01:12:00] Job 8 started on M00
# [Day 1 01:31:00] Job 2 finished on M01 (after 91 minutes)
# [Day 1 01:31:00] Job 3 started on M01
# [Day 1 01:38:00] Job 5 finished on M02 (after 84 minutes)
# [Day 1 01:38:00] Job 7 started on M02
# [Day 1 02:09:00] Job 7 finished on M02 (after 31 minutes)
# [Day 1 02:09:00] Job 14 started on M02
# [Day 1 02:23:00] Job 14 finished on M02 (after 14 minutes)
# [Day 1 02:23:00] Job 15 started on M02
# [Day 1 02:28:00] Job 8 finished on M00 (after 76 minutes)
# [Day 1 02:28:00] Job 10 started on M00
# [Day 1 02:52:00] Job 3 finished on M01 (after 81 minutes)
# [Day 1 02:52:00] Job 6 started on M01
# [Day 1 02:54:00] Job 15 finished on M02 (after 31 minutes)
# [Day 1 02:54:00] Job 1 started on M02
# [Day 1 02:57:00] Job 10 finished on M00 (after 29 minutes)
# [Day 1 02:57:00] Job 12 started on M00
# [Day 1 03:38:00] Job 6 finished on M01 (after 46 minutes)
# [Day 1 03:38:00] Job 9 started on M01
# [Day 1 04:13:00] Job 12 finished on M00 (after 76 minutes)
# [Day 1 04:13:00] Job 16 started on M00
# [Day 1 04:24:00] Job 1 finished on M02 (after 90 minutes)
# [Day 1 04:24:00] Job 3 started on M02
# [Day 1 04:24:00] Job 1 started on M04
# [Day 1 04:56:00] Job 16 finished on M00 (after 43 minutes)
# [Day 1 04:56:00] Job 4 started on M00
# [Day 1 05:02:00] Job 4 finished on M00 (after 06 minutes)
# [Day 1 05:02:00] Job 2 started on M00
# [Day 1 05:03:00] Job 9 finished on M01 (after 85 minutes)
# [Day 1 05:03:00] Job 11 started on M01
# [Day 1 05:39:00] Job 1 finished on M04 (after 75 minutes)
# [Day 1 05:39:00] Job 1 started on M09
# [Day 1 05:50:00] Job 1 finished on M09 (after 11 minutes)
# [Day 1 05:50:00] Job 1 started on M03
# [Day 1 05:59:00] Job 3 finished on M02 (after 95 minutes)
# [Day 1 05:59:00] Job 16 started on M02
# [Day 1 06:27:00] Job 2 finished on M00 (after 85 minutes)
# [Day 1 06:27:00] Job 7 started on M00
# [Day 1 06:28:00] Job 11 finished on M01 (after 85 minutes)
# [Day 1 06:28:00] Job 13 started on M01
# [Day 1 06:59:00] Job 1 finished on M03 (after 69 minutes)
# [Day 1 06:59:00] Job 2 started on M03
# [Day 1 07:29:00] Job 16 finished on M02 (after 90 minutes)
# [Day 1 07:29:00] Job 16 started on M04
# [Day 1 07:38:00] Job 2 finished on M03 (after 39 minutes)
# [Day 1 07:38:00] Job 2 started on M02
# [Day 1 07:53:00] Job 7 finished on M00 (after 86 minutes)
# [Day 1 07:53:00] Job 14 started on M00
# [Day 1 07:59:00] Job 13 finished on M01 (after 91 minutes)
# [Day 1 07:59:00] Job 14 finished on M00 (after 06 minutes)
# [Day 1 07:59:00] Job 17 started on M01
# [Day 1 07:59:00] Job 15 started on M00
# [Day 1 08:44:00] Job 16 finished on M04 (after 75 minutes)
# [Day 1 08:44:00] Job 16 started on M09
# [Day 1 08:52:00] Job 2 finished on M02 (after 74 minutes)
# [Day 1 08:52:00] Job 2 started on M08
# [Day 1 08:55:00] Job 16 finished on M09 (after 11 minutes)
# [Day 1 08:55:00] Job 16 started on M03
# [Day 1 09:20:00] Job 17 finished on M01 (after 81 minutes)
# [Day 1 09:20:00] Job 0 started on M01
# [Day 1 09:20:00] Job 17 started on M02
# [Day 1 09:25:00] Job 15 finished on M00 (after 86 minutes)
# [Day 1 09:25:00] Job 6 started on M00
# [Day 1 10:02:00] Job 6 finished on M00 (after 37 minutes)
# [Day 1 10:02:00] Job 9 started on M00
# [Day 1 10:04:00] Job 16 finished on M03 (after 69 minutes)
# [Day 1 10:04:00] Job 6 started on M03
# [Day 1 10:15:00] Job 9 finished on M00 (after 13 minutes)
# [Day 1 10:15:00] Job 3 started on M00
# [Day 1 10:22:00] Job 2 finished on M08 (after 90 minutes)
# [Day 1 10:22:00] Job 2 started on M05
# [Day 1 10:32:00] Job 2 finished on M05 (after 10 minutes)
# [Day 1 10:32:00] Job 2 started on M07
# [Day 1 10:38:00] Job 0 finished on M01 (after 78 minutes)
# [Day 1 10:38:00] Job 5 started on M01
# [Day 1 10:40:00] Job 5 finished on M01 (after 02 minutes)
# [Day 1 10:40:00] Job 8 started on M01
# [Day 1 10:40:00] Job 5 started on M05
# [Day 1 10:44:00] Job 2 finished on M07 (after 12 minutes)
# [Day 1 10:44:00] Job 2 started on M06
# [Day 1 10:55:00] Job 17 finished on M02 (after 95 minutes)
# [Day 1 10:55:00] Job 9 started on M02
# [Day 1 11:05:00] Job 6 finished on M03 (after 61 minutes)
# [Day 1 11:26:00] Job 3 finished on M00 (after 71 minutes)
# [Day 1 11:26:00] Job 11 started on M00
# [Day 1 11:26:00] Job 3 started on M04
# [Day 1 11:32:00] Job 5 finished on M05 (after 52 minutes)
# [Day 1 11:32:00] Job 5 started on M03
# [Day 1 11:39:00] Job 11 finished on M00 (after 13 minutes)
# [Day 1 11:39:00] Job 13 started on M00
# [Day 1 11:49:00] Job 8 finished on M01 (after 69 minutes)
# [Day 1 11:49:00] Job 10 started on M01
# [Day 1 11:56:00] Job 9 finished on M02 (after 61 minutes)
# [Day 1 11:56:00] Job 0 started on M02
# [Day 1 12:05:00] Job 0 finished on M02 (after 09 minutes)
# [Day 1 12:05:00] Job 6 started on M02
# [Day 1 12:13:00] Job 2 finished on M06 (after 89 minutes)
# [Day 1 12:13:00] Job 9 started on M06
# [Day 1 12:13:00] Job 2 started on M09
# [Day 1 12:18:00] Job 6 finished on M02 (after 13 minutes)
# [Day 1 12:18:00] Job 11 started on M02
# [Day 1 12:20:00] Job 9 finished on M06 (after 07 minutes)
# [Day 1 12:20:00] Job 6 started on M06
# [Day 1 12:20:00] Job 9 started on M08
# [Day 1 12:52:00] Job 6 finished on M06 (after 32 minutes)
# [Day 1 12:52:00] Job 6 started on M05
# [Day 1 12:58:00] Job 2 finished on M09 (after 45 minutes)
# [Day 1 13:04:00] Job 13 finished on M00 (after 85 minutes)
# [Day 1 13:04:00] Job 17 started on M00
# [Day 1 13:05:00] Job 3 finished on M04 (after 99 minutes)
# [Day 1 13:05:00] Job 2 started on M04
# [Day 1 13:05:00] Job 3 started on M06
# [Day 1 13:07:00] Job 5 finished on M03 (after 95 minutes)
# [Day 1 13:07:00] Job 10 finished on M01 (after 78 minutes)
# [Day 1 13:07:00] Job 8 started on M03
# [Day 1 13:07:00] Job 12 started on M01
# [Day 1 13:13:00] Job 6 finished on M05 (after 21 minutes)
# [Day 1 13:13:00] Job 6 started on M09
# [Day 1 13:14:00] Job 3 finished on M06 (after 09 minutes)
# [Day 1 13:19:00] Job 11 finished on M02 (after 61 minutes)
# [Day 1 13:19:00] Job 10 started on M02
# [Day 1 13:19:00] Job 11 started on M06
# [Day 1 13:24:00] Job 9 finished on M08 (after 64 minutes)
# [Day 1 13:24:00] Job 5 started on M08
# [Day 1 13:26:00] Job 11 finished on M06 (after 07 minutes)
# [Day 1 13:28:00] Job 10 finished on M02 (after 09 minutes)
# [Day 1 13:38:00] Job 2 finished on M04 (after 33 minutes)
# [Day 1 13:45:00] Job 6 finished on M09 (after 32 minutes)
# [Day 1 13:45:00] Job 9 started on M09
# [Day 1 14:12:00] Job 5 finished on M08 (after 48 minutes)
# [Day 1 14:12:00] Job 3 started on M08
# [Day 1 14:15:00] Job 17 finished on M00 (after 71 minutes)
# [Day 1 14:15:00] Job 17 started on M04
# [Day 1 14:16:00] Job 12 finished on M01 (after 69 minutes)
# [Day 1 14:16:00] Job 4 started on M01
# [Day 1 14:23:00] Job 8 finished on M03 (after 76 minutes)
# [Day 1 14:23:00] Job 0 started on M03
# [Day 1 14:23:00] Job 8 started on M05
# [Day 1 14:38:00] Job 4 finished on M01 (after 22 minutes)
# [Day 1 14:38:00] Job 1 started on M01
# [Day 1 14:59:00] Job 0 finished on M03 (after 36 minutes)
# [Day 1 14:59:00] Job 13 started on M03
# [Day 1 15:01:00] Job 9 finished on M09 (after 76 minutes)
# [Day 1 15:01:00] Job 5 started on M09
# [Day 1 15:04:00] Job 3 finished on M08 (after 52 minutes)
# [Day 1 15:04:00] Job 11 started on M08
# [Day 1 15:04:00] Job 3 started on M07
# [Day 1 15:06:00] Job 1 finished on M01 (after 28 minutes)
# [Day 1 15:06:00] Job 7 started on M01
# [Day 1 15:06:00] Job 1 started on M06
# [Day 1 15:14:00] Job 8 finished on M05 (after 51 minutes)
# [Day 1 15:14:00] Job 4 started on M05
# [Day 1 15:14:00] Job 8 started on M02
# [Day 1 15:38:00] Job 13 finished on M03 (after 39 minutes)
# [Day 1 15:38:00] Job 10 started on M03
# [Day 1 15:52:00] Job 7 finished on M01 (after 46 minutes)
# [Day 1 15:52:00] Job 1 finished on M06 (after 46 minutes)
# [Day 1 15:52:00] Job 14 started on M01
# [Day 1 15:54:00] Job 17 finished on M04 (after 99 minutes)
# [Day 1 15:54:00] Job 0 started on M04
# [Day 1 15:54:00] Job 17 started on M06
# [Day 1 16:03:00] Job 17 finished on M06 (after 09 minutes)
# [Day 1 16:08:00] Job 11 finished on M08 (after 64 minutes)
# [Day 1 16:08:00] Job 6 started on M08
# [Day 1 16:13:00] Job 5 finished on M09 (after 72 minutes)
# [Day 1 16:13:00] Job 11 started on M09
# [Day 1 16:13:00] Job 5 started on M00
# [Day 1 16:14:00] Job 10 finished on M03 (after 36 minutes)
# [Day 1 16:14:00] Job 14 finished on M01 (after 22 minutes)
# [Day 1 16:14:00] Job 12 started on M03
# [Day 1 16:14:00] Job 15 started on M01
# [Day 1 16:15:00] Job 4 finished on M05 (after 61 minutes)
# [Day 1 16:15:00] Job 9 started on M05
# [Day 1 16:29:00] Job 3 finished on M07 (after 85 minutes)
# [Day 1 16:39:00] Job 8 finished on M02 (after 85 minutes)
# [Day 1 16:39:00] Job 13 started on M02
# [Day 1 16:43:00] Job 0 finished on M04 (after 49 minutes)
# [Day 1 16:43:00] Job 10 started on M04
# [Day 1 17:00:00] Job 5 finished on M00 (after 47 minutes)
# [Day 1 17:00:00] Job 15 finished on M01 (after 46 minutes)
# [Day 1 17:00:00] Job 5 started on M06
# [Day 1 17:00:00] Job 16 started on M01
# [Day 1 17:02:00] Job 9 finished on M05 (after 47 minutes)
# [Day 1 17:02:00] Job 7 started on M05
# [Day 1 17:28:00] Job 16 finished on M01 (after 28 minutes)
# [Day 1 17:29:00] Job 11 finished on M09 (after 76 minutes)
# [Day 1 17:29:00] Job 8 started on M09
# [Day 1 17:30:00] Job 12 finished on M03 (after 76 minutes)
# [Day 1 17:30:00] Job 4 started on M03
# [Day 1 17:32:00] Job 10 finished on M04 (after 49 minutes)
# [Day 1 17:37:00] Job 6 finished on M08 (after 89 minutes)
# [Day 1 17:37:00] Job 17 started on M08
# [Day 1 17:37:00] Job 6 started on M07
# [Day 1 17:40:00] Job 8 finished on M09 (after 11 minutes)
# [Day 1 17:53:00] Job 13 finished on M02 (after 74 minutes)
# [Day 1 17:56:00] Job 4 finished on M03 (after 26 minutes)
# [Day 1 17:56:00] Job 3 started on M03
# [Day 1 17:56:00] Job 4 started on M04
# [Day 1 18:05:00] Job 5 finished on M06 (after 65 minutes)
# [Day 1 18:05:00] Job 16 started on M06
# [Day 1 18:07:00] Job 6 finished on M07 (after 30 minutes)
# [Day 1 18:16:00] Job 7 finished on M05 (after 74 minutes)
# [Day 1 18:16:00] Job 1 started on M05
# [Day 1 18:29:00] Job 17 finished on M08 (after 52 minutes)
# [Day 1 18:29:00] Job 13 started on M08
# [Day 1 18:29:00] Job 17 started on M07
# [Day 1 18:51:00] Job 16 finished on M06 (after 46 minutes)
# [Day 1 18:51:00] Job 8 started on M06
# [Day 1 19:02:00] Job 1 finished on M05 (after 46 minutes)
# [Day 1 19:02:00] Job 14 started on M05
# [Day 1 19:05:00] Job 4 finished on M04 (after 69 minutes)
# [Day 1 19:05:00] Job 5 started on M04
# [Day 1 19:11:00] Job 5 finished on M04 (after 06 minutes)
# [Day 1 19:11:00] Job 6 started on M04
# [Day 1 19:31:00] Job 8 finished on M06 (after 40 minutes)
# [Day 1 19:34:00] Job 3 finished on M03 (after 98 minutes)
# [Day 1 19:34:00] Job 9 started on M03
# [Day 1 19:34:00] Job 3 started on M09
# [Day 1 19:54:00] Job 17 finished on M07 (after 85 minutes)
# [Day 1 19:54:00] Job 1 started on M07
# [Day 1 19:56:00] Job 3 finished on M09 (after 22 minutes)
# [Day 1 19:59:00] Job 13 finished on M08 (after 90 minutes)
# [Day 1 19:59:00] Job 4 started on M08
# [Day 1 20:03:00] Job 14 finished on M05 (after 61 minutes)
# [Day 1 20:03:00] Job 0 started on M05
# [Day 1 20:06:00] Job 6 finished on M04 (after 55 minutes)
# [Day 1 20:06:00] Job 7 started on M04
# [Day 1 20:14:00] Job 0 finished on M05 (after 11 minutes)
# [Day 1 20:14:00] Job 15 started on M05
# [Day 1 20:14:00] Job 0 started on M06
# [Day 1 20:20:00] Job 4 finished on M08 (after 21 minutes)
# [Day 1 20:26:00] Job 9 finished on M03 (after 52 minutes)
# [Day 1 20:26:00] Job 17 started on M03
# [Day 1 20:38:00] Job 7 finished on M04 (after 32 minutes)
# [Day 1 20:38:00] Job 9 started on M04
# [Day 1 21:06:00] Job 1 finished on M07 (after 72 minutes)
# [Day 1 21:06:00] Job 5 started on M07
# [Day 1 21:06:00] Job 1 started on M08
# [Day 1 21:16:00] Job 0 finished on M06 (after 62 minutes)
# [Day 1 21:16:00] Job 7 started on M06
# [Day 1 21:28:00] Job 15 finished on M05 (after 74 minutes)
# [Day 1 21:28:00] Job 11 started on M05
# [Day 1 21:31:00] Job 5 finished on M07 (after 25 minutes)
# [Day 1 21:31:00] Job 8 started on M07
# [Day 1 21:36:00] Job 1 finished on M08 (after 30 minutes)
# [Day 1 22:04:00] Job 17 finished on M03 (after 98 minutes)
# [Day 1 22:04:00] Job 14 started on M03
# [Day 1 22:04:00] Job 17 started on M09
# [Day 1 22:08:00] Job 9 finished on M04 (after 90 minutes)
# [Day 1 22:08:00] Job 15 started on M04
# [Day 1 22:15:00] Job 11 finished on M05 (after 47 minutes)
# [Day 1 22:15:00] Job 12 started on M05
# [Day 1 22:26:00] Job 17 finished on M09 (after 22 minutes)
# [Day 1 22:30:00] Job 14 finished on M03 (after 26 minutes)
# [Day 1 22:30:00] Job 11 started on M03
# [Day 1 22:40:00] Job 15 finished on M04 (after 32 minutes)
# [Day 1 22:40:00] Job 14 started on M04
# [Day 1 22:44:00] Job 7 finished on M06 (after 88 minutes)
# [Day 1 22:44:00] Job 15 started on M06
# [Day 1 22:44:00] Job 7 started on M08
# [Day 1 23:00:00] Job 8 finished on M07 (after 89 minutes)
# [Day 1 23:00:00] Job 4 started on M07
# [Day 1 23:03:00] Job 7 finished on M08 (after 19 minutes)
# [Day 1 23:03:00] Job 7 started on M09
# [Day 1 23:06:00] Job 12 finished on M05 (after 51 minutes)
# [Day 1 23:06:00] Job 10 started on M05
# [Day 1 23:06:00] Job 12 started on M02
# [Day 1 23:17:00] Job 10 finished on M05 (after 11 minutes)
# [Day 1 23:17:00] Job 16 started on M05
# [Day 1 23:22:00] Job 11 finished on M03 (after 52 minutes)
# [Day 1 23:49:00] Job 14 finished on M04 (after 69 minutes)
# [Day 1 23:49:00] Job 4 finished on M07 (after 49 minutes)
# [Day 1 23:49:00] Job 8 started on M04
# [Day 1 23:49:00] Job 14 started on M08
# [Day 1 23:49:00] Job 0 started on M07
# [Day 1 23:51:00] Job 7 finished on M09 (after 48 minutes)
# [Day 1 23:51:00] Job 4 started on M09
# [Day 2 00:00:00] Job 19 started on M01
# [Day 2 00:00:00] Job 23 started on M00
# [Day 2 00:03:00] Job 16 finished on M05 (after 46 minutes)
# [Day 2 00:03:00] Job 3 started on M05
# [Day 2 00:10:00] Job 14 finished on M08 (after 21 minutes)
# [Day 2 00:12:00] Job 15 finished on M06 (after 88 minutes)
# [Day 2 00:12:00] Job 10 started on M06
# [Day 2 00:12:00] Job 15 started on M08
# [Day 2 00:15:00] Job 8 finished on M04 (after 26 minutes)
# [Day 2 00:15:00] Job 11 started on M04
# [Day 2 00:31:00] Job 12 finished on M02 (after 85 minutes)
# [Day 2 00:31:00] Job 15 finished on M08 (after 19 minutes)
# [Day 2 00:31:00] Job 18 started on M02
# [Day 2 00:31:00] Job 8 started on M08
# [Day 2 00:45:00] Job 0 finished on M07 (after 56 minutes)
# [Day 2 00:45:00] Job 9 started on M07
# [Day 2 00:46:00] Job 19 finished on M01 (after 46 minutes)
# [Day 2 00:46:00] Job 3 finished on M05 (after 43 minutes)
# [Day 2 00:46:00] Job 21 started on M01
# [Day 2 00:46:00] Job 13 started on M05
# [Day 2 00:56:00] Job 13 finished on M05 (after 10 minutes)
# [Day 2 00:56:00] Job 17 started on M05
# [Day 2 01:03:00] Job 4 finished on M09 (after 72 minutes)
# [Day 2 01:03:00] Job 12 started on M09
# [Day 2 01:14:00] Job 10 finished on M06 (after 62 minutes)
# [Day 2 01:14:00] Job 12 finished on M09 (after 11 minutes)
# [Day 2 01:14:00] Job 4 started on M06
# [Day 2 01:14:00] Job 15 started on M09
# [Day 2 01:16:00] Job 23 finished on M00 (after 76 minutes)
# [Day 2 01:16:00] Job 28 started on M00
# [Day 2 01:30:00] Job 9 finished on M07 (after 45 minutes)
# [Day 2 01:30:00] Job 7 started on M07
# [Day 2 01:39:00] Job 17 finished on M05 (after 43 minutes)
# [Day 2 01:45:00] Job 11 finished on M04 (after 90 minutes)
# [Day 2 01:45:00] Job 8 finished on M08 (after 74 minutes)
# [Day 2 01:45:00] Job 28 finished on M00 (after 29 minutes)
# [Day 2 01:45:00] Job 0 started on M08
# [Day 2 01:45:00] Job 29 started on M00
# [Day 2 01:55:00] Job 18 finished on M02 (after 84 minutes)
# [Day 2 01:55:00] Job 20 started on M02
# [Day 2 02:02:00] Job 15 finished on M09 (after 48 minutes)
# [Day 2 02:06:00] Job 7 finished on M07 (after 36 minutes)
# [Day 2 02:06:00] Job 16 started on M07
# [Day 2 02:06:00] Job 7 started on M03
# [Day 2 02:07:00] Job 21 finished on M01 (after 81 minutes)
# [Day 2 02:07:00] Job 4 finished on M06 (after 53 minutes)
# [Day 2 02:07:00] Job 22 started on M01
# [Day 2 02:07:00] Job 12 started on M06
# [Day 2 02:26:00] Job 20 finished on M02 (after 31 minutes)
# [Day 2 02:26:00] Job 24 started on M02
# [Day 2 02:28:00] Job 29 finished on M00 (after 43 minutes)
# [Day 2 02:28:00] Job 30 started on M00
# [Day 2 02:29:00] Job 0 finished on M08 (after 44 minutes)
# [Day 2 02:29:00] Job 0 started on M09
# [Day 2 02:47:00] Job 12 finished on M06 (after 40 minutes)
# [Day 2 02:50:00] Job 0 finished on M09 (after 21 minutes)
# [Day 2 03:18:00] Job 16 finished on M07 (after 72 minutes)
# [Day 2 03:18:00] Job 14 started on M07
# [Day 2 03:18:00] Job 16 started on M08
# [Day 2 03:25:00] Job 7 finished on M03 (after 79 minutes)
# [Day 2 03:38:00] Job 22 finished on M01 (after 91 minutes)
# [Day 2 03:38:00] Job 25 started on M01
# [Day 2 03:44:00] Job 30 finished on M00 (after 76 minutes)
# [Day 2 03:44:00] Job 31 started on M00
# [Day 2 03:48:00] Job 16 finished on M08 (after 30 minutes)
# [Day 2 03:50:00] Job 24 finished on M02 (after 84 minutes)
# [Day 2 03:50:00] Job 27 started on M02
# [Day 2 04:04:00] Job 27 finished on M02 (after 14 minutes)
# [Day 2 04:04:00] Job 32 started on M02
# [Day 2 04:07:00] Job 14 finished on M07 (after 49 minutes)
# [Day 2 04:07:00] Job 13 started on M07
# [Day 2 04:07:00] Job 14 started on M09
# [Day 2 04:19:00] Job 13 finished on M07 (after 12 minutes)
# [Day 2 04:19:00] Job 10 started on M07
# [Day 2 04:19:00] Job 13 started on M06
# [Day 2 04:24:00] Job 25 finished on M01 (after 46 minutes)
# [Day 2 04:24:00] Job 26 started on M01
# [Day 2 04:27:00] Job 31 finished on M00 (after 43 minutes)
# [Day 2 04:27:00] Job 39 started on M00
# [Day 2 04:56:00] Job 39 finished on M00 (after 29 minutes)
# [Day 2 04:56:00] Job 19 started on M00
# [Day 2 05:15:00] Job 10 finished on M07 (after 56 minutes)
# [Day 2 05:15:00] Job 11 started on M07
# [Day 2 05:15:00] Job 10 started on M08
# [Day 2 05:19:00] Job 14 finished on M09 (after 72 minutes)
# [Day 2 05:28:00] Job 32 finished on M02 (after 84 minutes)
# [Day 2 05:28:00] Job 35 started on M02
# [Day 2 05:33:00] Job 19 finished on M00 (after 37 minutes)
# [Day 2 05:33:00] Job 20 started on M00
# [Day 2 05:33:00] Job 19 started on M03
# [Day 2 05:48:00] Job 13 finished on M06 (after 89 minutes)
# [Day 2 05:48:00] Job 14 started on M06
# [Day 2 05:48:00] Job 13 started on M09
# [Day 2 05:49:00] Job 26 finished on M01 (after 85 minutes)
# [Day 2 05:49:00] Job 33 started on M01
# [Day 2 05:59:00] Job 10 finished on M08 (after 44 minutes)
# [Day 2 05:59:00] Job 35 finished on M02 (after 31 minutes)
# [Day 2 05:59:00] Job 38 started on M02
# [Day 2 06:00:00] Job 11 finished on M07 (after 45 minutes)
# [Day 2 06:00:00] Job 15 started on M07
# [Day 2 06:13:00] Job 38 finished on M02 (after 14 minutes)
# [Day 2 06:13:00] Job 21 started on M02
# [Day 2 06:33:00] Job 13 finished on M09 (after 45 minutes)
# [Day 2 06:33:00] Job 10 started on M09
# [Day 2 06:33:00] Job 13 started on M04
# [Day 2 06:34:00] Job 19 finished on M03 (after 61 minutes)
# [Day 2 06:35:00] Job 33 finished on M01 (after 46 minutes)
# [Day 2 06:35:00] Job 34 started on M01
# [Day 2 06:36:00] Job 15 finished on M07 (after 36 minutes)
# [Day 2 06:36:00] Job 12 started on M07
# [Day 2 06:36:00] Job 15 started on M03
# [Day 2 06:41:00] Job 14 finished on M06 (after 53 minutes)
# [Day 2 06:54:00] Job 10 finished on M09 (after 21 minutes)
# [Day 2 06:59:00] Job 20 finished on M00 (after 86 minutes)
# [Day 2 06:59:00] Job 22 started on M00
# [Day 2 07:06:00] Job 13 finished on M04 (after 33 minutes)
# [Day 2 07:48:00] Job 21 finished on M02 (after 95 minutes)
# [Day 2 07:48:00] Job 29 started on M02
# [Day 2 07:55:00] Job 15 finished on M03 (after 79 minutes)
# [Day 2 08:00:00] Job 34 finished on M01 (after 85 minutes)
# [Day 2 08:00:00] Job 36 started on M01
# [Day 2 08:05:00] Job 12 finished on M07 (after 89 minutes)
# [Day 2 08:05:00] Job 12 started on M04
# [Day 2 08:24:00] Job 22 finished on M00 (after 85 minutes)
# [Day 2 08:24:00] Job 27 started on M00
# [Day 2 08:24:00] Job 22 started on M03
# [Day 2 08:30:00] Job 27 finished on M00 (after 06 minutes)
# [Day 2 08:30:00] Job 25 started on M00
# [Day 2 08:31:00] Job 12 finished on M04 (after 26 minutes)
# [Day 2 08:31:00] Job 12 started on M08
# [Day 2 09:03:00] Job 22 finished on M03 (after 39 minutes)
# [Day 2 09:07:00] Job 25 finished on M00 (after 37 minutes)
# [Day 2 09:07:00] Job 26 started on M00
# [Day 2 09:07:00] Job 25 started on M03
# [Day 2 09:18:00] Job 29 finished on M02 (after 90 minutes)
# [Day 2 09:18:00] Job 31 started on M02
# [Day 2 09:18:00] Job 29 started on M04
# [Day 2 09:20:00] Job 26 finished on M00 (after 13 minutes)
# [Day 2 09:20:00] Job 35 started on M00
# [Day 2 09:21:00] Job 36 finished on M01 (after 81 minutes)
# [Day 2 09:21:00] Job 37 started on M01
# [Day 2 09:45:00] Job 12 finished on M08 (after 74 minutes)
# [Day 2 10:08:00] Job 25 finished on M03 (after 61 minutes)
# [Day 2 10:33:00] Job 29 finished on M04 (after 75 minutes)
# [Day 2 10:33:00] Job 29 started on M09
# [Day 2 10:44:00] Job 29 finished on M09 (after 11 minutes)
# [Day 2 10:44:00] Job 29 started on M03
# [Day 2 10:46:00] Job 35 finished on M00 (after 86 minutes)
# [Day 2 10:46:00] Job 38 started on M00
# [Day 2 10:48:00] Job 31 finished on M02 (after 90 minutes)
# [Day 2 10:48:00] Job 19 started on M02
# [Day 2 10:48:00] Job 31 started on M04
# [Day 2 10:52:00] Job 37 finished on M01 (after 91 minutes)
# [Day 2 10:52:00] Job 38 finished on M00 (after 06 minutes)
# [Day 2 10:52:00] Job 23 started on M01
# [Day 2 10:52:00] Job 33 started on M00
# [Day 2 11:01:00] Job 19 finished on M02 (after 13 minutes)
# [Day 2 11:01:00] Job 22 started on M02
# [Day 2 11:01:00] Job 19 started on M06
# [Day 2 11:29:00] Job 33 finished on M00 (after 37 minutes)
# [Day 2 11:29:00] Job 21 started on M00
# [Day 2 11:33:00] Job 19 finished on M06 (after 32 minutes)
# [Day 2 11:33:00] Job 19 started on M05
# [Day 2 11:53:00] Job 29 finished on M03 (after 69 minutes)
# [Day 2 11:53:00] Job 33 started on M03
# [Day 2 11:54:00] Job 19 finished on M05 (after 21 minutes)
# [Day 2 11:54:00] Job 19 started on M09
# [Day 2 12:01:00] Job 23 finished on M01 (after 69 minutes)
# [Day 2 12:01:00] Job 28 started on M01
# [Day 2 12:03:00] Job 31 finished on M04 (after 75 minutes)
# [Day 2 12:15:00] Job 22 finished on M02 (after 74 minutes)
# [Day 2 12:15:00] Job 26 started on M02
# [Day 2 12:15:00] Job 22 started on M08
# [Day 2 12:26:00] Job 19 finished on M09 (after 32 minutes)
# [Day 2 12:26:00] Job 31 started on M09
# [Day 2 12:37:00] Job 31 finished on M09 (after 11 minutes)
# [Day 2 12:40:00] Job 21 finished on M00 (after 71 minutes)
# [Day 2 12:40:00] Job 34 started on M00
# [Day 2 12:40:00] Job 21 started on M04
# [Day 2 12:53:00] Job 34 finished on M00 (after 13 minutes)
# [Day 2 12:53:00] Job 37 started on M00
# [Day 2 12:54:00] Job 33 finished on M03 (after 61 minutes)
# [Day 2 12:54:00] Job 23 started on M03
# [Day 2 13:16:00] Job 26 finished on M02 (after 61 minutes)
# [Day 2 13:16:00] Job 36 started on M02
# [Day 2 13:16:00] Job 26 started on M06
# [Day 2 13:19:00] Job 28 finished on M01 (after 78 minutes)
# [Day 2 13:19:00] Job 18 started on M01
# [Day 2 13:21:00] Job 18 finished on M01 (after 02 minutes)
# [Day 2 13:21:00] Job 30 started on M01
# [Day 2 13:21:00] Job 18 started on M05
# [Day 2 13:23:00] Job 26 finished on M06 (after 07 minutes)
# [Day 2 13:45:00] Job 22 finished on M08 (after 90 minutes)
# [Day 2 13:45:00] Job 19 started on M08
# [Day 2 14:10:00] Job 23 finished on M03 (after 76 minutes)
# [Day 2 14:10:00] Job 31 started on M03
# [Day 2 14:13:00] Job 18 finished on M05 (after 52 minutes)
# [Day 2 14:13:00] Job 22 started on M05
# [Day 2 14:18:00] Job 37 finished on M00 (after 85 minutes)
# [Day 2 14:19:00] Job 21 finished on M04 (after 99 minutes)
# [Day 2 14:19:00] Job 21 started on M06
# [Day 2 14:23:00] Job 22 finished on M05 (after 10 minutes)
# [Day 2 14:23:00] Job 23 started on M05
# [Day 2 14:23:00] Job 22 started on M07
# [Day 2 14:28:00] Job 21 finished on M06 (after 09 minutes)
# [Day 2 14:30:00] Job 30 finished on M01 (after 69 minutes)
# [Day 2 14:30:00] Job 24 started on M01
# [Day 2 14:32:00] Job 24 finished on M01 (after 02 minutes)
# [Day 2 14:32:00] Job 39 started on M01
# [Day 2 14:35:00] Job 22 finished on M07 (after 12 minutes)
# [Day 2 14:35:00] Job 22 started on M06
# [Day 2 14:51:00] Job 36 finished on M02 (after 95 minutes)
# [Day 2 14:51:00] Job 25 started on M02
# [Day 2 14:51:00] Job 36 started on M00
# [Day 2 15:04:00] Job 25 finished on M02 (after 13 minutes)
# [Day 2 15:04:00] Job 34 started on M02
# [Day 2 15:14:00] Job 19 finished on M08 (after 89 minutes)
# [Day 2 15:14:00] Job 23 finished on M05 (after 51 minutes)
# [Day 2 15:14:00] Job 26 started on M08
# [Day 2 15:14:00] Job 19 started on M07
# [Day 2 15:14:00] Job 24 started on M05
# [Day 2 15:19:00] Job 31 finished on M03 (after 69 minutes)
# [Day 2 15:19:00] Job 18 started on M03
# [Day 2 15:44:00] Job 19 finished on M07 (after 30 minutes)
# [Day 2 15:44:00] Job 19 started on M04
# [Day 2 15:50:00] Job 39 finished on M01 (after 78 minutes)
# [Day 2 15:50:00] Job 32 started on M01
# [Day 2 15:52:00] Job 32 finished on M01 (after 02 minutes)
# [Day 2 15:52:00] Job 20 started on M01
# [Day 2 16:02:00] Job 36 finished on M00 (after 71 minutes)
# [Day 2 16:04:00] Job 22 finished on M06 (after 89 minutes)
# [Day 2 16:04:00] Job 25 started on M06
# [Day 2 16:04:00] Job 22 started on M09
# [Day 2 16:05:00] Job 34 finished on M02 (after 61 minutes)
# [Day 2 16:05:00] Job 33 started on M02
# [Day 2 16:06:00] Job 24 finished on M05 (after 52 minutes)
# [Day 2 16:06:00] Job 32 started on M05
# [Day 2 16:18:00] Job 26 finished on M08 (after 64 minutes)
# [Day 2 16:18:00] Job 33 finished on M02 (after 13 minutes)
# [Day 2 16:18:00] Job 21 started on M08
# [Day 2 16:18:00] Job 28 started on M02
# [Day 2 16:27:00] Job 28 finished on M02 (after 09 minutes)
# [Day 2 16:27:00] Job 23 started on M02
# [Day 2 16:36:00] Job 25 finished on M06 (after 32 minutes)
# [Day 2 16:36:00] Job 34 started on M06
# [Day 2 16:38:00] Job 20 finished on M01 (after 46 minutes)
# [Day 2 16:38:00] Job 27 started on M01
# [Day 2 16:39:00] Job 19 finished on M04 (after 55 minutes)
# [Day 2 16:39:00] Job 36 started on M04
# [Day 2 16:43:00] Job 34 finished on M06 (after 07 minutes)
# [Day 2 16:43:00] Job 33 started on M06
# [Day 2 16:49:00] Job 22 finished on M09 (after 45 minutes)
# [Day 2 16:49:00] Job 26 started on M09
# [Day 2 16:54:00] Job 18 finished on M03 (after 95 minutes)
# [Day 2 16:54:00] Job 37 started on M03
# [Day 2 16:58:00] Job 32 finished on M05 (after 52 minutes)
# [Day 2 16:58:00] Job 25 started on M05
# [Day 2 17:00:00] Job 27 finished on M01 (after 22 minutes)
# [Day 2 17:00:00] Job 35 started on M01
# [Day 2 17:10:00] Job 21 finished on M08 (after 52 minutes)
# [Day 2 17:10:00] Job 34 started on M08
# [Day 2 17:10:00] Job 21 started on M07
# [Day 2 17:15:00] Job 33 finished on M06 (after 32 minutes)
# [Day 2 17:19:00] Job 25 finished on M05 (after 21 minutes)
# [Day 2 17:19:00] Job 20 started on M05
# [Day 2 17:33:00] Job 37 finished on M03 (after 39 minutes)
# [Day 2 17:33:00] Job 30 started on M03
# [Day 2 17:46:00] Job 35 finished on M01 (after 46 minutes)
# [Day 2 17:46:00] Job 38 started on M01
# [Day 2 17:52:00] Job 23 finished on M02 (after 85 minutes)
# [Day 2 17:52:00] Job 39 started on M02
# [Day 2 18:01:00] Job 39 finished on M02 (after 09 minutes)
# [Day 2 18:01:00] Job 37 started on M02
# [Day 2 18:05:00] Job 26 finished on M09 (after 76 minutes)
# [Day 2 18:05:00] Job 25 started on M09
# [Day 2 18:08:00] Job 38 finished on M01 (after 22 minutes)
# [Day 2 18:08:00] Job 29 started on M01
# [Day 2 18:14:00] Job 34 finished on M08 (after 64 minutes)
# [Day 2 18:14:00] Job 18 started on M08
# [Day 2 18:18:00] Job 36 finished on M04 (after 99 minutes)
# [Day 2 18:18:00] Job 22 started on M04
# [Day 2 18:18:00] Job 36 started on M06
# [Day 2 18:27:00] Job 36 finished on M06 (after 09 minutes)
# [Day 2 18:33:00] Job 20 finished on M05 (after 74 minutes)
# [Day 2 18:33:00] Job 27 started on M05
# [Day 2 18:35:00] Job 21 finished on M07 (after 85 minutes)
# [Day 2 18:36:00] Job 29 finished on M01 (after 28 minutes)
# [Day 2 18:36:00] Job 31 started on M01
# [Day 2 18:36:00] Job 29 started on M06
# [Day 2 18:37:00] Job 25 finished on M09 (after 32 minutes)
# [Day 2 18:37:00] Job 23 started on M09
# [Day 2 18:48:00] Job 23 finished on M09 (after 11 minutes)
# [Day 2 18:48:00] Job 34 started on M09
# [Day 2 18:49:00] Job 30 finished on M03 (after 76 minutes)
# [Day 2 18:49:00] Job 24 started on M03
# [Day 2 18:51:00] Job 22 finished on M04 (after 33 minutes)
# [Day 2 18:51:00] Job 20 started on M04
# [Day 2 19:02:00] Job 18 finished on M08 (after 48 minutes)
# [Day 2 19:02:00] Job 36 started on M08
# [Day 2 19:04:00] Job 31 finished on M01 (after 28 minutes)
# [Day 2 19:15:00] Job 37 finished on M02 (after 74 minutes)
# [Day 2 19:22:00] Job 29 finished on M06 (after 46 minutes)
# [Day 2 19:22:00] Job 23 started on M06
# [Day 2 19:23:00] Job 20 finished on M04 (after 32 minutes)
# [Day 2 19:34:00] Job 27 finished on M05 (after 61 minutes)
# [Day 2 19:34:00] Job 33 started on M05
# [Day 2 19:54:00] Job 36 finished on M08 (after 52 minutes)
# [Day 2 19:54:00] Job 25 started on M08
# [Day 2 19:54:00] Job 36 started on M07
# [Day 2 19:55:00] Job 33 finished on M05 (after 21 minutes)
# [Day 2 19:55:00] Job 35 started on M05
# [Day 2 20:02:00] Job 23 finished on M06 (after 40 minutes)
# [Day 2 20:02:00] Job 31 started on M06
# [Day 2 20:04:00] Job 34 finished on M09 (after 76 minutes)
# [Day 2 20:04:00] Job 18 started on M09
# [Day 2 20:24:00] Job 24 finished on M03 (after 95 minutes)
# [Day 2 20:24:00] Job 28 started on M03
# [Day 2 20:48:00] Job 31 finished on M06 (after 46 minutes)
# [Day 2 20:48:00] Job 20 started on M06
# [Day 2 21:00:00] Job 28 finished on M03 (after 36 minutes)
# [Day 2 21:00:00] Job 32 started on M03
# [Day 2 21:00:00] Job 28 started on M04
# [Day 2 21:09:00] Job 35 finished on M05 (after 74 minutes)
# [Day 2 21:09:00] Job 26 started on M05
# [Day 2 21:16:00] Job 18 finished on M09 (after 72 minutes)
# [Day 2 21:16:00] Job 33 started on M09
# [Day 2 21:16:00] Job 18 started on M00
# [Day 2 21:19:00] Job 36 finished on M07 (after 85 minutes)
# [Day 2 21:19:00] Job 23 started on M07
# [Day 2 21:23:00] Job 25 finished on M08 (after 89 minutes)
# [Day 2 21:23:00] Job 37 started on M08
# [Day 2 21:48:00] Job 33 finished on M09 (after 32 minutes)
# [Day 2 21:49:00] Job 28 finished on M04 (after 49 minutes)
# [Day 2 21:49:00] Job 35 started on M04
# [Day 2 21:56:00] Job 26 finished on M05 (after 47 minutes)
# [Day 2 21:56:00] Job 38 started on M05
# [Day 2 22:03:00] Job 18 finished on M00 (after 47 minutes)
# [Day 2 22:16:00] Job 20 finished on M06 (after 88 minutes)
# [Day 2 22:16:00] Job 18 started on M06
# [Day 2 22:21:00] Job 35 finished on M04 (after 32 minutes)
# [Day 2 22:35:00] Job 32 finished on M03 (after 95 minutes)
# [Day 2 22:35:00] Job 39 started on M03
# [Day 2 22:48:00] Job 23 finished on M07 (after 89 minutes)
# [Day 2 22:48:00] Job 25 started on M07
# [Day 2 22:48:00] Job 23 started on M04
# [Day 2 22:53:00] Job 37 finished on M08 (after 90 minutes)
# [Day 2 22:53:00] Job 24 started on M08
# [Day 2 22:57:00] Job 38 finished on M05 (after 61 minutes)
# [Day 2 22:57:00] Job 30 started on M05
# [Day 2 23:11:00] Job 39 finished on M03 (after 36 minutes)
# [Day 2 23:11:00] Job 21 started on M03
# [Day 2 23:14:00] Job 23 finished on M04 (after 26 minutes)
# [Day 2 23:14:00] Job 39 started on M04
# [Day 2 23:18:00] Job 25 finished on M07 (after 30 minutes)
# [Day 2 23:21:00] Job 18 finished on M06 (after 65 minutes)
# [Day 2 23:21:00] Job 35 started on M06
# [Day 2 23:41:00] Job 24 finished on M08 (after 48 minutes)
# [Day 2 23:41:00] Job 33 started on M08
# [Day 2 23:41:00] Job 24 started on M09
# [Day 2 23:48:00] Job 30 finished on M05 (after 51 minutes)
# [Day 2 23:48:00] Job 29 started on M05
# [Day 2 23:48:00] Job 30 started on M02
# [Day 3 00:00:00] Job 42 started on M00
# [Day 3 00:00:00] Job 43 started on M01
# [Day 3 00:03:00] Job 39 finished on M04 (after 49 minutes)
# [Day 3 00:03:00] Job 25 started on M04
# [Day 3 00:29:00] Job 42 finished on M00 (after 29 minutes)
# [Day 3 00:29:00] Job 47 started on M00
# [Day 3 00:34:00] Job 29 finished on M05 (after 46 minutes)
# [Day 3 00:34:00] Job 34 started on M05
# [Day 3 00:34:00] Job 29 started on M07
# [Day 3 00:49:00] Job 21 finished on M03 (after 98 minutes)
# [Day 3 00:49:00] Job 35 finished on M06 (after 88 minutes)
# [Day 3 00:49:00] Job 27 started on M03
# [Day 3 00:53:00] Job 24 finished on M09 (after 72 minutes)
# [Day 3 00:53:00] Job 21 started on M09
# [Day 3 00:58:00] Job 25 finished on M04 (after 55 minutes)
# [Day 3 00:58:00] Job 18 started on M04
# [Day 3 01:04:00] Job 18 finished on M04 (after 06 minutes)
# [Day 3 01:10:00] Job 33 finished on M08 (after 89 minutes)
# [Day 3 01:10:00] Job 20 started on M08
# [Day 3 01:12:00] Job 47 finished on M00 (after 43 minutes)
# [Day 3 01:12:00] Job 48 started on M00
# [Day 3 01:13:00] Job 30 finished on M02 (after 85 minutes)
# [Day 3 01:13:00] Job 40 started on M02
# [Day 3 01:15:00] Job 27 finished on M03 (after 26 minutes)
# [Day 3 01:15:00] Job 21 finished on M09 (after 22 minutes)
# [Day 3 01:15:00] Job 36 started on M03
# [Day 3 01:15:00] Job 27 started on M04
# [Day 3 01:15:00] Job 30 started on M09
# [Day 3 01:21:00] Job 34 finished on M05 (after 47 minutes)
# [Day 3 01:21:00] Job 31 started on M05
# [Day 3 01:26:00] Job 30 finished on M09 (after 11 minutes)
# [Day 3 01:26:00] Job 30 started on M06
# [Day 3 01:27:00] Job 40 finished on M02 (after 14 minutes)
# [Day 3 01:27:00] Job 41 started on M02
# [Day 3 01:29:00] Job 20 finished on M08 (after 19 minutes)
# [Day 3 01:29:00] Job 32 started on M08
# [Day 3 01:29:00] Job 20 started on M09
# [Day 3 01:31:00] Job 43 finished on M01 (after 91 minutes)
# [Day 3 01:31:00] Job 44 started on M01
# [Day 3 01:46:00] Job 29 finished on M07 (after 72 minutes)
# [Day 3 01:46:00] Job 18 started on M07
# [Day 3 02:06:00] Job 30 finished on M06 (after 40 minutes)
# [Day 3 02:07:00] Job 31 finished on M05 (after 46 minutes)
# [Day 3 02:07:00] Job 28 started on M05
# [Day 3 02:11:00] Job 18 finished on M07 (after 25 minutes)
# [Day 3 02:11:00] Job 33 started on M07
# [Day 3 02:17:00] Job 32 finished on M08 (after 48 minutes)
# [Day 3 02:17:00] Job 20 finished on M09 (after 48 minutes)
# [Day 3 02:17:00] Job 23 started on M08
# [Day 3 02:17:00] Job 32 started on M09
# [Day 3 02:18:00] Job 28 finished on M05 (after 11 minutes)
# [Day 3 02:18:00] Job 37 started on M05
# [Day 3 02:18:00] Job 28 started on M06
# [Day 3 02:24:00] Job 27 finished on M04 (after 69 minutes)
# [Day 3 02:28:00] Job 48 finished on M00 (after 76 minutes)
# [Day 3 02:28:00] Job 37 finished on M05 (after 10 minutes)
# [Day 3 02:28:00] Job 50 started on M00
# [Day 3 02:28:00] Job 39 started on M05
# [Day 3 02:39:00] Job 39 finished on M05 (after 11 minutes)
# [Day 3 02:39:00] Job 21 started on M05
# [Day 3 02:41:00] Job 33 finished on M07 (after 30 minutes)
# [Day 3 02:41:00] Job 30 started on M07
# [Day 3 02:41:00] Job 33 started on M04
# [Day 3 02:51:00] Job 41 finished on M02 (after 84 minutes)
# [Day 3 02:51:00] Job 46 started on M02
# [Day 3 02:53:00] Job 36 finished on M03 (after 98 minutes)
# [Day 3 02:53:00] Job 26 started on M03
# [Day 3 02:56:00] Job 44 finished on M01 (after 85 minutes)
# [Day 3 02:56:00] Job 45 started on M01
# [Day 3 03:11:00] Job 50 finished on M00 (after 43 minutes)
# [Day 3 03:11:00] Job 54 started on M00
# [Day 3 03:20:00] Job 28 finished on M06 (after 62 minutes)
# [Day 3 03:20:00] Job 39 started on M06
# [Day 3 03:22:00] Job 21 finished on M05 (after 43 minutes)
# [Day 3 03:22:00] Job 46 finished on M02 (after 31 minutes)
# [Day 3 03:22:00] Job 52 started on M02
# [Day 3 03:29:00] Job 32 finished on M09 (after 72 minutes)
# [Day 3 03:29:00] Job 36 started on M09
# [Day 3 03:31:00] Job 23 finished on M08 (after 74 minutes)
# [Day 3 03:31:00] Job 35 started on M08
# [Day 3 03:36:00] Job 33 finished on M04 (after 55 minutes)
# [Day 3 03:45:00] Job 26 finished on M03 (after 52 minutes)
# [Day 3 03:45:00] Job 38 started on M03
# [Day 3 03:45:00] Job 26 started on M04
# [Day 3 03:50:00] Job 35 finished on M08 (after 19 minutes)
# [Day 3 03:50:00] Job 29 started on M08
# [Day 3 03:51:00] Job 36 finished on M09 (after 22 minutes)
# [Day 3 03:51:00] Job 35 started on M09
# [Day 3 03:51:00] Job 36 started on M05
# [Day 3 04:10:00] Job 30 finished on M07 (after 89 minutes)
# [Day 3 04:10:00] Job 31 started on M07
# [Day 3 04:11:00] Job 38 finished on M03 (after 26 minutes)
# [Day 3 04:11:00] Job 34 started on M03
# [Day 3 04:17:00] Job 45 finished on M01 (after 81 minutes)
# [Day 3 04:17:00] Job 49 started on M01
# [Day 3 04:20:00] Job 29 finished on M08 (after 30 minutes)
# [Day 3 04:20:00] Job 27 started on M08
# [Day 3 04:22:00] Job 39 finished on M06 (after 62 minutes)
# [Day 3 04:27:00] Job 54 finished on M00 (after 76 minutes)
# [Day 3 04:27:00] Job 55 started on M00
# [Day 3 04:34:00] Job 36 finished on M05 (after 43 minutes)
# [Day 3 04:39:00] Job 35 finished on M09 (after 48 minutes)
# [Day 3 04:41:00] Job 27 finished on M08 (after 21 minutes)
# [Day 3 04:46:00] Job 52 finished on M02 (after 84 minutes)
# [Day 3 04:46:00] Job 47 started on M02
# [Day 3 04:56:00] Job 55 finished on M00 (after 29 minutes)
# [Day 3 04:56:00] Job 24 started on M00
# [Day 3 05:03:00] Job 34 finished on M03 (after 52 minutes)
# [Day 3 05:03:00] Job 49 finished on M01 (after 46 minutes)
# [Day 3 05:03:00] Job 51 started on M01
# [Day 3 05:15:00] Job 26 finished on M04 (after 90 minutes)
# [Day 3 05:15:00] Job 30 started on M04
# [Day 3 05:22:00] Job 31 finished on M07 (after 72 minutes)
# [Day 3 05:22:00] Job 20 started on M07
# [Day 3 05:22:00] Job 31 started on M08
# [Day 3 05:41:00] Job 30 finished on M04 (after 26 minutes)
# [Day 3 05:41:00] Job 38 started on M04
# [Day 3 05:43:00] Job 24 finished on M00 (after 47 minutes)
# [Day 3 05:43:00] Job 40 started on M00
# [Day 3 05:43:00] Job 24 started on M06
# [Day 3 05:49:00] Job 40 finished on M00 (after 06 minutes)
# [Day 3 05:49:00] Job 43 started on M00
# [Day 3 05:52:00] Job 31 finished on M08 (after 30 minutes)
# [Day 3 05:52:00] Job 30 started on M08
# [Day 3 05:58:00] Job 20 finished on M07 (after 36 minutes)
# [Day 3 05:58:00] Job 37 started on M07
# [Day 3 05:58:00] Job 20 started on M03
# [Day 3 06:10:00] Job 37 finished on M07 (after 12 minutes)
# [Day 3 06:10:00] Job 28 started on M07
# [Day 3 06:16:00] Job 47 finished on M02 (after 90 minutes)
# [Day 3 06:16:00] Job 50 started on M02
# [Day 3 06:24:00] Job 51 finished on M01 (after 81 minutes)
# [Day 3 06:24:00] Job 53 started on M01
# [Day 3 06:48:00] Job 24 finished on M06 (after 65 minutes)
# [Day 3 06:48:00] Job 37 started on M06
# [Day 3 06:50:00] Job 38 finished on M04 (after 69 minutes)
# [Day 3 06:50:00] Job 34 started on M04
# [Day 3 07:06:00] Job 30 finished on M08 (after 74 minutes)
# [Day 3 07:06:00] Job 28 finished on M07 (after 56 minutes)
# [Day 3 07:06:00] Job 38 started on M08
# [Day 3 07:06:00] Job 39 started on M07
# [Day 3 07:14:00] Job 43 finished on M00 (after 85 minutes)
# [Day 3 07:14:00] Job 44 started on M00
# [Day 3 07:17:00] Job 20 finished on M03 (after 79 minutes)
# [Day 3 07:17:00] Job 43 started on M03
# [Day 3 07:27:00] Job 38 finished on M08 (after 21 minutes)
# [Day 3 07:27:00] Job 44 finished on M00 (after 13 minutes)
# [Day 3 07:27:00] Job 28 started on M08
# [Day 3 07:27:00] Job 46 started on M00
# [Day 3 07:46:00] Job 50 finished on M02 (after 90 minutes)
# [Day 3 07:46:00] Job 45 started on M02
# [Day 3 07:49:00] Job 53 finished on M01 (after 85 minutes)
# [Day 3 07:49:00] Job 42 started on M01
# [Day 3 07:56:00] Job 43 finished on M03 (after 39 minutes)
# [Day 3 08:02:00] Job 39 finished on M07 (after 56 minutes)
# [Day 3 08:02:00] Job 35 started on M07
# [Day 3 08:11:00] Job 28 finished on M08 (after 44 minutes)
# [Day 3 08:11:00] Job 39 started on M08
# [Day 3 08:11:00] Job 28 started on M09
# [Day 3 08:17:00] Job 37 finished on M06 (after 89 minutes)
# [Day 3 08:20:00] Job 34 finished on M04 (after 90 minutes)
# [Day 3 08:20:00] Job 47 started on M04
# [Day 3 08:32:00] Job 28 finished on M09 (after 21 minutes)
# [Day 3 08:32:00] Job 37 started on M09
# [Day 3 08:38:00] Job 35 finished on M07 (after 36 minutes)
# [Day 3 08:38:00] Job 27 started on M07
# [Day 3 08:38:00] Job 35 started on M03
# [Day 3 08:53:00] Job 46 finished on M00 (after 86 minutes)
# [Day 3 08:53:00] Job 32 started on M00
# [Day 3 08:55:00] Job 39 finished on M08 (after 44 minutes)
# [Day 3 09:07:00] Job 42 finished on M01 (after 78 minutes)
# [Day 3 09:07:00] Job 48 started on M01
# [Day 3 09:17:00] Job 37 finished on M09 (after 45 minutes)
# [Day 3 09:17:00] Job 39 started on M09
# [Day 3 09:21:00] Job 45 finished on M02 (after 95 minutes)
# [Day 3 09:21:00] Job 51 started on M02
# [Day 3 09:27:00] Job 27 finished on M07 (after 49 minutes)
# [Day 3 09:27:00] Job 26 started on M07
# [Day 3 09:35:00] Job 47 finished on M04 (after 75 minutes)
# [Day 3 09:35:00] Job 24 started on M04
# [Day 3 09:38:00] Job 39 finished on M09 (after 21 minutes)
# [Day 3 09:38:00] Job 27 started on M09
# [Day 3 09:40:00] Job 32 finished on M00 (after 47 minutes)
# [Day 3 09:40:00] Job 49 started on M00
# [Day 3 09:40:00] Job 32 started on M06
# [Day 3 09:41:00] Job 24 finished on M04 (after 06 minutes)
# [Day 3 09:41:00] Job 50 started on M04
# [Day 3 09:57:00] Job 35 finished on M03 (after 79 minutes)
# [Day 3 10:12:00] Job 26 finished on M07 (after 45 minutes)
# [Day 3 10:12:00] Job 38 started on M07
# [Day 3 10:16:00] Job 48 finished on M01 (after 69 minutes)
# [Day 3 10:16:00] Job 41 started on M01
# [Day 3 10:16:00] Job 48 started on M03
# [Day 3 10:17:00] Job 49 finished on M00 (after 37 minutes)
# [Day 3 10:17:00] Job 53 started on M00
# [Day 3 10:18:00] Job 41 finished on M01 (after 02 minutes)
# [Day 3 10:18:00] Job 54 started on M01
# [Day 3 10:18:00] Job 41 started on M05
# [Day 3 10:30:00] Job 53 finished on M00 (after 13 minutes)
# [Day 3 10:30:00] Job 45 started on M00
# [Day 3 10:45:00] Job 32 finished on M06 (after 65 minutes)
# [Day 3 10:50:00] Job 27 finished on M09 (after 72 minutes)
# [Day 3 10:50:00] Job 47 started on M09
# [Day 3 10:50:00] Job 27 started on M06
# [Day 3 10:56:00] Job 51 finished on M02 (after 95 minutes)
# [Day 3 10:56:00] Job 50 finished on M04 (after 75 minutes)
# [Day 3 10:56:00] Job 44 started on M02
# [Day 3 10:56:00] Job 37 started on M04
# [Day 3 11:01:00] Job 38 finished on M07 (after 49 minutes)
# [Day 3 11:01:00] Job 47 finished on M09 (after 11 minutes)
# [Day 3 11:01:00] Job 34 started on M07
# [Day 3 11:01:00] Job 50 started on M09
# [Day 3 11:10:00] Job 41 finished on M05 (after 52 minutes)
# [Day 3 11:12:00] Job 50 finished on M09 (after 11 minutes)
# [Day 3 11:12:00] Job 38 started on M09
# [Day 3 11:27:00] Job 54 finished on M01 (after 69 minutes)
# [Day 3 11:27:00] Job 52 started on M01
# [Day 3 11:29:00] Job 37 finished on M04 (after 33 minutes)
# [Day 3 11:29:00] Job 52 finished on M01 (after 02 minutes)
# [Day 3 11:29:00] Job 32 started on M04
# [Day 3 11:29:00] Job 55 started on M01
# [Day 3 11:29:00] Job 52 started on M05
# [Day 3 11:32:00] Job 48 finished on M03 (after 76 minutes)
# [Day 3 11:32:00] Job 49 started on M03
# [Day 3 11:35:00] Job 32 finished on M04 (after 06 minutes)
# [Day 3 11:41:00] Job 45 finished on M00 (after 71 minutes)
# [Day 3 11:41:00] Job 51 started on M00
# [Day 3 11:41:00] Job 45 started on M04
# [Day 3 11:43:00] Job 27 finished on M06 (after 53 minutes)
# [Day 3 11:46:00] Job 34 finished on M07 (after 45 minutes)
# [Day 3 11:46:00] Job 24 started on M07
# [Day 3 11:57:00] Job 44 finished on M02 (after 61 minutes)
# [Day 3 11:57:00] Job 43 started on M02
# [Day 3 11:57:00] Job 44 started on M06
# [Day 3 12:04:00] Job 44 finished on M06 (after 07 minutes)
# [Day 3 12:04:00] Job 44 started on M08
# [Day 3 12:11:00] Job 24 finished on M07 (after 25 minutes)
# [Day 3 12:11:00] Job 32 started on M07
# [Day 3 12:21:00] Job 52 finished on M05 (after 52 minutes)
# [Day 3 12:21:00] Job 48 started on M05
# [Day 3 12:24:00] Job 38 finished on M09 (after 72 minutes)
# [Day 3 12:24:00] Job 38 started on M06
# [Day 3 12:33:00] Job 49 finished on M03 (after 61 minutes)
# [Day 3 12:33:00] Job 47 started on M03
# [Day 3 12:36:00] Job 32 finished on M07 (after 25 minutes)
# [Day 3 12:47:00] Job 55 finished on M01 (after 78 minutes)
# [Day 3 12:47:00] Job 40 started on M01
# [Day 3 12:52:00] Job 51 finished on M00 (after 71 minutes)
# [Day 3 13:08:00] Job 44 finished on M08 (after 64 minutes)
# [Day 3 13:08:00] Job 44 started on M09
# [Day 3 13:09:00] Job 40 finished on M01 (after 22 minutes)
# [Day 3 13:09:00] Job 46 started on M01
# [Day 3 13:11:00] Job 43 finished on M02 (after 74 minutes)
# [Day 3 13:11:00] Job 42 started on M02
# [Day 3 13:11:00] Job 43 started on M08
# [Day 3 13:12:00] Job 48 finished on M05 (after 51 minutes)
# [Day 3 13:12:00] Job 40 started on M05
# [Day 3 13:17:00] Job 38 finished on M06 (after 53 minutes)
# [Day 3 13:20:00] Job 45 finished on M04 (after 99 minutes)
# [Day 3 13:20:00] Job 42 finished on M02 (after 09 minutes)
# [Day 3 13:20:00] Job 51 started on M04
# [Day 3 13:20:00] Job 45 started on M06
# [Day 3 13:20:00] Job 53 started on M02
# [Day 3 13:29:00] Job 45 finished on M06 (after 09 minutes)
# [Day 3 13:42:00] Job 47 finished on M03 (after 69 minutes)
# [Day 3 13:42:00] Job 41 started on M03
# [Day 3 13:55:00] Job 46 finished on M01 (after 46 minutes)
# [Day 3 13:55:00] Job 47 started on M01
# [Day 3 14:13:00] Job 40 finished on M05 (after 61 minutes)
# [Day 3 14:13:00] Job 46 started on M05
# [Day 3 14:21:00] Job 53 finished on M02 (after 61 minutes)
# [Day 3 14:21:00] Job 49 started on M02
# [Day 3 14:21:00] Job 53 started on M06
# [Day 3 14:23:00] Job 47 finished on M01 (after 28 minutes)
# [Day 3 14:24:00] Job 44 finished on M09 (after 76 minutes)
# [Day 3 14:28:00] Job 53 finished on M06 (after 07 minutes)
# [Day 3 14:28:00] Job 47 started on M06
# [Day 3 14:34:00] Job 49 finished on M02 (after 13 minutes)
# [Day 3 14:34:00] Job 55 started on M02
# [Day 3 14:41:00] Job 43 finished on M08 (after 90 minutes)
# [Day 3 14:41:00] Job 45 started on M08
# [Day 3 14:43:00] Job 55 finished on M02 (after 09 minutes)
# [Day 3 14:43:00] Job 48 started on M02
# [Day 3 14:59:00] Job 51 finished on M04 (after 99 minutes)
# [Day 3 15:14:00] Job 47 finished on M06 (after 46 minutes)
# [Day 3 15:14:00] Job 49 started on M06
# [Day 3 15:17:00] Job 41 finished on M03 (after 95 minutes)
# [Day 3 15:17:00] Job 50 started on M03
# [Day 3 15:27:00] Job 46 finished on M05 (after 74 minutes)
# [Day 3 15:27:00] Job 44 started on M05
# [Day 3 15:27:00] Job 46 started on M04
# [Day 3 15:33:00] Job 45 finished on M08 (after 52 minutes)
# [Day 3 15:33:00] Job 53 started on M08
# [Day 3 15:33:00] Job 45 started on M07
# [Day 3 15:46:00] Job 49 finished on M06 (after 32 minutes)
# [Day 3 15:46:00] Job 51 started on M06
# [Day 3 15:55:00] Job 51 finished on M06 (after 09 minutes)
# [Day 3 15:59:00] Job 46 finished on M04 (after 32 minutes)
# [Day 3 15:59:00] Job 46 started on M06
# [Day 3 16:08:00] Job 48 finished on M02 (after 85 minutes)
# [Day 3 16:08:00] Job 48 started on M09
# [Day 3 16:14:00] Job 44 finished on M05 (after 47 minutes)
# [Day 3 16:14:00] Job 43 started on M05
# [Day 3 16:19:00] Job 48 finished on M09 (after 11 minutes)
# [Day 3 16:24:00] Job 43 finished on M05 (after 10 minutes)
# [Day 3 16:24:00] Job 47 started on M05
# [Day 3 16:26:00] Job 50 finished on M03 (after 69 minutes)
# [Day 3 16:26:00] Job 54 started on M03
# [Day 3 16:26:00] Job 50 started on M01
# [Day 3 16:37:00] Job 53 finished on M08 (after 64 minutes)
# [Day 3 16:37:00] Job 41 started on M08
# [Day 3 16:37:00] Job 53 started on M09
# [Day 3 16:54:00] Job 50 finished on M01 (after 28 minutes)
# [Day 3 16:58:00] Job 45 finished on M07 (after 85 minutes)
# [Day 3 16:58:00] Job 43 started on M07
# [Day 3 17:10:00] Job 47 finished on M05 (after 46 minutes)
# [Day 3 17:10:00] Job 43 finished on M07 (after 12 minutes)
# [Day 3 17:10:00] Job 49 started on M05
# [Day 3 17:10:00] Job 47 started on M07
# [Day 3 17:25:00] Job 41 finished on M08 (after 48 minutes)
# [Day 3 17:25:00] Job 51 started on M08
# [Day 3 17:27:00] Job 46 finished on M06 (after 88 minutes)
# [Day 3 17:27:00] Job 48 started on M06
# [Day 3 17:31:00] Job 49 finished on M05 (after 21 minutes)
# [Day 3 17:42:00] Job 54 finished on M03 (after 76 minutes)
# [Day 3 17:42:00] Job 52 started on M03
# [Day 3 17:42:00] Job 54 started on M05
# [Day 3 17:53:00] Job 53 finished on M09 (after 76 minutes)
# [Day 3 17:53:00] Job 41 started on M09
# [Day 3 18:07:00] Job 48 finished on M06 (after 40 minutes)
# [Day 3 18:07:00] Job 50 started on M06
# [Day 3 18:17:00] Job 51 finished on M08 (after 52 minutes)
# [Day 3 18:17:00] Job 46 started on M08
# [Day 3 18:22:00] Job 47 finished on M07 (after 72 minutes)
# [Day 3 18:22:00] Job 48 started on M07
# [Day 3 18:33:00] Job 54 finished on M05 (after 51 minutes)
# [Day 3 18:33:00] Job 53 started on M05
# [Day 3 18:33:00] Job 54 started on M02
# ...
# [Day 4 01:55:00] Job 46 started on M03
# [Day 4 01:55:00] Job 51 started on M09
# [Day 4 01:59:00] Job 42 finished on M07 (after 56 minutes)
# [Day 4 01:59:00] Job 40 started on M07
# [Day 4 01:59:00] Job 42 started on M08
# [Day 4 02:08:00] Job 49 finished on M04 (after 55 minutes)
# [Day 4 02:08:00] Job 52 started on M04
# [Day 4 02:14:00] Job 52 finished on M04 (after 06 minutes)
# [Day 4 02:14:00] Job 53 started on M04
# [Day 4 02:17:00] Job 58 finished on M01 (after 46 minutes)
# [Day 4 02:17:00] Job 51 finished on M09 (after 22 minutes)
# [Day 4 02:17:00] Job 60 started on M01
# [Day 4 02:17:00] Job 51 started on M05
# [Day 4 02:28:00] Job 69 finished on M00 (after 43 minutes)
# [Day 4 02:28:00] Job 70 started on M00
# [Day 4 02:40:00] Job 63 finished on M02 (after 84 minutes)
# [Day 4 02:40:00] Job 66 started on M02
# [Day 4 02:43:00] Job 42 finished on M08 (after 44 minutes)
# [Day 4 02:43:00] Job 42 started on M09
# [Day 4 02:48:00] Job 40 finished on M07 (after 49 minutes)
# [Day 4 02:48:00] Job 41 started on M07
# [Day 4 02:54:00] Job 66 finished on M02 (after 14 minutes)
# [Day 4 02:54:00] Job 69 started on M02
# [Day 4 02:57:00] Job 70 finished on M00 (after 29 minutes)
# [Day 4 02:57:00] Job 57 started on M00
# [Day 4 03:00:00] Job 51 finished on M05 (after 43 minutes)
# [Day 4 03:04:00] Job 42 finished on M09 (after 21 minutes)
# [Day 4 03:04:00] Job 40 started on M09
# [Day 4 03:13:00] Job 41 finished on M07 (after 25 minutes)
# [Day 4 03:13:00] Job 44 started on M07
# [Day 4 03:14:00] Job 46 finished on M03 (after 79 minutes)
# [Day 4 03:38:00] Job 60 finished on M01 (after 81 minutes)
# [Day 4 03:38:00] Job 62 started on M01
# [Day 4 03:44:00] Job 53 finished on M04 (after 90 minutes)
# [Day 4 03:44:00] Job 54 started on M04
# [Day 4 03:58:00] Job 44 finished on M07 (after 45 minutes)
# [Day 4 03:58:00] Job 55 started on M07
# [Day 4 04:10:00] Job 54 finished on M04 (after 26 minutes)
# [Day 4 04:10:00] Job 54 started on M08
# [Day 4 04:16:00] Job 40 finished on M09 (after 72 minutes)
# [Day 4 04:16:00] Job 40 started on M06
# [Day 4 04:23:00] Job 57 finished on M00 (after 86 minutes)
# [Day 4 04:23:00] Job 59 started on M00
# [Day 4 04:24:00] Job 69 finished on M02 (after 90 minutes)
# [Day 4 04:24:00] Job 60 started on M02
# [Day 4 04:24:00] Job 69 started on M04
# [Day 4 04:29:00] Job 59 finished on M00 (after 06 minutes)
# [Day 4 04:29:00] Job 61 started on M00
# [Day 4 04:54:00] Job 55 finished on M07 (after 56 minutes)
# [Day 4 04:54:00] Job 52 started on M07
# [Day 4 05:09:00] Job 62 finished on M01 (after 91 minutes)
# [Day 4 05:09:00] Job 40 finished on M06 (after 53 minutes)
# [Day 4 05:09:00] Job 64 started on M01
# [Day 4 05:19:00] Job 52 finished on M07 (after 25 minutes)
# [Day 4 05:19:00] Job 53 started on M07
# [Day 4 05:24:00] Job 54 finished on M08 (after 74 minutes)
# [Day 4 05:24:00] Job 55 started on M08
# [Day 4 05:39:00] Job 69 finished on M04 (after 75 minutes)
# [Day 4 05:39:00] Job 69 started on M09
# [Day 4 05:50:00] Job 69 finished on M09 (after 11 minutes)
# [Day 4 05:50:00] Job 69 started on M03
# [Day 4 05:55:00] Job 61 finished on M00 (after 86 minutes)
# [Day 4 05:55:00] Job 56 started on M00
# [Day 4 05:59:00] Job 60 finished on M02 (after 95 minutes)
# [Day 4 06:04:00] Job 53 finished on M07 (after 45 minutes)
# [Day 4 06:08:00] Job 55 finished on M08 (after 44 minutes)
# [Day 4 06:08:00] Job 55 started on M09
# [Day 4 06:29:00] Job 55 finished on M09 (after 21 minutes)
# [Day 4 06:34:00] Job 64 finished on M01 (after 85 minutes)
# [Day 4 06:34:00] Job 68 started on M01
# [Day 4 06:59:00] Job 69 finished on M03 (after 69 minutes)
# [Day 4 07:20:00] Job 56 finished on M00 (after 85 minutes)
# [Day 4 07:20:00] Job 68 finished on M01 (after 46 minutes)
# [Day 4 07:20:00] Job 58 started on M00
# [Day 4 07:20:00] Job 56 started on M03
# [Day 4 07:20:00] Job 65 started on M01
# [Day 4 07:57:00] Job 58 finished on M00 (after 37 minutes)
# [Day 4 07:57:00] Job 66 started on M00
# [Day 4 07:59:00] Job 56 finished on M03 (after 39 minutes)
# [Day 4 07:59:00] Job 58 started on M03
# [Day 4 07:59:00] Job 56 started on M02
# [Day 4 08:03:00] Job 66 finished on M00 (after 06 minutes)
# [Day 4 08:03:00] Job 62 started on M00
# [Day 4 08:29:00] Job 65 finished on M01 (after 69 minutes)
# [Day 4 08:29:00] Job 67 started on M01
# [Day 4 09:00:00] Job 58 finished on M03 (after 61 minutes)
# [Day 4 09:00:00] Job 65 started on M03
# [Day 4 09:13:00] Job 56 finished on M02 (after 74 minutes)
# [Day 4 09:13:00] Job 58 started on M02
# [Day 4 09:13:00] Job 56 started on M08
# [Day 4 09:26:00] Job 58 finished on M02 (after 13 minutes)
# [Day 4 09:26:00] Job 58 started on M06
# [Day 4 09:28:00] Job 62 finished on M00 (after 85 minutes)
# [Day 4 09:28:00] Job 60 started on M00
# [Day 4 09:47:00] Job 67 finished on M01 (after 78 minutes)
# [Day 4 09:47:00] Job 63 started on M01
# [Day 4 09:47:00] Job 67 started on M02
# [Day 4 09:49:00] Job 63 finished on M01 (after 02 minutes)
# [Day 4 09:49:00] Job 70 started on M01
# [Day 4 09:49:00] Job 63 started on M05
# [Day 4 09:56:00] Job 67 finished on M02 (after 09 minutes)
# [Day 4 09:58:00] Job 58 finished on M06 (after 32 minutes)
# [Day 4 10:16:00] Job 65 finished on M03 (after 76 minutes)
# [Day 4 10:16:00] Job 62 started on M03
# [Day 4 10:39:00] Job 60 finished on M00 (after 71 minutes)
# [Day 4 10:39:00] Job 64 started on M00
# [Day 4 10:39:00] Job 60 started on M04
# [Day 4 10:41:00] Job 63 finished on M05 (after 52 minutes)
# [Day 4 10:41:00] Job 58 started on M05
# [Day 4 10:43:00] Job 56 finished on M08 (after 90 minutes)
# [Day 4 10:52:00] Job 64 finished on M00 (after 13 minutes)
# [Day 4 10:52:00] Job 68 started on M00
# [Day 4 10:52:00] Job 64 started on M02
# [Day 4 10:55:00] Job 62 finished on M03 (after 39 minutes)
# [Day 4 10:55:00] Job 67 started on M03
# [Day 4 11:02:00] Job 58 finished on M05 (after 21 minutes)
# [Day 4 11:02:00] Job 65 started on M05
# [Day 4 11:02:00] Job 58 started on M09
# [Day 4 11:07:00] Job 70 finished on M01 (after 78 minutes)
# [Day 4 11:07:00] Job 57 started on M01
# [Day 4 11:29:00] Job 68 finished on M00 (after 37 minutes)
# [Day 4 11:31:00] Job 67 finished on M03 (after 36 minutes)
# [Day 4 11:31:00] Job 63 started on M03
# [Day 4 11:34:00] Job 58 finished on M09 (after 32 minutes)
# [Day 4 11:34:00] Job 58 started on M08
# [Day 4 11:53:00] Job 64 finished on M02 (after 61 minutes)
# [Day 4 11:53:00] Job 65 finished on M05 (after 51 minutes)
# [Day 4 11:53:00] Job 57 finished on M01 (after 46 minutes)
# [Day 4 11:53:00] Job 62 started on M02
# [Day 4 11:53:00] Job 64 started on M06
# [Day 4 11:53:00] Job 56 started on M05
# [Day 4 11:53:00] Job 59 started on M01
# [Day 4 12:00:00] Job 64 finished on M06 (after 07 minutes)
# [Day 4 12:03:00] Job 56 finished on M05 (after 10 minutes)
# [Day 4 12:03:00] Job 57 started on M05
# [Day 4 12:03:00] Job 56 started on M07
# [Day 4 12:15:00] Job 59 finished on M01 (after 22 minutes)
# [Day 4 12:15:00] Job 56 finished on M07 (after 12 minutes)
# [Day 4 12:15:00] Job 61 started on M01
# [Day 4 12:15:00] Job 56 started on M06
# [Day 4 12:18:00] Job 60 finished on M04 (after 99 minutes)
# [Day 4 12:18:00] Job 67 started on M04
# [Day 4 13:01:00] Job 61 finished on M01 (after 46 minutes)
# [Day 4 13:01:00] Job 69 started on M01
# [Day 4 13:03:00] Job 58 finished on M08 (after 89 minutes)
# [Day 4 13:03:00] Job 64 started on M08
# [Day 4 13:03:00] Job 58 started on M07
# [Day 4 13:06:00] Job 63 finished on M03 (after 95 minutes)
# [Day 4 13:06:00] Job 68 started on M03
# [Day 4 13:07:00] Job 62 finished on M02 (after 74 minutes)
# [Day 4 13:07:00] Job 67 finished on M04 (after 49 minutes)
# [Day 4 13:07:00] Job 70 started on M02
# [Day 4 13:16:00] Job 70 finished on M02 (after 09 minutes)
# [Day 4 13:16:00] Job 65 started on M02
# [Day 4 13:17:00] Job 57 finished on M05 (after 74 minutes)
# [Day 4 13:17:00] Job 59 started on M05
# [Day 4 13:17:00] Job 57 started on M04
# [Day 4 13:29:00] Job 69 finished on M01 (after 28 minutes)
# [Day 4 13:29:00] Job 66 started on M01
# [Day 4 13:33:00] Job 58 finished on M07 (after 30 minutes)
# [Day 4 13:44:00] Job 56 finished on M06 (after 89 minutes)
# [Day 4 13:44:00] Job 60 started on M06
# [Day 4 13:44:00] Job 56 started on M09
# [Day 4 13:49:00] Job 57 finished on M04 (after 32 minutes)
# [Day 4 13:49:00] Job 58 started on M04
# [Day 4 13:51:00] Job 66 finished on M01 (after 22 minutes)
# [Day 4 13:53:00] Job 60 finished on M06 (after 09 minutes)
# [Day 4 13:53:00] Job 69 started on M06
# [Day 4 14:07:00] Job 64 finished on M08 (after 64 minutes)
# [Day 4 14:07:00] Job 68 finished on M03 (after 61 minutes)
# [Day 4 14:07:00] Job 63 started on M08
# [Day 4 14:07:00] Job 70 started on M03
# [Day 4 14:18:00] Job 59 finished on M05 (after 61 minutes)
# [Day 4 14:18:00] Job 61 started on M05
# [Day 4 14:29:00] Job 56 finished on M09 (after 45 minutes)
# [Day 4 14:29:00] Job 64 started on M09
# [Day 4 14:39:00] Job 69 finished on M06 (after 46 minutes)
# [Day 4 14:39:00] Job 57 started on M06
# [Day 4 14:41:00] Job 65 finished on M02 (after 85 minutes)
# [Day 4 14:41:00] Job 68 started on M02
# [Day 4 14:43:00] Job 70 finished on M03 (after 36 minutes)
# [Day 4 14:43:00] Job 59 started on M03
# [Day 4 14:44:00] Job 58 finished on M04 (after 55 minutes)
# [Day 4 14:44:00] Job 56 started on M04
# [Day 4 14:54:00] Job 68 finished on M02 (after 13 minutes)
# [Day 4 14:55:00] Job 63 finished on M08 (after 48 minutes)
# [Day 4 14:55:00] Job 62 started on M08
# [Day 4 15:09:00] Job 59 finished on M03 (after 26 minutes)
# [Day 4 15:17:00] Job 56 finished on M04 (after 33 minutes)
# [Day 4 15:17:00] Job 70 started on M04
# [Day 4 15:32:00] Job 61 finished on M05 (after 74 minutes)
# [Day 4 15:32:00] Job 67 started on M05
# [Day 4 15:43:00] Job 67 finished on M05 (after 11 minutes)
# [Day 4 15:43:00] Job 66 started on M05
# [Day 4 15:45:00] Job 64 finished on M09 (after 76 minutes)
# [Day 4 15:45:00] Job 65 started on M09
# [Day 4 15:56:00] Job 65 finished on M09 (after 11 minutes)
# [Day 4 15:56:00] Job 63 started on M09
# [Day 4 16:06:00] Job 70 finished on M04 (after 49 minutes)
# [Day 4 16:06:00] Job 59 started on M04
# [Day 4 16:07:00] Job 57 finished on M06 (after 88 minutes)
# [Day 4 16:07:00] Job 68 started on M06
# [Day 4 16:25:00] Job 62 finished on M08 (after 90 minutes)
# [Day 4 16:25:00] Job 60 started on M08
# [Day 4 16:39:00] Job 68 finished on M06 (after 32 minutes)
# [Day 4 16:39:00] Job 67 started on M06
# [Day 4 16:44:00] Job 66 finished on M05 (after 61 minutes)
# [Day 4 16:44:00] Job 69 started on M05
# [Day 4 16:44:00] Job 66 started on M03
# [Day 4 17:08:00] Job 63 finished on M09 (after 72 minutes)
# [Day 4 17:08:00] Job 63 started on M00
# [Day 4 17:10:00] Job 66 finished on M03 (after 26 minutes)
# [Day 4 17:15:00] Job 59 finished on M04 (after 69 minutes)
# [Day 4 17:15:00] Job 61 started on M04
# [Day 4 17:17:00] Job 60 finished on M08 (after 52 minutes)
# [Day 4 17:17:00] Job 57 started on M08
# [Day 4 17:17:00] Job 60 started on M07
# [Day 4 17:30:00] Job 69 finished on M05 (after 46 minutes)
# [Day 4 17:30:00] Job 64 started on M05
# [Day 4 17:36:00] Job 57 finished on M08 (after 19 minutes)
# [Day 4 17:36:00] Job 59 started on M08
# [Day 4 17:36:00] Job 57 started on M09
# [Day 4 17:41:00] Job 67 finished on M06 (after 62 minutes)
# [Day 4 17:41:00] Job 65 started on M06
# [Day 4 17:47:00] Job 61 finished on M04 (after 32 minutes)
# [Day 4 17:47:00] Job 66 started on M04
# [Day 4 17:55:00] Job 63 finished on M00 (after 47 minutes)
# [Day 4 17:57:00] Job 59 finished on M08 (after 21 minutes)
# [Day 4 18:17:00] Job 64 finished on M05 (after 47 minutes)
# [Day 4 18:17:00] Job 70 started on M05
# [Day 4 18:17:00] Job 64 started on M03
# [Day 4 18:21:00] Job 65 finished on M06 (after 40 minutes)
# [Day 4 18:21:00] Job 61 started on M06
# [Day 4 18:24:00] Job 57 finished on M09 (after 48 minutes)
# [Day 4 18:28:00] Job 70 finished on M05 (after 11 minutes)
# [Day 4 18:28:00] Job 62 started on M05
# [Day 4 18:38:00] Job 62 finished on M05 (after 10 minutes)
# [Day 4 18:38:00] Job 68 started on M05
# [Day 4 18:42:00] Job 60 finished on M07 (after 85 minutes)
# [Day 4 18:42:00] Job 69 started on M07
# [Day 4 18:56:00] Job 66 finished on M04 (after 69 minutes)
# [Day 4 18:56:00] Job 66 started on M08
# [Day 4 18:59:00] Job 68 finished on M05 (after 21 minutes)
# [Day 4 18:59:00] Job 68 started on M09
# [Day 4 19:09:00] Job 64 finished on M03 (after 52 minutes)
# [Day 4 19:09:00] Job 60 started on M03
# [Day 4 19:09:00] Job 64 started on M04
# [Day 4 19:17:00] Job 66 finished on M08 (after 21 minutes)
# [Day 4 19:31:00] Job 68 finished on M09 (after 32 minutes)
# [Day 4 19:31:00] Job 68 started on M08
# [Day 4 19:49:00] Job 61 finished on M06 (after 88 minutes)
# [Day 4 19:49:00] Job 63 started on M06
# [Day 4 19:54:00] Job 69 finished on M07 (after 72 minutes)
# [Day 4 19:54:00] Job 67 started on M07
# [Day 4 20:39:00] Job 64 finished on M04 (after 90 minutes)
# [Day 4 20:47:00] Job 60 finished on M03 (after 98 minutes)
# [Day 4 20:47:00] Job 60 started on M09
# [Day 4 20:50:00] Job 67 finished on M07 (after 56 minutes)
# [Day 4 20:50:00] Job 59 started on M07
# [Day 4 20:54:00] Job 63 finished on M06 (after 65 minutes)
# [Day 4 20:54:00] Job 70 started on M06
# [Day 4 20:54:00] Job 63 started on M04
# [Day 4 21:00:00] Job 68 finished on M08 (after 89 minutes)
# [Day 4 21:00:00] Job 63 finished on M04 (after 06 minutes)
# [Day 4 21:00:00] Job 61 started on M08
# [Day 4 21:09:00] Job 60 finished on M09 (after 22 minutes)
# [Day 4 21:09:00] Job 60 started on M05
# [Day 4 21:19:00] Job 61 finished on M08 (after 19 minutes)
# [Day 4 21:19:00] Job 69 started on M08
# [Day 4 21:19:00] Job 61 started on M09
# [Day 4 21:39:00] Job 59 finished on M07 (after 49 minutes)
# [Day 4 21:39:00] Job 65 started on M07
# [Day 4 21:49:00] Job 69 finished on M08 (after 30 minutes)
# [Day 4 21:49:00] Job 67 started on M08
# [Day 4 21:52:00] Job 60 finished on M05 (after 43 minutes)
# [Day 4 21:56:00] Job 70 finished on M06 (after 62 minutes)
# [Day 4 22:07:00] Job 61 finished on M09 (after 48 minutes)
# [Day 4 22:07:00] Job 59 started on M09
# [Day 4 22:33:00] Job 67 finished on M08 (after 44 minutes)
# [Day 4 23:08:00] Job 65 finished on M07 (after 89 minutes)
# [Day 4 23:08:00] Job 57 started on M07
# [Day 4 23:08:00] Job 65 started on M04
# [Day 4 23:19:00] Job 59 finished on M09 (after 72 minutes)
# [Day 4 23:19:00] Job 67 started on M09
# [Day 4 23:19:00] Job 59 started on M06
# [Day 4 23:34:00] Job 65 finished on M04 (after 26 minutes)
# [Day 4 23:34:00] Job 65 started on M08
# [Day 4 23:40:00] Job 67 finished on M09 (after 21 minutes)
# [Day 4 23:44:00] Job 57 finished on M07 (after 36 minutes)
# [Day 4 23:44:00] Job 62 started on M07
# [Day 4 23:44:00] Job 57 started on M03
# [Day 4 23:56:00] Job 62 finished on M07 (after 12 minutes)
# [Day 4 23:56:00] Job 66 started on M07
# [Day 5 00:12:00] Job 59 finished on M06 (after 53 minutes)
# [Day 5 00:12:00] Job 62 started on M06
# [Day 5 00:45:00] Job 66 finished on M07 (after 49 minutes)
# [Day 5 00:45:00] Job 64 started on M07
# [Day 5 00:45:00] Job 66 started on M09
# [Day 5 00:48:00] Job 65 finished on M08 (after 74 minutes)
# [Day 5 01:03:00] Job 57 finished on M03 (after 79 minutes)
# [Day 5 01:30:00] Job 64 finished on M07 (after 45 minutes)
# [Day 5 01:30:00] Job 68 started on M07
# [Day 5 01:41:00] Job 62 finished on M06 (after 89 minutes)
# [Day 5 01:57:00] Job 66 finished on M09 (after 72 minutes)
# [Day 5 01:57:00] Job 62 started on M09
# [Day 5 01:57:00] Job 66 started on M06
# [Day 5 02:00:00] Job 68 finished on M07 (after 30 minutes)
# [Day 5 02:00:00] Job 63 started on M07
# [Day 5 02:00:00] Job 68 started on M04
# [Day 5 02:25:00] Job 63 finished on M07 (after 25 minutes)
# [Day 5 02:25:00] Job 70 started on M07
# [Day 5 02:42:00] Job 62 finished on M09 (after 45 minutes)
# [Day 5 02:50:00] Job 66 finished on M06 (after 53 minutes)
# [Day 5 02:55:00] Job 68 finished on M04 (after 55 minutes)
# [Day 5 02:55:00] Job 62 started on M04
# [Day 5 03:21:00] Job 70 finished on M07 (after 56 minutes)
# [Day 5 03:21:00] Job 61 started on M07
# [Day 5 03:21:00] Job 70 started on M08
# [Day 5 03:28:00] Job 62 finished on M04 (after 33 minutes)
# [Day 5 03:57:00] Job 61 finished on M07 (after 36 minutes)
# [Day 5 03:57:00] Job 61 started on M03
# [Day 5 04:05:00] Job 70 finished on M08 (after 44 minutes)
# [Day 5 04:05:00] Job 70 started on M09
# [Day 5 04:26:00] Job 70 finished on M09 (after 21 minutes)
# [Day 5 05:16:00] Job 61 finished on M03 (after 79 minutes)

# %%
df_fcfs_execution
# Out:
#      Job  Production_Plan_ID  Operation Machine  Arrival  Ready Time   Start  \
# 0      0                   0          0     M00       51        1440  1440.0
# 1      0                   0          1     M01       51        1440  2000.0
# 2      0                   0          2     M02       51        1440  2156.0
# 3      0                   0          3     M03       51        1440  2303.0
# 4      0                   0          4     M04       51        1440  2394.0
# 5      0                   0          5     M05       51        1440  2643.0
# 6      0                   0          6     M06       51        1440  2654.0
# 7      0                   0          7     M07       51        1440  2869.0
# ..   ...                 ...        ...     ...      ...         ...     ...
# 702   70                   0          2     M02     5757        5760  6547.0
# 703   70                   0          3     M03     5757        5760  6607.0
# 704   70                   0          4     M04     5757        5760  6677.0
# 705   70                   0          5     M05     5757        5760  6857.0
# 706   70                   0          6     M06     5757        5760  7014.0
# 707   70                   0          7     M07     5757        5760  7345.0
# 708   70                   0          8     M08     5757        5760  7401.0
# 709   70                   0          9     M09     5757        5760  7445.0
#
#      Processing Time     End
# 0               29.0  1469.0
# 1               78.0  2078.0
# 2                9.0  2165.0
# 3               36.0  2339.0
# 4               49.0  2443.0
# 5               11.0  2654.0
# 6               62.0  2716.0
# 7               56.0  2925.0
# ..               ...     ...
# 702              9.0  6556.0
# 703             36.0  6643.0
# 704             49.0  6726.0
# 705             11.0  6868.0
# 706             62.0  7076.0
# 707             56.0  7401.0
# 708             44.0  7445.0
# 709             21.0  7466.0
#
# [710 rows x 9 columns]

# %%
show.plot_gantt(df_fcfs_execution, perspective="Machine")

# %%
# Letzte Operation je Job auswählen
df_last_ops = df_fcfs_execution.sort_values("Operation").groupby("Job").last().reset_index()
df_last_ops
# Out:
#     Job  Production_Plan_ID  Operation Machine  Arrival  Ready Time   Start  \
# 0     0                   0          9     M09       51        1440  3029.0
# 1     1                   1          9     M08      136        1440  2706.0
# 2     2                   2          9     M04      158        1440  2225.0
# 3     3                   3          9     M05      236        1440  2883.0
# 4     4                   4          9     M06      404        1440  2954.0
# 5     5                   5          9     M07      485        1440  2706.0
# 6     6                   6          9     M04      501        1440  2591.0
# 7     7                   7          9     M03      528        1440  3006.0
# ..  ...                 ...        ...     ...      ...         ...     ...
# 63   63                   5          9     M07     5239        5760  7320.0
# 64   64                   9          9     M07     5413        5760  7245.0
# 65   65                   8          9     M08     5586        5760  7174.0
# 66   66                   4          9     M06     5587        5760  7317.0
# 67   67                   0          9     M09     5649        5760  7159.0
# 68   68                   6          9     M04     5651        5760  7320.0
# 69   69                   1          9     M08     5667        5760  7039.0
# 70   70                   0          9     M09     5757        5760  7445.0
#
#     Processing Time     End
# 0              21.0  3050.0
# 1              30.0  2736.0
# 2              33.0  2258.0
# 3              43.0  2926.0
# 4              53.0  3007.0
# 5              25.0  2731.0
# 6              55.0  2646.0
# 7              79.0  3085.0
# ..              ...     ...
# 63             25.0  7345.0
# 64             45.0  7290.0
# 65             74.0  7248.0
# 66             53.0  7370.0
# 67             21.0  7180.0
# 68             55.0  7375.0
# 69             30.0  7069.0
# 70             21.0  7466.0
#
# [71 rows x 9 columns]

# %%
df_jobs_times = df_last_ops[["Job", "Production_Plan_ID", "Arrival", "Ready Time", "End"]]

df_proc_time = df_jssp.groupby("Job", as_index=False)["Processing Time"].sum()
df_jobs_times = df_jobs_times.merge(df_proc_time, on="Job", how="left")
df_jobs_times
# Out:
#     Job  Production_Plan_ID  Arrival  Ready Time     End  Processing Time
# 0     0                   0       51        1440  3050.0              395
# 1     1                   1      136        1440  2736.0              510
# 2     2                   2      158        1440  2258.0              568
# 3     3                   3      236        1440  2926.0              655
# 4     4                   4      404        1440  3007.0              393
# 5     5                   5      485        1440  2731.0              496
# 6     6                   6      501        1440  2646.0              416
# 7     7                   7      528        1440  3085.0              539
# ..  ...                 ...      ...         ...     ...              ...
# 63   63                   5     5239        5760  7345.0              496
# 64   64                   9     5413        5760  7290.0              540
# 65   65                   8     5586        5760  7248.0              597
# 66   66                   4     5587        5760  7370.0              393
# 67   67                   0     5649        5760  7180.0              395
# 68   68                   6     5651        5760  7375.0              416
# 69   69                   1     5667        5760  7069.0              510
# 70   70                   0     5757        5760  7466.0              395
#
# [71 rows x 6 columns]

# %% [markdown]
# ## 2) Log-Normalverteilung

# %%
def plot_random_deadline_distributions(df, n=3, seed=42, steps=1440, tick_interval=2880):
    """
    Plots histogram distributions of scattered deadlines for n evenly spaced jobs.
    Each subplot shows its own x–axis labels and title.
    
    Parameters:
    - df: DataFrame with columns 'Job', 'Deadline_List', 'Arrival', 'Ready Time', 'End'
    - n: number of jobs to plot (default 3)
    - seed: random seed for reproducibility
    - steps: step size for computing x_max (default 1440)
    - tick_interval: spacing between x–ticks (default 2880)
    """
    np.random.seed(seed)

    # sort & pick n evenly spaced jobs
    df_sorted = df.sort_values("Arrival").reset_index(drop=True)
    total = len(df_sorted)
    n = min(n, total)
    indices = np.linspace(0, total - 1, n, dtype=int)
    df_plot = df_sorted.iloc[indices].sort_values("Production_Plan_ID")

    # determine global x range & ticks
    x_max = max(max(lst) for lst in df_plot["Deadline_List"])
    x_ticks = np.arange(0, x_max + steps, tick_interval)

    # create subplots (no sharex) with ample size
    fig, axes = plt.subplots(n, 1, figsize=(14, n * 3.5))
    if n == 1:
        axes = [axes]

    for ax, (_, row) in zip(axes, df_plot.iterrows()):
        # histogram
        ax.hist(row["Deadline_List"], bins=50, density=True, alpha=0.7, color="orange")
        # vertical markers
        ax.axvline(row["Arrival"], color="blue", linestyle="--", linewidth=1, label="Arrival Time")
        ax.axvline(row["Ready Time"], color="green", linestyle="--", linewidth=2, label="Ready Time")
        ax.axvline(row["Ready Time"] + row["Processing Time"], color="orange", linestyle="--", linewidth=2, label="Earliest End")
        ax.axvline(row["End"], color="red", linestyle="--", linewidth=2, label="End")

        # titles & labels
        ax.set_title(f'Production_Plan {row["Production_Plan_ID"]} - Job {row["Job"]}')
        ax.set_ylabel("Dichte")
        ax.set_xlabel("Gestreute Deadline")
        ax.set_xticks(x_ticks)
        ax.tick_params(axis="x", labelrotation=90, labelsize=8, labelbottom=True)
        ax.set_xlim(0, x_max)

        ax.grid(True)
        ax.legend()

    plt.tight_layout()
    plt.show()

# %%
def add_deadline_list_from_fn(df: pd.DataFrame, base_fn, k: int = 5, seed: int = 42, **base_fn_kwargs) -> pd.DataFrame:
    """
    Erzeugt für jeden Job eine Liste von k Deadlines, indem die gegebene Funktion
    mehrfach mit unterschiedlichen Seeds aufgerufen wird.

    Parameter:
    - df (pd.DataFrame): DataFrame mit Spalte 'Deadline', wie von base_fn erzeugt
    - base_fn (callable): Funktion, die df und base_fn_kwargs entgegennimmt
                          und eine DataFrame mit Spalte 'Deadline' zurückgibt
    - k (int): Anzahl der Szenarien / Läufe pro Job
    - seed (int): Basis-Seed; die Läufe verwenden seed, seed+1, ..., seed+k-1
    - **base_fn_kwargs: weitere Parameter, die an base_fn übergeben werden

    Rückgabe:
    - pd.DataFrame: Kopie von df mit neuer Spalte 'Deadline_List' (List[int])
    """
    df_temp = df.copy()
    all_deadlines = []

    # k Läufe generieren
    for i in range(k):
        df_run = base_fn(df_temp, seed=seed + i, **base_fn_kwargs)
        all_deadlines.append(df_run["Deadline"].tolist())

    # Transponieren: pro Zeile eine Liste aus den k Werten
    n_rows = len(df_temp)
    deadline_list = [
        [all_deadlines[j][row_idx] for j in range(k)]
        for row_idx in range(n_rows)
    ]

    df_temp["Deadline_List"] = deadline_list
    return df_temp

# %% [markdown]
# ### A) Lognormalverteilte Multiplikation von End-Zeiten zur Deadline-Erzeugung

# %%
def add_lognormal_deadlines_a(df: pd.DataFrame, sigma: float = 0.2, seed: int = 42) -> pd.DataFrame:
    """
    Fügt einem DataFrame eine Deadline-Spalte hinzu, basierend auf lognormalverteilten Faktoren multipliziert mit 'End'.

    Parameter:
        df (pd.DataFrame): DataFrame mit Spalte 'End'
        sigma (float): Standardabweichung der zugrunde liegenden Normalverteilung
        seed (int): Seed für Zufallszahlengenerierung

    Rückgabe:
        pd.DataFrame: Kopie des DataFrames mit zusätzlicher Spalte 'Deadline'
    """
    df_temp = df.copy()
    np.random.seed(seed)
    factors = np.random.lognormal(mean=0, sigma=sigma, size=len(df_temp))
    df_temp["Deadline"] = np.ceil(df_temp["End"] * factors).astype(int)
    return df_temp

df_with_deadlines_a = add_lognormal_deadlines_a(df_jobs_times, sigma=0.2)
df_with_deadlines_a
# Out:
#     Job  Production_Plan_ID  Arrival  Ready Time     End  Processing Time  \
# 0     0                   0       51        1440  3050.0              395
# 1     1                   1      136        1440  2736.0              510
# 2     2                   2      158        1440  2258.0              568
# 3     3                   3      236        1440  2926.0              655
# 4     4                   4      404        1440  3007.0              393
# 5     5                   5      485        1440  2731.0              496
# 6     6                   6      501        1440  2646.0              416
# 7     7                   7      528        1440  3085.0              539
# ..  ...                 ...      ...         ...     ...              ...
# 63   63                   5     5239        5760  7345.0              496
# 64   64                   9     5413        5760  7290.0              540
# 65   65                   8     5586        5760  7248.0              597
# 66   66                   4     5587        5760  7370.0              393
# 67   67                   0     5649        5760  7180.0              395
# 68   68                   6     5651        5760  7375.0              416
# 69   69                   1     5667        5760  7069.0              510
# 70   70                   0     5757        5760  7466.0              395
#
#     Deadline
# 0       3369
# 1       2662
# 2       2571
# 3       3968
# 4       2870
# 5       2607
# 6       3629
# 7       3597
# ..       ...
# 63      5783
# 64      8577
# 65      9507
# 66      7265
# 67      8776
# 68      7929
# 69      6214
# 70      8026
#
# [71 rows x 7 columns]

# %%
df = add_deadline_list_from_fn(df_jobs_times, base_fn=add_lognormal_deadlines_a,
                                          k=5000, seed=42, sigma=0.3)

filt = df.Production_Plan_ID.astype(str) == "2"
plot_random_deadline_distributions(df[filt], n=2)

filt = df.Production_Plan_ID.astype(str) == "3"
plot_random_deadline_distributions(df[filt], n=2)

# %% [markdown]
# ### B) Lognormalverteilte Deadlines aus globalem mittleren End-Wert, verschoben auf individuelle End-Werte

# %%
def add_lognormal_deadlines_b(df: pd.DataFrame, sigma: float = 0.2, seed: int = 42) -> pd.DataFrame:
    """
    Fügt dem DataFrame eine 'Deadline'-Spalte hinzu, indem lognormalverteilte Zufallswerte
    mit Erwartungswert ≈ mean(End) erzeugt und differenziell zu jedem End-Wert addiert werden.

    Die Formel lautet:
        Deadline_i = End_i + (Z_i - mean_end), wobei Z_i ~ LogNormal(mu, sigma)

    Dadurch bleibt die Gesamtverteilung um End erhalten, aber mit asymmetrischer Streuung.
    """
    df_copy = df.copy()
    np.random.seed(seed)

    mean_end = df_copy["End"].mean()
    mu = np.log(mean_end) - 0.5 * sigma**2

    # Lognormalverteilte Zufallswerte mit Erwartung ≈ mean_end
    samples = np.random.lognormal(mean=mu, sigma=sigma, size=len(df_copy))

    # Deadline = End + (Sample - mean_end)
    df_copy["Deadline"] = (df_copy["End"] + (samples - mean_end)).round(1)

    return df_copy

df_with_deadlines_b = add_lognormal_deadlines_b(df_jobs_times, sigma=0.2)
df_with_deadlines_b
# Out:
#     Job  Production_Plan_ID  Arrival  Ready Time     End  Processing Time  \
# 0     0                   0       51        1440  3050.0              395
# 1     1                   1      136        1440  2736.0              510
# 2     2                   2      158        1440  2258.0              568
# 3     3                   3      236        1440  2926.0              655
# 4     4                   4      404        1440  3007.0              393
# 5     5                   5      485        1440  2731.0              496
# 6     6                   6      501        1440  2646.0              416
# 7     7                   7      528        1440  3085.0              539
# ..  ...                 ...      ...         ...     ...              ...
# 63   63                   5     5239        5760  7345.0              496
# 64   64                   9     5413        5760  7290.0              540
# 65   65                   8     5586        5760  7248.0              597
# 66   66                   4     5587        5760  7370.0              393
# 67   67                   0     5649        5760  7180.0              395
# 68   68                   6     5651        5760  7375.0              416
# 69   69                   1     5667        5760  7069.0              510
# 70   70                   0     5757        5760  7466.0              395
#
#     Deadline
# 0     3469.6
# 1     2499.5
# 2     2846.3
# 3     4599.1
# 4     2678.5
# 5     2402.5
# 6     4395.4
# 7     3810.7
# ..       ...
# 63    6184.6
# 64    8068.3
# 65    8699.4
# 66    7198.2
# 67    8186.5
# 68    7648.0
# 69    6365.4
# 70    7738.7
#
# [71 rows x 7 columns]

# %%
df = add_deadline_list_from_fn(df_jobs_times, base_fn=add_lognormal_deadlines_b,
                                          k=5000, seed=42, sigma=0.3)

filt = df.Production_Plan_ID.astype(str) == "2"
plot_random_deadline_distributions(df[filt], n=2)

filt = df.Production_Plan_ID.astype(str) == "3"
plot_random_deadline_distributions(df[filt], n=2)

# %% [markdown]
# ### C) Lognormalverteilte Deadlines je Produktionsplan, direkt aus Gruppenmittelwert erzeugt

# %%
def add_groupwise_lognormal_deadlines_c(df: pd.DataFrame, sigma: float = 0.2, seed: int = 42) -> pd.DataFrame:
    """
    Fügt Deadlines hinzu, die direkt aus einer lognormalen Verteilung mit Erwartungswert = mean(End) pro Gruppe gezogen werden.
    """
    np.random.seed(seed)
    df_temp = df.copy()
    df_temp["Deadline"] = np.nan  # Leere Spalte vorbereiten

    for plan_id, group in df_temp.groupby("Production_Plan_ID"):
        n = len(group)
        mean_end = group["End"].mean()

        # Berechne μ so, dass E[X] = mean_end
        mu = np.log(mean_end) - 0.5 * sigma**2

        # Ziehe Deadlines direkt aus lognormaler Verteilung
        deadlines = np.random.lognormal(mean=mu, sigma=sigma, size=n)

        # Runde und eintragen
        df_temp.loc[group.index, "Deadline"] = np.round(deadlines, 1)

    return df_temp


df_with_deadlines_c = add_groupwise_lognormal_deadlines_c(df_jobs_times, sigma=0.2)
df_with_deadlines_c
# Out:
#     Job  Production_Plan_ID  Arrival  Ready Time     End  Processing Time  \
# 0     0                   0       51        1440  3050.0              395
# 1     1                   1      136        1440  2736.0              510
# 2     2                   2      158        1440  2258.0              568
# 3     3                   3      236        1440  2926.0              655
# 4     4                   4      404        1440  3007.0              393
# 5     5                   5      485        1440  2731.0              496
# 6     6                   6      501        1440  2646.0              416
# 7     7                   7      528        1440  3085.0              539
# ..  ...                 ...      ...         ...     ...              ...
# 63   63                   5     5239        5760  7345.0              496
# 64   64                   9     5413        5760  7290.0              540
# 65   65                   8     5586        5760  7248.0              597
# 66   66                   4     5587        5760  7370.0              393
# 67   67                   0     5649        5760  7180.0              395
# 68   68                   6     5651        5760  7375.0              416
# 69   69                   1     5667        5760  7069.0              510
# 70   70                   0     5757        5760  7466.0              395
#
#     Deadline
# 0     5793.5
# 1     4254.0
# 2     4317.4
# 3     4800.6
# 4     4897.9
# 5     5356.2
# 6     4660.2
# 7     5505.1
# ..       ...
# 63    5019.6
# 64    5355.7
# 65    3830.3
# 66    4067.3
# 67    7194.0
# 68    3478.7
# 69    3309.4
# 70    6115.9
#
# [71 rows x 7 columns]

# %%
df = add_deadline_list_from_fn(df_jobs_times, base_fn=add_groupwise_lognormal_deadlines_c,
                                          k=5000, seed=42, sigma=0.3)

filt = df.Production_Plan_ID.astype(str) == "2"
plot_random_deadline_distributions(df[filt], n=2)

filt = df.Production_Plan_ID.astype(str) == "3"
plot_random_deadline_distributions(df[filt], n=2)

# %% [markdown]
# ### D) Lognormalverteilte Deadlines je Produktionsplan, verschoben auf individuelle End-Werte

# %%
import numpy as np
import pandas as pd

def add_groupwise_lognormal_deadlines(df: pd.DataFrame, sigma: float = 0.2, seed: int = 42, method: str = 'mean') -> pd.DataFrame:
    """
    Fügt lognormal-verteilte Deadlines hinzu:
        Deadline = End + (sample - mean_end)

    Dabei wird für jede Gruppe ('Production_Plan_ID'):
      mean_end = group['End'].mean()

    Und je nach Methode:
      - method='mean':   E[X] = mean_end
                         → mu = ln(mean_end) - σ²/2
      - method='mode':   mode(X) = mean_end
                         → mu = ln(mean_end) + σ²

    Args:
        df:     DataFrame mit Spalten 'Production_Plan_ID' und 'End'
        sigma:  Lognormal-Standardabweichung
        seed:   Seed für den Zufalls-Generator
        method: 'mean'  → Erwartungswert = mean_end,
                'mode'  → Modalwert = mean_end

    Returns:
        df mit neuer Spalte 'Deadline' (float, 1 Dezimalstelle)
    """
    np.random.seed(seed)
    df_temp = df.copy()
    df_temp['Deadline'] = np.nan

    for plan_id, group in df_temp.groupby('Production_Plan_ID'):
        mean_end = group['End'].mean()
        if method == 'mean':
            # Erwartungswert = mean_end
            mu = np.log(mean_end) - 0.5 * sigma**2
        elif method == 'mode':
            # Modalwert = mean_end
            mu = np.log(mean_end) + sigma**2
        else:
            raise ValueError("Methode muss 'mean' oder 'mode' sein.")

        # Lognormal-Samples ziehen und um mean_end verschieben
        samples = np.random.lognormal(mean=mu, sigma=sigma, size=len(group))
        shifted = group['End'].values + (samples - mean_end)

        df_temp.loc[group.index, 'Deadline'] = np.round(shifted, 1)

    return df_temp

# %%
df_times = add_groupwise_lognormal_deadlines(df_jobs_times, sigma=0.2, method= "mode")
df_times
# Out:
#     Job  Production_Plan_ID  Arrival  Ready Time     End  Processing Time  \
# 0     0                   0       51        1440  3050.0              395
# 1     1                   1      136        1440  2736.0              510
# 2     2                   2      158        1440  2258.0              568
# 3     3                   3      236        1440  2926.0              655
# 4     4                   4      404        1440  3007.0              393
# 5     5                   5      485        1440  2731.0              496
# 6     6                   6      501        1440  2646.0              416
# 7     7                   7      528        1440  3085.0              539
# ..  ...                 ...      ...         ...     ...              ...
# 63   63                   5     5239        5760  7345.0              496
# 64   64                   9     5413        5760  7290.0              540
# 65   65                   8     5586        5760  7248.0              597
# 66   66                   4     5587        5760  7370.0              393
# 67   67                   0     5649        5760  7180.0              395
# 68   68                   6     5651        5760  7375.0              416
# 69   69                   1     5667        5760  7069.0              510
# 70   70                   0     5757        5760  7466.0              395
#
#     Deadline
# 0     3850.2
# 1     2485.9
# 2     1913.5
# 3     3191.6
# 4     2910.7
# 5     3177.6
# 6     2544.9
# 7     3666.7
# ..       ...
# 63    7434.2
# 64    7894.0
# 65    6351.3
# 66    6391.8
# 67    9467.2
# 68    6019.4
# 69    5815.9
# 70    8608.4
#
# [71 rows x 7 columns]

# %%
df = add_deadline_list_from_fn(df_jobs_times, base_fn=add_groupwise_lognormal_deadlines,
                                          k=5000, seed=42, sigma=0.3, method="mean")

filt = df.Production_Plan_ID.astype(str).isin(["2"])
plot_random_deadline_distributions( df[filt], n=2)

filt = df.Production_Plan_ID.astype(str).isin(["3"])
plot_random_deadline_distributions( df[filt], n=2)

# %%
df = add_deadline_list_from_fn(df_jobs_times, base_fn=add_groupwise_lognormal_deadlines,
                                          k=5000, seed=42, sigma=0.3, method="mode")

filt = df.Production_Plan_ID.astype(str).isin(["2"])
plot_random_deadline_distributions( df[filt], n=2)

filt = df.Production_Plan_ID.astype(str).isin(["3"])
plot_random_deadline_distributions( df[filt], n=2)

# %% [markdown]
# ## III) "Untere Begrenzung" der Deadlines

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_relative_spread_horizontal(df, end_col='End', deadline_col='Deadline',
                                    figsize=(12, 3),
                                    title='Range-Boxplot der relativen Streuung'):
    """
    Zeichnet einen symmetrischen, horizontalen Boxplot der relativen Streuung
    (Deadline - End) / End mit Inline-Kommentaren im ax.boxplot-Aufruf.
    """
    # 1. Relative Streuung berechnen
    rel = (df[deadline_col] - df[end_col]) / df[end_col]

    # 2. Figure und Axes anlegen
    fig, ax = plt.subplots(figsize=figsize)

    # 3. Horizontaler Boxplot mit Inline-Kommentaren
    bp = ax.boxplot(rel,
                    vert=False,                  # horizontal statt vertical
                    patch_artist=True,           # ermöglicht Box-Füllung
                    showcaps=True,               # zeichnet Caps an den Whiskern
                    whis=(0, 100),               # Whiskers von Min bis Max
                    widths=0.4,                  # Dicke der Box (max. 1)
                    boxprops=dict(facecolor='#ededed', edgecolor='darkslategray'),      # Box-Farben
                    medianprops=dict(color='#ff3300', linewidth=2),  # Medianlinie
                    whiskerprops=dict(color='darkslategray'),        # Whisker-Farbe
                    capprops=dict(color='darkslategray'),            # Caps-Farbe
                    flierprops=dict(marker='o', markerfacecolor='black', markersize=2)  # Ausreißer-Markierung
    )

    # 4. X-Ticks in 0.1-Schritten setzen
    xticks = np.arange(-1, 1.01, 0.1)
    ax.set_xticks(xticks)

    # 5. Styling
    ax.set_yticks([])                     # Y-Achse ausblenden
    for spine in ax.spines.values():
        spine.set_linewidth(1.2)
    ax.set_xlabel('Relative Streuung\n(Deadline - End) / End')
    ax.set_title(title)
    ax.xaxis.grid(True, linestyle='--', alpha=0.7)
    plt.tight_layout()
    return fig, ax

# %%
df_times = add_groupwise_lognormal_deadlines(df_jobs_times, sigma=0.2, method= "mode")
df_times.head()
# Out:
#    Job  Production_Plan_ID  Arrival  Ready Time     End  Processing Time  \
# 0    0                   0       51        1440  3050.0              395
# 1    1                   1      136        1440  2736.0              510
# 2    2                   2      158        1440  2258.0              568
# 3    3                   3      236        1440  2926.0              655
# 4    4                   4      404        1440  3007.0              393
#
#    Deadline
# 0    3850.2
# 1    2485.9
# 2    1913.5
# 3    3191.6
# 4    2910.7

# %%
fig, ax = plot_relative_spread_horizontal(df_times)
plt.show()

# %%
df_times['Deadline'] = np.ceil(
    np.maximum(
        df_times['Deadline'],
        df_times['Ready Time'] + df_times['Processing Time']
    )
).astype(int)
df_times.head()
# Out:
#    Job  Production_Plan_ID  Arrival  Ready Time     End  Processing Time  \
# 0    0                   0       51        1440  3050.0              395
# 1    1                   1      136        1440  2736.0              510
# 2    2                   2      158        1440  2258.0              568
# 3    3                   3      236        1440  2926.0              655
# 4    4                   4      404        1440  3007.0              393
#
#    Deadline
# 0      3851
# 1      2486
# 2      2008
# 3      3192
# 4      2911

# %%
fig, ax = plot_relative_spread_horizontal(df_times)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Relative Streuung berechnen
rel = (df_times['Deadline'] - df_times['End']) / df_times['End']

# 2. Plot
plt.figure(figsize=(10, 4))
plt.hist(rel, bins=50, color='steelblue', edgecolor='white')  # Balken
plt.xlabel('Relative Streuung (Deadline - End) / End')
plt.ylabel('Häufigkeit')
plt.title('Histogramm der relativen Streuung')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
