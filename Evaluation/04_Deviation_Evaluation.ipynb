# %%
import matplotlib.pyplot as plt
import pandas as pd

# Analyses
from src.analyses.schedule_jobs_dataframe import jobs_metrics_from_operations_df, mean_start_deviation_per_shift_df

df_experiments = pd.read_csv("experiments_v01.csv")
df_experiments
# Out:
#     Experiment_ID  Abs Lateness Ratio  Inner Tardiness Ratio  \
# 0             B-1                0.25                   1.00
# 1             B-2                0.25                   0.75
# 2             B-3                0.25                   0.50
# 3             B-4                0.25                   0.25
# 4             B-5                0.25                   0.00
# ..            ...                 ...                    ...
# 175         R-125                1.00                   1.00
# 176         R-126                1.00                   0.75
# 177         R-127                1.00                   0.50
# 178         R-128                1.00                   0.25
# 179         R-129                1.00                   0.00
#
#      Max Bottleneck Utilization  Sim Sigma  Shift Length  w_t  w_e  w_dev  \
# 0                          0.75        0.1          1440    1    0      3
# 1                          0.75        0.1          1440    3    1     12
# ...

# %%
df_shift_dev = pd.read_csv("experiment_shift_dev_v01.csv")


df_dev_mean = (
    df_shift_dev
    .groupby("Experiment_ID")["Deviation",]
    .mean()
    .round(2)  # ➜ Rundet auf 2 Nachkommastellen
    .reset_index()
    .rename(columns={"Deviation": "Deviation_Mean", "Pairs": "Pairs_Mean"})
)
df_experiments = df_experiments.merge(df_dev_mean, on="Experiment_ID", how="left")
df_experiments
# Out:
#     Experiment_ID  Abs Lateness Ratio  Inner Tardiness Ratio  \
# 0             B-1                0.25                   1.00
# 1             B-2                0.25                   0.75
# 2             B-3                0.25                   0.50
# 3             B-4                0.25                   0.25
# 4             B-5                0.25                   0.00
# ..            ...                 ...                    ...
# 175         R-125                1.00                   1.00
# 176         R-126                1.00                   0.75
# 177         R-127                1.00                   0.50
# 178         R-128                1.00                   0.25
# 179         R-129                1.00                   0.00
#
#      Max Bottleneck Utilization  Sim Sigma  Shift Length  w_t  w_e  w_dev  \
# 0                          0.75        0.1          1440    1    0      3
# 1                          0.75        0.1          1440    3    1     12
# ...

# %% [markdown]
# ## Evaluation

# %%
from src.DataFrameEvaluations import plot_experiment_heatmaps_good_low,plot_experiment_boxrow

# %%
fig, axes = plot_experiment_heatmaps_good_low(
    df_experiments,
    value_col="Deviation_Mean", value_as="Ø result. Deviation",
    x_col="Inner Tardiness Ratio", x_col_as=  r" Verhältnis ${T}$ zu ${E}$",
    y_col="Abs Lateness Ratio", y_col_as= r"Verhältnis Lateness ${T}$, ${E}$ zu ${Dev}$",
    vmin=0.0, vmax= 120,
    #vmax=df_experiments["Mean_Tardiness"].max(),
    annot=True, fmt=".2f",
    extend="auto"
)

# %%
fig, axes = plot_experiment_heatmaps_good_low(
    df_experiments[df_experiments["Max Bottleneck Utilization"].isin([0.75, 0.95])],
    value_col="Deviation_Mean", value_as="Ø result. Deviation",
    x_col="Inner Tardiness Ratio", x_col_as=  r" Verhältnis ${T}$ zu ${E}$",
    y_col="Abs Lateness Ratio", y_col_as= r"Verhältnis Lateness ${T}$, ${E}$ zu ${Dev}$",
    vmin=0.0, vmax= 120,
    col_col="Max Bottleneck Utilization",
    #vmax=df_experiments["Mean_Tardiness"].max(),
    annot=True, fmt=".2f",
    extend="auto"
)

# %%
fig, axes = plot_experiment_heatmaps_good_low(
    df_experiments,
    value_col="Deviation_Mean",
    x_col="Inner Tardiness Ratio",
    y_col="Abs Lateness Ratio",
    col_col="Sim Sigma",
    vmin=0.0, vmax= 120,
    #vmax=df_experiments["Mean_Tardiness"].max(),
    annot=True, fmt=".2f",
    extend="auto"
)

# %%
fig, axes = plot_experiment_boxrow(
    df_values=df_shift_dev,
    df_meta=df_experiments,
    value_col="Deviation",
    x_col="Abs Lateness Ratio", x_col_as= r"Verhältnis Lateness {$\overline{T}$, $\overline{E}$} zu $\overline{\mathrm{Dev}}$",
    # optional Facetten, falls gewünscht:
    #col_col="Sim Sigma",
    value_as="Startzeit-Abweichung",
    median_fmt = ".1f"
)
plt.show()

# %%
fig, axes = plot_experiment_boxrow(
    df_values=df_shift_dev,
    df_meta=df_experiments,
    value_col="Deviation",
    x_col="Abs Lateness Ratio", x_col_as= r"Verhältnis Lateness {$\overline{T}$, $\overline{E}$} zu $\overline{\mathrm{Dev}}$",
    # optional Facetten, falls gewünscht:
    col_col="Max Bottleneck Utilization", # "Sim Sigma",
    value_as="Startzeit-Abweichung",
    median_fmt = ".1f",
    xlabel_at_col = 1
)
plt.show()
